# %%
import os
import sys
import pickle
from skimage import io
import matplotlib.pyplot as plt
import numpy 
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import _LRScheduler
from torch.autograd import Variable
import torchvision
import torchvision.transforms as transforms
import argparse
import glob
import cv2
import torch.optim as optim
import matplotlib
matplotlib.use('Agg')

# %% [markdown]
# ## Loading Data (CIFAR100)

# %%
class CIFAR100Train(Dataset):
    """CIFAR100 test dataset, derived from
    torch.utils.data.DataSet
    """

    def __init__(self, path, transform=None):
        #if transform is given, we transoform data using
        with open(os.path.join(path, 'train'), 'rb') as CIFAR100:
            self.data = pickle.load(CIFAR100, encoding='bytes')
        self.transform = transform
        
    def __len__(self):
        return len(self.data['fine_labels'.encode()])

    def __getitem__(self, index):
        label = self.data['fine_labels'.encode()][index]
        r = self.data['data'.encode()][index, :1024].reshape(32, 32)
        g = self.data['data'.encode()][index, 1024:2048].reshape(32, 32)
        b = self.data['data'.encode()][index, 2048:].reshape(32, 32)
        image = numpy.dstack((r, g, b))

        if self.transform:
            image = self.transform(image)
        return label, image

class CIFAR100Test(Dataset):
    """CIFAR100 test dataset, derived from
    torch.utils.data.DataSet
    """

    def __init__(self, path, transform=None):
        with open(os.path.join(path, 'test'), 'rb') as CIFAR100:
            self.data = pickle.load(CIFAR100, encoding='bytes')
        self.transform = transform 

    def __len__(self):
        return len(self.data['data'.encode()])
    
    def __getitem__(self, index):
        label = self.data['fine_labels'.encode()][index]
        r = self.data['data'.encode()][index, :1024].reshape(32, 32)
        g = self.data['data'.encode()][index, 1024:2048].reshape(32, 32)
        b = self.data['data'.encode()][index, 2048:].reshape(32, 32)
        image = numpy.dstack((r, g, b))

        if self.transform:
            image = self.transform(image)
        return label, image

# %% [markdown]
# ## Attention Modules (CAM,SAM,CBAM,ZAM)

# %%
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        return self.sigmoid(out)

class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=3):
        super(SpatialAttention, self).__init__()

        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return self.sigmoid(x)

class CBAM(nn.Module):
    def __init__(self, in_planes):
        super(CBAM, self).__init__()

        self.ca = ChannelAttention(in_planes)
        self.sa = SpatialAttention()
        
    def forward(self, x):
        
        out = x * (self.ca(x))
        out = out * (self.sa(out))
        
        return out

## ZAM ##    
class ZeroChannelAttention(nn.Module):
    def __init__(self):
        super(ZeroChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
    
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        return self.sigmoid(self.avg_pool(x) + self.max_pool(x))

class ZeroSpatialAttention(nn.Module):
    def __init__(self):
        super(ZeroSpatialAttention, self).__init__()

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        return self.sigmoid(avg_out + max_out)
    
class ZAM(nn.Module):
    def __init__(self, use_skip_connection = False):
        super(ZAM, self).__init__()

        self.ca = ZeroChannelAttention()
        self.sa = ZeroSpatialAttention()
        self.use_skip_connection = use_skip_connection
        
    def forward(self, x):
        
        out = x + x * self.ca(x) if self.use_skip_connection else x * self.ca(x)
        out = out + out * self.sa(out) if self.use_skip_connection else out * self.sa(out)
        
        return out

# %% [markdown]
# ## Models (ResNet,MobileNet)

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )
        
        self.cbam = CBAM(planes)

    def forward(self, x):
        residual = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = self.cbam(out)
        out += self.shortcut(residual)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )
        
        self.cbam = CBAM(self.expansion*planes)
        
    def forward(self, x):
        residual = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out = self.cbam(out)
        out += self.shortcut(residual)
        out = F.relu(out)
        return out


class ResNetCBAM(nn.Module):
    def __init__(self, block, num_blocks, num_classes=100):
        super(ResNetCBAM, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNetCBAM18():
    return ResNetCBAM(BasicBlock, [2,2,2,2])

class MobileNetCBAM(nn.Module):
    def __init__(self, classes = 100):
        super(MobileNetCBAM, self).__init__()

        def conv_bn(inp, oup, stride):
            return nn.Sequential(
                nn.Conv2d(inp, oup, 3, stride, 1, bias=False),
                nn.BatchNorm2d(oup),
                nn.ReLU(inplace=True)
            )

        def conv_dw(inp, oup, stride):
            return nn.Sequential(
                nn.Conv2d(inp, inp, 3, stride, 1, groups=inp, bias=False),
                nn.BatchNorm2d(inp),
                nn.ReLU(inplace=True),
                nn.Conv2d(inp, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
                CBAM(oup),
                nn.ReLU(inplace=True),
            )

        self.model = nn.Sequential(
            conv_bn(  3,  32, 1), 
            conv_dw( 32,  64, 1),
            conv_dw( 64, 128, 1),
            conv_dw(128, 128, 1),
            conv_dw(128, 256, 2),
            conv_dw(256, 256, 1),
            conv_dw(256, 512, 2),
            conv_dw(512, 512, 1),
            conv_dw(512, 512, 1),
            conv_dw(512, 512, 1),
            conv_dw(512, 512, 1),
            conv_dw(512, 512, 1),
            conv_dw(512, 1024, 2),
            conv_dw(1024, 1024, 1),
            nn.AvgPool2d(4),
        )
        self.fc = nn.Linear(1024, classes)

    def forward(self, x):
        x = self.model(x)
        x = x.view(-1, 1024)
        x = self.fc(x)
        return x

# %% [markdown]
# ## Utils

# %%
def get_network():
    net=ResNetCBAM18().cuda()
    #net=MobileNetCBAM().cuda()
    """ return given network
    """
    return net


def get_training_dataloader(mean, std, batch_size=16, num_workers=2, shuffle=True):
    """ return training dataloader
    Args:
        mean: mean of CIFAR100 training dataset
        std: std of CIFAR100 training dataset
        path: path to CIFAR100 training python dataset
        batch_size: dataloader batchsize
        num_workers: dataloader num_works
        shuffle: whether to shuffle 
    Returns: train_data_loader:torch dataloader object
    """

    transform_train = transforms.Compose([
        #transforms.ToPILImage(),
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
    #CIFAR100_training = CIFAR100Train(path, transform=transform_train)
    CIFAR100_training = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
    CIFAR100_training_loader = DataLoader(
        CIFAR100_training, shuffle=shuffle, num_workers=num_workers, batch_size=batch_size)

    return CIFAR100_training_loader

def get_test_dataloader(mean, std, batch_size=16, num_workers=2, shuffle=True):
    """ return training dataloader
    Args:
        mean: mean of CIFAR100 test dataset
        std: std of CIFAR100 test dataset
        path: path to CIFAR100 test python dataset
        batch_size: dataloader batchsize
        num_workers: dataloader num_works
        shuffle: whether to shuffle 
    Returns: CIFAR100_test_loader:torch dataloader object
    """

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
    #CIFAR100_test = CIFAR100Test(path, transform=transform_test)
    CIFAR100_test = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
    CIFAR100_test_loader = DataLoader(
        CIFAR100_test, shuffle=shuffle, num_workers=num_workers, batch_size=batch_size)

    return CIFAR100_test_loader

def compute_mean_std(CIFAR100_dataset):
    """compute the mean and std of CIFAR100 dataset
    Args:
        CIFAR100_training_dataset or CIFAR100_test_dataset
        witch derived from class torch.utils.data
    
    Returns:
        a tuple contains mean, std value of entire dataset
    """

    data_r = numpy.dstack([CIFAR100_dataset[i][1][:, :, 0] for i in range(len(CIFAR100_dataset))])
    data_g = numpy.dstack([CIFAR100_dataset[i][1][:, :, 1] for i in range(len(CIFAR100_dataset))])
    data_b = numpy.dstack([CIFAR100_dataset[i][1][:, :, 2] for i in range(len(CIFAR100_dataset))])
    mean = numpy.mean(data_r), numpy.mean(data_g), numpy.mean(data_b)
    std = numpy.std(data_r), numpy.std(data_g), numpy.std(data_b)

    return mean, std

class WarmUpLR(_LRScheduler):
    """warmup_training learning rate scheduler
    Args:
        optimizer: optimzier(e.g. SGD)
        total_iters: totoal_iters of warmup phase
    """
    def __init__(self, optimizer, total_iters, last_epoch=-1):
        
        self.total_iters = total_iters
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        """we will use the first m batches, and set the learning
        rate to base_lr * m / total_iters
        """
        return [base_lr * self.last_epoch / (self.total_iters + 1e-8) for base_lr in self.base_lrs]

# %%
from datetime import datetime
CIFAR10_TRAIN_MEAN = (0.49139968, 0.48215827 ,0.44653124)
CIFAR10_TRAIN_STD = (0.24703233, 0.24348505, 0.26158768)

CIFAR100_TRAIN_MEAN = (0.5088964127604166, 0.48739301317401956, 0.44194221124387256)
CIFAR100_TRAIN_STD = (0.2682515741720801, 0.2573637364478126, 0.2770957707973042)

#directory to save weights file
CHECKPOINT_PATH = 'checkpoint'

#total training epoches
EPOCH = 25
MILESTONES = [6, 12, 16]

#initial learning rate
#INIT_LR = 0.1

#time of we run the script
TIME_NOW = datetime.now().isoformat()

#tensorboard log dir
LOG_DIR = 'runs'

#save weights file per SAVE_EPOCH epoch
SAVE_EPOCH = 10

# %% [markdown]
# ## Training the model

# %%
def train(epoch):

    net.train()
    for batch_index, (images, labels) in enumerate(CIFAR100_training_loader):
        if epoch <= 1:
            warmup_scheduler.step()

        images = Variable(images)
        labels = Variable(labels)

        labels = labels.cuda()
        images = images.cuda()

        optimizer.zero_grad()
        outputs = net(images)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()

        print('Training Epoch: {epoch} [{trained_samples}/{total_samples}]\tLoss: {:0.4f}\tLR: {:0.6f}'.format(
            loss.item(),
            optimizer.param_groups[0]['lr'],
            epoch=epoch,
            trained_samples=batch_index * 128 + len(images),
            total_samples=len(CIFAR100_training_loader.dataset)
        ))


    for name, param in net.named_parameters():
        layer, attr = os.path.splitext(name)
        attr = attr[1:]

def eval_training(epoch):
    net.eval()

    test_loss = 0.0 # cost function error
    correct = 0.0

    for (images, labels) in CIFAR100_test_loader:
        images = Variable(images)
        labels = Variable(labels)

        images = images.cuda()
        labels = labels.cuda()

        outputs = net(images)
        loss = loss_function(outputs, labels)
        test_loss += loss.item()
        _, preds = outputs.max(1)
        correct += preds.eq(labels).sum()

    print('Test set: Average loss: {:.4f}, Accuracy: {:.4f}'.format(
        test_loss / len(CIFAR100_test_loader.dataset),
        correct.float() / len(CIFAR100_test_loader.dataset)
    ))
    print()


    return correct.float() / len(CIFAR100_test_loader.dataset)

if __name__ == '__main__':
    
#     parser = argparse.ArgumentParser()
#     parser.add_argument('-net', type=str, required=True, help='net type')
#     parser.add_argument('-gpu', type=bool, default=True, help='use gpu or not')
#     parser.add_argument('-w', type=int, default=2, help='number of workers for dataloader')
#     parser.add_argument('-b', type=int, default=128, help='batch size for dataloader')
#     parser.add_argument('-s', type=bool, default=True, help='whether shuffle the dataset')
#     parser.add_argument('-warm', type=int, default=1, help='warm up training phase')
#     parser.add_argument('-lr', type=float, default=0.1, help='initial learning rate')
#     args = parser.parse_args()

    net= get_network()
    
        
    #data preprocessing:
    CIFAR100_training_loader = get_training_dataloader(
        CIFAR100_TRAIN_MEAN,
        CIFAR100_TRAIN_STD,
        num_workers=2,
        batch_size=128,
        shuffle=True
    )
    
    CIFAR100_test_loader = get_test_dataloader(
        CIFAR100_TRAIN_MEAN,
        CIFAR100_TRAIN_STD,
        num_workers=2,
        batch_size=128,
        shuffle=True
    )
    
    loss_function = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
    train_scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=MILESTONES, gamma=0.15) #learning rate decay
    iter_per_epoch = len(CIFAR100_training_loader)
    warmup_scheduler = WarmUpLR(optimizer, iter_per_epoch * 1)
    checkpoint_path = os.path.join(CHECKPOINT_PATH, "resnetcbam18")

    #create checkpoint folder to save model
    if not os.path.exists(checkpoint_path):
        os.makedirs(checkpoint_path)
    checkpoint_path = os.path.join(checkpoint_path, '{net}-{epoch}-{type}.pth')

    best_acc = 0.0
    for epoch in range(1, EPOCH):
        if epoch > 1:
            train_scheduler.step(epoch)

        train(epoch)
        acc = eval_training(epoch)

        #start to save best performance model after learning rate decay to 0.01 
        if epoch > MILESTONES[1] and best_acc < acc:
            torch.save(net.state_dict(), checkpoint_path.format(net="resnetcbam18", epoch=epoch, type='best'))
            best_acc = acc
            continue

        if not epoch % SAVE_EPOCH:
            torch.save(net.state_dict(), checkpoint_path.format(net="resnetcbam18", epoch=epoch, type='regular'))
    print()
    print("best_acc: ", best_acc)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169001437/169001437 [00:03<00:00, 48070033.32it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Training Epoch: 1 [128/50000]	Loss: 4.6507	LR: 0.000256
# Training Epoch: 1 [256/50000]	Loss: 4.6324	LR: 0.000512
# Training Epoch: 1 [384/50000]	Loss: 4.6493	LR: 0.000767
# Training Epoch: 1 [512/50000]	Loss: 4.6173	LR: 0.001023
# Training Epoch: 1 [640/50000]	Loss: 4.6510	LR: 0.001279
# Training Epoch: 1 [768/50000]	Loss: 4.6976	LR: 0.001535
# Training Epoch: 1 [896/50000]	Loss: 4.6573	LR: 0.001790
# Training Epoch: 1 [1024/50000]	Loss: 4.7152	LR: 0.002046
# Training Epoch: 1 [1152/50000]	Loss: 4.5731	LR: 0.002302
# Training Epoch: 1 [1280/50000]	Loss: 4.6527	LR: 0.002558
# Training Epoch: 1 [1408/50000]	Loss: 4.6436	LR: 0.002813
# Training Epoch: 1 [1536/50000]	Loss: 4.6094	LR: 0.003069
# Training Epoch: 1 [1664/50000]	Loss: 4.6279	LR: 0.003325
# Training Epoch: 1 [1792/50000]	Loss: 4.6317	LR: 0.003581
# Training Epoch: 1 [1920/50000]	Loss: 4.6196	LR: 0.003836
# Training Epoch: 1 [2048/50000]	Loss: 4.6183	LR: 0.004092
# Training Epoch: 1 [2176/50000]	Loss: 4.6311	LR: 0.004348
# Training Epoch: 1 [2304/50000]	Loss: 4.6127	LR: 0.004604
# Training Epoch: 1 [2432/50000]	Loss: 4.6092	LR: 0.004859
# Training Epoch: 1 [2560/50000]	Loss: 4.5878	LR: 0.005115
# Training Epoch: 1 [2688/50000]	Loss: 4.5749	LR: 0.005371
# Training Epoch: 1 [2816/50000]	Loss: 4.6031	LR: 0.005627
# Training Epoch: 1 [2944/50000]	Loss: 4.5741	LR: 0.005882
# Training Epoch: 1 [3072/50000]	Loss: 4.5415	LR: 0.006138
# Training Epoch: 1 [3200/50000]	Loss: 4.5378	LR: 0.006394
# Training Epoch: 1 [3328/50000]	Loss: 4.5447	LR: 0.006650
# Training Epoch: 1 [3456/50000]	Loss: 4.5466	LR: 0.006905
# Training Epoch: 1 [3584/50000]	Loss: 4.5047	LR: 0.007161
# Training Epoch: 1 [3712/50000]	Loss: 4.5115	LR: 0.007417
# Training Epoch: 1 [3840/50000]	Loss: 4.5655	LR: 0.007673
# Training Epoch: 1 [3968/50000]	Loss: 4.4941	LR: 0.007928
# Training Epoch: 1 [4096/50000]	Loss: 4.5405	LR: 0.008184
# Training Epoch: 1 [4224/50000]	Loss: 4.5044	LR: 0.008440
# Training Epoch: 1 [4352/50000]	Loss: 4.4329	LR: 0.008696
# Training Epoch: 1 [4480/50000]	Loss: 4.4754	LR: 0.008951
# Training Epoch: 1 [4608/50000]	Loss: 4.4646	LR: 0.009207
# Training Epoch: 1 [4736/50000]	Loss: 4.4347	LR: 0.009463
# Training Epoch: 1 [4864/50000]	Loss: 4.4428	LR: 0.009719
# Training Epoch: 1 [4992/50000]	Loss: 4.4673	LR: 0.009974
# Training Epoch: 1 [5120/50000]	Loss: 4.3743	LR: 0.010230
# Training Epoch: 1 [5248/50000]	Loss: 4.4955	LR: 0.010486
# Training Epoch: 1 [5376/50000]	Loss: 4.3461	LR: 0.010742
# Training Epoch: 1 [5504/50000]	Loss: 4.4251	LR: 0.010997
# Training Epoch: 1 [5632/50000]	Loss: 4.3611	LR: 0.011253
# Training Epoch: 1 [5760/50000]	Loss: 4.4575	LR: 0.011509
# Training Epoch: 1 [5888/50000]	Loss: 4.3841	LR: 0.011765
# Training Epoch: 1 [6016/50000]	Loss: 4.3607	LR: 0.012020
# Training Epoch: 1 [6144/50000]	Loss: 4.4392	LR: 0.012276
# Training Epoch: 1 [6272/50000]	Loss: 4.3713	LR: 0.012532
# Training Epoch: 1 [6400/50000]	Loss: 4.3732	LR: 0.012788
# Training Epoch: 1 [6528/50000]	Loss: 4.5575	LR: 0.013043
# Training Epoch: 1 [6656/50000]	Loss: 4.2912	LR: 0.013299
# Training Epoch: 1 [6784/50000]	Loss: 4.4365	LR: 0.013555
# Training Epoch: 1 [6912/50000]	Loss: 4.2794	LR: 0.013811
# Training Epoch: 1 [7040/50000]	Loss: 4.2445	LR: 0.014066
# Training Epoch: 1 [7168/50000]	Loss: 4.2476	LR: 0.014322
# Training Epoch: 1 [7296/50000]	Loss: 4.2848	LR: 0.014578
# Training Epoch: 1 [7424/50000]	Loss: 4.3164	LR: 0.014834
# Training Epoch: 1 [7552/50000]	Loss: 4.3514	LR: 0.015090
# Training Epoch: 1 [7680/50000]	Loss: 4.1648	LR: 0.015345
# Training Epoch: 1 [7808/50000]	Loss: 4.2274	LR: 0.015601
# Training Epoch: 1 [7936/50000]	Loss: 4.2261	LR: 0.015857
# Training Epoch: 1 [8064/50000]	Loss: 4.2420	LR: 0.016113
# Training Epoch: 1 [8192/50000]	Loss: 4.2799	LR: 0.016368
# Training Epoch: 1 [8320/50000]	Loss: 4.1981	LR: 0.016624
# Training Epoch: 1 [8448/50000]	Loss: 4.2097	LR: 0.016880
# Training Epoch: 1 [8576/50000]	Loss: 4.1463	LR: 0.017136
# Training Epoch: 1 [8704/50000]	Loss: 4.1267	LR: 0.017391
# Training Epoch: 1 [8832/50000]	Loss: 4.2274	LR: 0.017647
# Training Epoch: 1 [8960/50000]	Loss: 4.2137	LR: 0.017903
# Training Epoch: 1 [9088/50000]	Loss: 4.1605	LR: 0.018159
# Training Epoch: 1 [9216/50000]	Loss: 4.1583	LR: 0.018414
# Training Epoch: 1 [9344/50000]	Loss: 4.1491	LR: 0.018670
# Training Epoch: 1 [9472/50000]	Loss: 4.2346	LR: 0.018926
# Training Epoch: 1 [9600/50000]	Loss: 4.1110	LR: 0.019182
# Training Epoch: 1 [9728/50000]	Loss: 4.1188	LR: 0.019437
# Training Epoch: 1 [9856/50000]	Loss: 4.1621	LR: 0.019693
# Training Epoch: 1 [9984/50000]	Loss: 4.0994	LR: 0.019949
# Training Epoch: 1 [10112/50000]	Loss: 4.1931	LR: 0.020205
# Training Epoch: 1 [10240/50000]	Loss: 4.1976	LR: 0.020460
# Training Epoch: 1 [10368/50000]	Loss: 3.9801	LR: 0.020716
# Training Epoch: 1 [10496/50000]	Loss: 4.3022	LR: 0.020972
# Training Epoch: 1 [10624/50000]	Loss: 4.1261	LR: 0.021228
# Training Epoch: 1 [10752/50000]	Loss: 4.1886	LR: 0.021483
# Training Epoch: 1 [10880/50000]	Loss: 4.1280	LR: 0.021739
# Training Epoch: 1 [11008/50000]	Loss: 4.0858	LR: 0.021995
# Training Epoch: 1 [11136/50000]	Loss: 4.0655	LR: 0.022251
# Training Epoch: 1 [11264/50000]	Loss: 4.1956	LR: 0.022506
# Training Epoch: 1 [11392/50000]	Loss: 4.1355	LR: 0.022762
# Training Epoch: 1 [11520/50000]	Loss: 4.2229	LR: 0.023018
# Training Epoch: 1 [11648/50000]	Loss: 4.1571	LR: 0.023274
# Training Epoch: 1 [11776/50000]	Loss: 4.1374	LR: 0.023529
# Training Epoch: 1 [11904/50000]	Loss: 4.1637	LR: 0.023785
# Training Epoch: 1 [12032/50000]	Loss: 4.1048	LR: 0.024041
# Training Epoch: 1 [12160/50000]	Loss: 4.1233	LR: 0.024297
# Training Epoch: 1 [12288/50000]	Loss: 3.9923	LR: 0.024552
# Training Epoch: 1 [12416/50000]	Loss: 4.0317	LR: 0.024808
# Training Epoch: 1 [12544/50000]	Loss: 4.0471	LR: 0.025064
# Training Epoch: 1 [12672/50000]	Loss: 4.0995	LR: 0.025320
# Training Epoch: 1 [12800/50000]	Loss: 4.0192	LR: 0.025575
# Training Epoch: 1 [12928/50000]	Loss: 4.1559	LR: 0.025831
# Training Epoch: 1 [13056/50000]	Loss: 4.2485	LR: 0.026087
# Training Epoch: 1 [13184/50000]	Loss: 3.7907	LR: 0.026343
# Training Epoch: 1 [13312/50000]	Loss: 3.9931	LR: 0.026598
# Training Epoch: 1 [13440/50000]	Loss: 3.9992	LR: 0.026854
# Training Epoch: 1 [13568/50000]	Loss: 3.8904	LR: 0.027110
# Training Epoch: 1 [13696/50000]	Loss: 3.9871	LR: 0.027366
# Training Epoch: 1 [13824/50000]	Loss: 3.9629	LR: 0.027621
# Training Epoch: 1 [13952/50000]	Loss: 4.0125	LR: 0.027877
# Training Epoch: 1 [14080/50000]	Loss: 4.1490	LR: 0.028133
# Training Epoch: 1 [14208/50000]	Loss: 4.1631	LR: 0.028389
# Training Epoch: 1 [14336/50000]	Loss: 4.0784	LR: 0.028645
# Training Epoch: 1 [14464/50000]	Loss: 3.9721	LR: 0.028900
# Training Epoch: 1 [14592/50000]	Loss: 3.9118	LR: 0.029156
# Training Epoch: 1 [14720/50000]	Loss: 3.9864	LR: 0.029412
# Training Epoch: 1 [14848/50000]	Loss: 3.8921	LR: 0.029668
# Training Epoch: 1 [14976/50000]	Loss: 3.9585	LR: 0.029923
# Training Epoch: 1 [15104/50000]	Loss: 3.9202	LR: 0.030179
# Training Epoch: 1 [15232/50000]	Loss: 4.0785	LR: 0.030435
# Training Epoch: 1 [15360/50000]	Loss: 3.9483	LR: 0.030691
# Training Epoch: 1 [15488/50000]	Loss: 3.9404	LR: 0.030946
# Training Epoch: 1 [15616/50000]	Loss: 3.8918	LR: 0.031202
# Training Epoch: 1 [15744/50000]	Loss: 4.0861	LR: 0.031458
# Training Epoch: 1 [15872/50000]	Loss: 3.9199	LR: 0.031714
# Training Epoch: 1 [16000/50000]	Loss: 4.0404	LR: 0.031969
# Training Epoch: 1 [16128/50000]	Loss: 3.8529	LR: 0.032225
# Training Epoch: 1 [16256/50000]	Loss: 3.8805	LR: 0.032481
# Training Epoch: 1 [16384/50000]	Loss: 3.9648	LR: 0.032737
# Training Epoch: 1 [16512/50000]	Loss: 4.0377	LR: 0.032992
# Training Epoch: 1 [16640/50000]	Loss: 3.9529	LR: 0.033248
# Training Epoch: 1 [16768/50000]	Loss: 3.8429	LR: 0.033504
# Training Epoch: 1 [16896/50000]	Loss: 3.8548	LR: 0.033760
# Training Epoch: 1 [17024/50000]	Loss: 3.8364	LR: 0.034015
# Training Epoch: 1 [17152/50000]	Loss: 3.7903	LR: 0.034271
# Training Epoch: 1 [17280/50000]	Loss: 3.9468	LR: 0.034527
# Training Epoch: 1 [17408/50000]	Loss: 3.9843	LR: 0.034783
# Training Epoch: 1 [17536/50000]	Loss: 4.0029	LR: 0.035038
# Training Epoch: 1 [17664/50000]	Loss: 3.8559	LR: 0.035294
# Training Epoch: 1 [17792/50000]	Loss: 4.0090	LR: 0.035550
# Training Epoch: 1 [17920/50000]	Loss: 3.8589	LR: 0.035806
# Training Epoch: 1 [18048/50000]	Loss: 3.8621	LR: 0.036061
# Training Epoch: 1 [18176/50000]	Loss: 3.8942	LR: 0.036317
# Training Epoch: 1 [18304/50000]	Loss: 3.8725	LR: 0.036573
# Training Epoch: 1 [18432/50000]	Loss: 4.0245	LR: 0.036829
# Training Epoch: 1 [18560/50000]	Loss: 4.0843	LR: 0.037084
# Training Epoch: 1 [18688/50000]	Loss: 3.9934	LR: 0.037340
# Training Epoch: 1 [18816/50000]	Loss: 3.9612	LR: 0.037596
# Training Epoch: 1 [18944/50000]	Loss: 3.8148	LR: 0.037852
# Training Epoch: 1 [19072/50000]	Loss: 3.9076	LR: 0.038107
# Training Epoch: 1 [19200/50000]	Loss: 3.9948	LR: 0.038363
# Training Epoch: 1 [19328/50000]	Loss: 3.8151	LR: 0.038619
# Training Epoch: 1 [19456/50000]	Loss: 3.9485	LR: 0.038875
# Training Epoch: 1 [19584/50000]	Loss: 3.8269	LR: 0.039130
# Training Epoch: 1 [19712/50000]	Loss: 3.9449	LR: 0.039386
# Training Epoch: 1 [19840/50000]	Loss: 3.9531	LR: 0.039642
# Training Epoch: 1 [19968/50000]	Loss: 3.8379	LR: 0.039898
# Training Epoch: 1 [20096/50000]	Loss: 3.8584	LR: 0.040153
# Training Epoch: 1 [20224/50000]	Loss: 4.0612	LR: 0.040409
# Training Epoch: 1 [20352/50000]	Loss: 3.6869	LR: 0.040665
# Training Epoch: 1 [20480/50000]	Loss: 3.7893	LR: 0.040921
# Training Epoch: 1 [20608/50000]	Loss: 3.7232	LR: 0.041176
# Training Epoch: 1 [20736/50000]	Loss: 3.8802	LR: 0.041432
# Training Epoch: 1 [20864/50000]	Loss: 3.7566	LR: 0.041688
# Training Epoch: 1 [20992/50000]	Loss: 4.0086	LR: 0.041944
# Training Epoch: 1 [21120/50000]	Loss: 3.9211	LR: 0.042199
# Training Epoch: 1 [21248/50000]	Loss: 3.8620	LR: 0.042455
# Training Epoch: 1 [21376/50000]	Loss: 3.8014	LR: 0.042711
# Training Epoch: 1 [21504/50000]	Loss: 3.7882	LR: 0.042967
# Training Epoch: 1 [21632/50000]	Loss: 3.9489	LR: 0.043223
# Training Epoch: 1 [21760/50000]	Loss: 3.8747	LR: 0.043478
# Training Epoch: 1 [21888/50000]	Loss: 3.8774	LR: 0.043734
# Training Epoch: 1 [22016/50000]	Loss: 3.7477	LR: 0.043990
# Training Epoch: 1 [22144/50000]	Loss: 3.8283	LR: 0.044246
# Training Epoch: 1 [22272/50000]	Loss: 3.9015	LR: 0.044501
# Training Epoch: 1 [22400/50000]	Loss: 3.6718	LR: 0.044757
# Training Epoch: 1 [22528/50000]	Loss: 3.8281	LR: 0.045013
# Training Epoch: 1 [22656/50000]	Loss: 3.8860	LR: 0.045269
# Training Epoch: 1 [22784/50000]	Loss: 4.0292	LR: 0.045524
# Training Epoch: 1 [22912/50000]	Loss: 3.8426	LR: 0.045780
# Training Epoch: 1 [23040/50000]	Loss: 3.6816	LR: 0.046036
# Training Epoch: 1 [23168/50000]	Loss: 3.8003	LR: 0.046292
# Training Epoch: 1 [23296/50000]	Loss: 3.7209	LR: 0.046547
# Training Epoch: 1 [23424/50000]	Loss: 3.7672	LR: 0.046803
# Training Epoch: 1 [23552/50000]	Loss: 3.8911	LR: 0.047059
# Training Epoch: 1 [23680/50000]	Loss: 3.6707	LR: 0.047315
# Training Epoch: 1 [23808/50000]	Loss: 3.6844	LR: 0.047570
# Training Epoch: 1 [23936/50000]	Loss: 3.8395	LR: 0.047826
# Training Epoch: 1 [24064/50000]	Loss: 3.8548	LR: 0.048082
# Training Epoch: 1 [24192/50000]	Loss: 3.6439	LR: 0.048338
# Training Epoch: 1 [24320/50000]	Loss: 3.7992	LR: 0.048593
# Training Epoch: 1 [24448/50000]	Loss: 3.9595	LR: 0.048849
# Training Epoch: 1 [24576/50000]	Loss: 3.8170	LR: 0.049105
# Training Epoch: 1 [24704/50000]	Loss: 3.7771	LR: 0.049361
# Training Epoch: 1 [24832/50000]	Loss: 3.7689	LR: 0.049616
# Training Epoch: 1 [24960/50000]	Loss: 3.6162	LR: 0.049872
# Training Epoch: 1 [25088/50000]	Loss: 3.8134	LR: 0.050128
# Training Epoch: 1 [25216/50000]	Loss: 3.9571	LR: 0.050384
# Training Epoch: 1 [25344/50000]	Loss: 3.8486	LR: 0.050639
# Training Epoch: 1 [25472/50000]	Loss: 3.7664	LR: 0.050895
# Training Epoch: 1 [25600/50000]	Loss: 4.1065	LR: 0.051151
# Training Epoch: 1 [25728/50000]	Loss: 3.9639	LR: 0.051407
# Training Epoch: 1 [25856/50000]	Loss: 4.0228	LR: 0.051662
# Training Epoch: 1 [25984/50000]	Loss: 4.1364	LR: 0.051918
# Training Epoch: 1 [26112/50000]	Loss: 3.7931	LR: 0.052174
# Training Epoch: 1 [26240/50000]	Loss: 3.8309	LR: 0.052430
# Training Epoch: 1 [26368/50000]	Loss: 3.7737	LR: 0.052685
# Training Epoch: 1 [26496/50000]	Loss: 3.7962	LR: 0.052941
# Training Epoch: 1 [26624/50000]	Loss: 3.9748	LR: 0.053197
# Training Epoch: 1 [26752/50000]	Loss: 3.7677	LR: 0.053453
# Training Epoch: 1 [26880/50000]	Loss: 3.7537	LR: 0.053708
# Training Epoch: 1 [27008/50000]	Loss: 3.9801	LR: 0.053964
# Training Epoch: 1 [27136/50000]	Loss: 3.6921	LR: 0.054220
# Training Epoch: 1 [27264/50000]	Loss: 3.7142	LR: 0.054476
# Training Epoch: 1 [27392/50000]	Loss: 3.6872	LR: 0.054731
# Training Epoch: 1 [27520/50000]	Loss: 3.7834	LR: 0.054987
# Training Epoch: 1 [27648/50000]	Loss: 3.7168	LR: 0.055243
# Training Epoch: 1 [27776/50000]	Loss: 3.8324	LR: 0.055499
# Training Epoch: 1 [27904/50000]	Loss: 3.8366	LR: 0.055754
# Training Epoch: 1 [28032/50000]	Loss: 3.6837	LR: 0.056010
# Training Epoch: 1 [28160/50000]	Loss: 3.6788	LR: 0.056266
# Training Epoch: 1 [28288/50000]	Loss: 3.5579	LR: 0.056522
# Training Epoch: 1 [28416/50000]	Loss: 3.7390	LR: 0.056777
# Training Epoch: 1 [28544/50000]	Loss: 3.9571	LR: 0.057033
# Training Epoch: 1 [28672/50000]	Loss: 3.8232	LR: 0.057289
# Training Epoch: 1 [28800/50000]	Loss: 3.8004	LR: 0.057545
# Training Epoch: 1 [28928/50000]	Loss: 3.7530	LR: 0.057801
# Training Epoch: 1 [29056/50000]	Loss: 3.8685	LR: 0.058056
# Training Epoch: 1 [29184/50000]	Loss: 3.7937	LR: 0.058312
# Training Epoch: 1 [29312/50000]	Loss: 3.7911	LR: 0.058568
# Training Epoch: 1 [29440/50000]	Loss: 3.7577	LR: 0.058824
# Training Epoch: 1 [29568/50000]	Loss: 3.6127	LR: 0.059079
# Training Epoch: 1 [29696/50000]	Loss: 3.7255	LR: 0.059335
# Training Epoch: 1 [29824/50000]	Loss: 3.6870	LR: 0.059591
# Training Epoch: 1 [29952/50000]	Loss: 3.8676	LR: 0.059847
# Training Epoch: 1 [30080/50000]	Loss: 3.7166	LR: 0.060102
# Training Epoch: 1 [30208/50000]	Loss: 3.6786	LR: 0.060358
# Training Epoch: 1 [30336/50000]	Loss: 3.8525	LR: 0.060614
# Training Epoch: 1 [30464/50000]	Loss: 3.7544	LR: 0.060870
# Training Epoch: 1 [30592/50000]	Loss: 3.8792	LR: 0.061125
# Training Epoch: 1 [30720/50000]	Loss: 3.8431	LR: 0.061381
# Training Epoch: 1 [30848/50000]	Loss: 3.7635	LR: 0.061637
# Training Epoch: 1 [30976/50000]	Loss: 3.6596	LR: 0.061893
# Training Epoch: 1 [31104/50000]	Loss: 3.7776	LR: 0.062148
# Training Epoch: 1 [31232/50000]	Loss: 3.4597	LR: 0.062404
# Training Epoch: 1 [31360/50000]	Loss: 3.7839	LR: 0.062660
# Training Epoch: 1 [31488/50000]	Loss: 3.8048	LR: 0.062916
# Training Epoch: 1 [31616/50000]	Loss: 3.6912	LR: 0.063171
# Training Epoch: 1 [31744/50000]	Loss: 3.7546	LR: 0.063427
# Training Epoch: 1 [31872/50000]	Loss: 3.8282	LR: 0.063683
# Training Epoch: 1 [32000/50000]	Loss: 3.7469	LR: 0.063939
# Training Epoch: 1 [32128/50000]	Loss: 3.8072	LR: 0.064194
# Training Epoch: 1 [32256/50000]	Loss: 3.6585	LR: 0.064450
# Training Epoch: 1 [32384/50000]	Loss: 3.6655	LR: 0.064706
# Training Epoch: 1 [32512/50000]	Loss: 3.8900	LR: 0.064962
# Training Epoch: 1 [32640/50000]	Loss: 3.7613	LR: 0.065217
# Training Epoch: 1 [32768/50000]	Loss: 3.7120	LR: 0.065473
# Training Epoch: 1 [32896/50000]	Loss: 3.7550	LR: 0.065729
# Training Epoch: 1 [33024/50000]	Loss: 3.7438	LR: 0.065985
# Training Epoch: 1 [33152/50000]	Loss: 3.8784	LR: 0.066240
# Training Epoch: 1 [33280/50000]	Loss: 3.8509	LR: 0.066496
# Training Epoch: 1 [33408/50000]	Loss: 3.8151	LR: 0.066752
# Training Epoch: 1 [33536/50000]	Loss: 3.8175	LR: 0.067008
# Training Epoch: 1 [33664/50000]	Loss: 3.8992	LR: 0.067263
# Training Epoch: 1 [33792/50000]	Loss: 3.7458	LR: 0.067519
# Training Epoch: 1 [33920/50000]	Loss: 3.5457	LR: 0.067775
# Training Epoch: 1 [34048/50000]	Loss: 3.7304	LR: 0.068031
# Training Epoch: 1 [34176/50000]	Loss: 3.7496	LR: 0.068286
# Training Epoch: 1 [34304/50000]	Loss: 3.7529	LR: 0.068542
# Training Epoch: 1 [34432/50000]	Loss: 3.6254	LR: 0.068798
# Training Epoch: 1 [34560/50000]	Loss: 3.6914	LR: 0.069054
# Training Epoch: 1 [34688/50000]	Loss: 3.5598	LR: 0.069309
# Training Epoch: 1 [34816/50000]	Loss: 3.7288	LR: 0.069565
# Training Epoch: 1 [34944/50000]	Loss: 3.8147	LR: 0.069821
# Training Epoch: 1 [35072/50000]	Loss: 3.8171	LR: 0.070077
# Training Epoch: 1 [35200/50000]	Loss: 3.6264	LR: 0.070332
# Training Epoch: 1 [35328/50000]	Loss: 3.9858	LR: 0.070588
# Training Epoch: 1 [35456/50000]	Loss: 3.7918	LR: 0.070844
# Training Epoch: 1 [35584/50000]	Loss: 3.6804	LR: 0.071100
# Training Epoch: 1 [35712/50000]	Loss: 3.7825	LR: 0.071355
# Training Epoch: 1 [35840/50000]	Loss: 3.5353	LR: 0.071611
# Training Epoch: 1 [35968/50000]	Loss: 3.7673	LR: 0.071867
# Training Epoch: 1 [36096/50000]	Loss: 3.6662	LR: 0.072123
# Training Epoch: 1 [36224/50000]	Loss: 3.5828	LR: 0.072379
# Training Epoch: 1 [36352/50000]	Loss: 3.5660	LR: 0.072634
# Training Epoch: 1 [36480/50000]	Loss: 3.6322	LR: 0.072890
# Training Epoch: 1 [36608/50000]	Loss: 3.6093	LR: 0.073146
# Training Epoch: 1 [36736/50000]	Loss: 3.7183	LR: 0.073402
# Training Epoch: 1 [36864/50000]	Loss: 3.9557	LR: 0.073657
# Training Epoch: 1 [36992/50000]	Loss: 3.8356	LR: 0.073913
# Training Epoch: 1 [37120/50000]	Loss: 3.7029	LR: 0.074169
# Training Epoch: 1 [37248/50000]	Loss: 3.7527	LR: 0.074425
# Training Epoch: 1 [37376/50000]	Loss: 3.5980	LR: 0.074680
# Training Epoch: 1 [37504/50000]	Loss: 3.6676	LR: 0.074936
# Training Epoch: 1 [37632/50000]	Loss: 3.7234	LR: 0.075192
# Training Epoch: 1 [37760/50000]	Loss: 3.6600	LR: 0.075448
# Training Epoch: 1 [37888/50000]	Loss: 3.7088	LR: 0.075703
# Training Epoch: 1 [38016/50000]	Loss: 3.6290	LR: 0.075959
# Training Epoch: 1 [38144/50000]	Loss: 3.4513	LR: 0.076215
# Training Epoch: 1 [38272/50000]	Loss: 3.7934	LR: 0.076471
# Training Epoch: 1 [38400/50000]	Loss: 3.8292	LR: 0.076726
# Training Epoch: 1 [38528/50000]	Loss: 3.6971	LR: 0.076982
# Training Epoch: 1 [38656/50000]	Loss: 3.5980	LR: 0.077238
# Training Epoch: 1 [38784/50000]	Loss: 3.7738	LR: 0.077494
# Training Epoch: 1 [38912/50000]	Loss: 3.6190	LR: 0.077749
# Training Epoch: 1 [39040/50000]	Loss: 3.4794	LR: 0.078005
# Training Epoch: 1 [39168/50000]	Loss: 3.7486	LR: 0.078261
# Training Epoch: 1 [39296/50000]	Loss: 3.6866	LR: 0.078517
# Training Epoch: 1 [39424/50000]	Loss: 3.5287	LR: 0.078772
# Training Epoch: 1 [39552/50000]	Loss: 3.6370	LR: 0.079028
# Training Epoch: 1 [39680/50000]	Loss: 3.9288	LR: 0.079284
# Training Epoch: 1 [39808/50000]	Loss: 3.9294	LR: 0.079540
# Training Epoch: 1 [39936/50000]	Loss: 3.6346	LR: 0.079795
# Training Epoch: 1 [40064/50000]	Loss: 3.7591	LR: 0.080051
# Training Epoch: 1 [40192/50000]	Loss: 3.7150	LR: 0.080307
# Training Epoch: 1 [40320/50000]	Loss: 3.5667	LR: 0.080563
# Training Epoch: 1 [40448/50000]	Loss: 3.5274	LR: 0.080818
# Training Epoch: 1 [40576/50000]	Loss: 3.6301	LR: 0.081074
# Training Epoch: 1 [40704/50000]	Loss: 3.5854	LR: 0.081330
# Training Epoch: 1 [40832/50000]	Loss: 3.6668	LR: 0.081586
# Training Epoch: 1 [40960/50000]	Loss: 3.7217	LR: 0.081841
# Training Epoch: 1 [41088/50000]	Loss: 3.7325	LR: 0.082097
# Training Epoch: 1 [41216/50000]	Loss: 3.7417	LR: 0.082353
# Training Epoch: 1 [41344/50000]	Loss: 3.9163	LR: 0.082609
# Training Epoch: 1 [41472/50000]	Loss: 3.7841	LR: 0.082864
# Training Epoch: 1 [41600/50000]	Loss: 3.5577	LR: 0.083120
# Training Epoch: 1 [41728/50000]	Loss: 3.7982	LR: 0.083376
# Training Epoch: 1 [41856/50000]	Loss: 3.7088	LR: 0.083632
# Training Epoch: 1 [41984/50000]	Loss: 3.5481	LR: 0.083887
# Training Epoch: 1 [42112/50000]	Loss: 3.4591	LR: 0.084143
# Training Epoch: 1 [42240/50000]	Loss: 3.6536	LR: 0.084399
# Training Epoch: 1 [42368/50000]	Loss: 3.6974	LR: 0.084655
# Training Epoch: 1 [42496/50000]	Loss: 3.7048	LR: 0.084910
# Training Epoch: 1 [42624/50000]	Loss: 3.5638	LR: 0.085166
# Training Epoch: 1 [42752/50000]	Loss: 3.3764	LR: 0.085422
# Training Epoch: 1 [42880/50000]	Loss: 3.6017	LR: 0.085678
# Training Epoch: 1 [43008/50000]	Loss: 3.6609	LR: 0.085934
# Training Epoch: 1 [43136/50000]	Loss: 3.8098	LR: 0.086189
# Training Epoch: 1 [43264/50000]	Loss: 3.6670	LR: 0.086445
# Training Epoch: 1 [43392/50000]	Loss: 3.7231	LR: 0.086701
# Training Epoch: 1 [43520/50000]	Loss: 3.5168	LR: 0.086957
# Training Epoch: 1 [43648/50000]	Loss: 3.6239	LR: 0.087212
# Training Epoch: 1 [43776/50000]	Loss: 3.7642	LR: 0.087468
# Training Epoch: 1 [43904/50000]	Loss: 3.3881	LR: 0.087724
# Training Epoch: 1 [44032/50000]	Loss: 3.6365	LR: 0.087980
# Training Epoch: 1 [44160/50000]	Loss: 3.5626	LR: 0.088235
# Training Epoch: 1 [44288/50000]	Loss: 3.7306	LR: 0.088491
# Training Epoch: 1 [44416/50000]	Loss: 3.6060	LR: 0.088747
# Training Epoch: 1 [44544/50000]	Loss: 3.7726	LR: 0.089003
# Training Epoch: 1 [44672/50000]	Loss: 3.3807	LR: 0.089258
# Training Epoch: 1 [44800/50000]	Loss: 3.6395	LR: 0.089514
# Training Epoch: 1 [44928/50000]	Loss: 3.5314	LR: 0.089770
# Training Epoch: 1 [45056/50000]	Loss: 3.4179	LR: 0.090026
# Training Epoch: 1 [45184/50000]	Loss: 3.5046	LR: 0.090281
# Training Epoch: 1 [45312/50000]	Loss: 3.5504	LR: 0.090537
# Training Epoch: 1 [45440/50000]	Loss: 3.5314	LR: 0.090793
# Training Epoch: 1 [45568/50000]	Loss: 3.4245	LR: 0.091049
# Training Epoch: 1 [45696/50000]	Loss: 3.7760	LR: 0.091304
# Training Epoch: 1 [45824/50000]	Loss: 3.6492	LR: 0.091560
# Training Epoch: 1 [45952/50000]	Loss: 3.6154	LR: 0.091816
# Training Epoch: 1 [46080/50000]	Loss: 3.4581	LR: 0.092072
# Training Epoch: 1 [46208/50000]	Loss: 3.7265	LR: 0.092327
# Training Epoch: 1 [46336/50000]	Loss: 3.3368	LR: 0.092583
# Training Epoch: 1 [46464/50000]	Loss: 3.3146	LR: 0.092839
# Training Epoch: 1 [46592/50000]	Loss: 3.7879	LR: 0.093095
# Training Epoch: 1 [46720/50000]	Loss: 3.5057	LR: 0.093350
# Training Epoch: 1 [46848/50000]	Loss: 3.4532	LR: 0.093606
# Training Epoch: 1 [46976/50000]	Loss: 3.3547	LR: 0.093862
# Training Epoch: 1 [47104/50000]	Loss: 3.4400	LR: 0.094118
# Training Epoch: 1 [47232/50000]	Loss: 3.5357	LR: 0.094373
# Training Epoch: 1 [47360/50000]	Loss: 3.6399	LR: 0.094629
# Training Epoch: 1 [47488/50000]	Loss: 3.4902	LR: 0.094885
# Training Epoch: 1 [47616/50000]	Loss: 3.6130	LR: 0.095141
# Training Epoch: 1 [47744/50000]	Loss: 3.5975	LR: 0.095396
# Training Epoch: 1 [47872/50000]	Loss: 3.8459	LR: 0.095652
# Training Epoch: 1 [48000/50000]	Loss: 3.6711	LR: 0.095908
# Training Epoch: 1 [48128/50000]	Loss: 3.5434	LR: 0.096164
# Training Epoch: 1 [48256/50000]	Loss: 3.6941	LR: 0.096419
# Training Epoch: 1 [48384/50000]	Loss: 3.5428	LR: 0.096675
# Training Epoch: 1 [48512/50000]	Loss: 3.5307	LR: 0.096931
# Training Epoch: 1 [48640/50000]	Loss: 3.5406	LR: 0.097187
# Training Epoch: 1 [48768/50000]	Loss: 3.4451	LR: 0.097442
# Training Epoch: 1 [48896/50000]	Loss: 3.4862	LR: 0.097698
# Training Epoch: 1 [49024/50000]	Loss: 3.7249	LR: 0.097954
# Training Epoch: 1 [49152/50000]	Loss: 3.5979	LR: 0.098210
# Training Epoch: 1 [49280/50000]	Loss: 3.6634	LR: 0.098465
# Training Epoch: 1 [49408/50000]	Loss: 3.4853	LR: 0.098721
# Training Epoch: 1 [49536/50000]	Loss: 3.3569	LR: 0.098977
# Training Epoch: 1 [49664/50000]	Loss: 3.4297	LR: 0.099233
# Training Epoch: 1 [49792/50000]	Loss: 3.5583	LR: 0.099488
# Training Epoch: 1 [49920/50000]	Loss: 3.4809	LR: 0.099744
# Training Epoch: 1 [50000/50000]	Loss: 3.5167	LR: 0.100000
# Test set: Average loss: 0.0283, Accuracy: 0.1539
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Training Epoch: 2 [128/50000]	Loss: 3.5765	LR: 0.100000
# Training Epoch: 2 [256/50000]	Loss: 3.5915	LR: 0.100000
# Training Epoch: 2 [384/50000]	Loss: 3.4508	LR: 0.100000
# Training Epoch: 2 [512/50000]	Loss: 3.6061	LR: 0.100000
# Training Epoch: 2 [640/50000]	Loss: 3.3129	LR: 0.100000
# Training Epoch: 2 [768/50000]	Loss: 3.4682	LR: 0.100000
# Training Epoch: 2 [896/50000]	Loss: 3.3650	LR: 0.100000
# Training Epoch: 2 [1024/50000]	Loss: 3.4019	LR: 0.100000
# Training Epoch: 2 [1152/50000]	Loss: 3.2115	LR: 0.100000
# Training Epoch: 2 [1280/50000]	Loss: 3.7266	LR: 0.100000
# Training Epoch: 2 [1408/50000]	Loss: 3.4627	LR: 0.100000
# Training Epoch: 2 [1536/50000]	Loss: 3.5186	LR: 0.100000
# Training Epoch: 2 [1664/50000]	Loss: 3.5937	LR: 0.100000
# Training Epoch: 2 [1792/50000]	Loss: 3.5174	LR: 0.100000
# Training Epoch: 2 [1920/50000]	Loss: 3.4119	LR: 0.100000
# Training Epoch: 2 [2048/50000]	Loss: 3.4305	LR: 0.100000
# Training Epoch: 2 [2176/50000]	Loss: 3.4926	LR: 0.100000
# Training Epoch: 2 [2304/50000]	Loss: 3.4980	LR: 0.100000
# Training Epoch: 2 [2432/50000]	Loss: 3.2341	LR: 0.100000
# Training Epoch: 2 [2560/50000]	Loss: 3.6349	LR: 0.100000
# Training Epoch: 2 [2688/50000]	Loss: 3.3660	LR: 0.100000
# Training Epoch: 2 [2816/50000]	Loss: 3.3357	LR: 0.100000
# Training Epoch: 2 [2944/50000]	Loss: 3.5673	LR: 0.100000
# Training Epoch: 2 [3072/50000]	Loss: 3.5230	LR: 0.100000
# Training Epoch: 2 [3200/50000]	Loss: 3.6280	LR: 0.100000
# Training Epoch: 2 [3328/50000]	Loss: 3.4704	LR: 0.100000
# Training Epoch: 2 [3456/50000]	Loss: 3.4918	LR: 0.100000
# Training Epoch: 2 [3584/50000]	Loss: 3.2351	LR: 0.100000
# Training Epoch: 2 [3712/50000]	Loss: 3.5515	LR: 0.100000
# Training Epoch: 2 [3840/50000]	Loss: 3.4772	LR: 0.100000
# Training Epoch: 2 [3968/50000]	Loss: 3.5209	LR: 0.100000
# Training Epoch: 2 [4096/50000]	Loss: 3.3133	LR: 0.100000
# Training Epoch: 2 [4224/50000]	Loss: 3.6272	LR: 0.100000
# Training Epoch: 2 [4352/50000]	Loss: 3.4879	LR: 0.100000
# Training Epoch: 2 [4480/50000]	Loss: 3.3093	LR: 0.100000
# Training Epoch: 2 [4608/50000]	Loss: 3.2723	LR: 0.100000
# Training Epoch: 2 [4736/50000]	Loss: 3.4114	LR: 0.100000
# Training Epoch: 2 [4864/50000]	Loss: 3.3935	LR: 0.100000
# Training Epoch: 2 [4992/50000]	Loss: 3.3737	LR: 0.100000
# Training Epoch: 2 [5120/50000]	Loss: 3.4547	LR: 0.100000
# Training Epoch: 2 [5248/50000]	Loss: 3.2917	LR: 0.100000
# Training Epoch: 2 [5376/50000]	Loss: 3.2650	LR: 0.100000
# Training Epoch: 2 [5504/50000]	Loss: 3.2721	LR: 0.100000
# Training Epoch: 2 [5632/50000]	Loss: 3.7201	LR: 0.100000
# Training Epoch: 2 [5760/50000]	Loss: 3.4977	LR: 0.100000
# Training Epoch: 2 [5888/50000]	Loss: 3.3742	LR: 0.100000
# Training Epoch: 2 [6016/50000]	Loss: 3.2944	LR: 0.100000
# Training Epoch: 2 [6144/50000]	Loss: 3.4005	LR: 0.100000
# Training Epoch: 2 [6272/50000]	Loss: 3.4300	LR: 0.100000
# Training Epoch: 2 [6400/50000]	Loss: 3.3361	LR: 0.100000
# Training Epoch: 2 [6528/50000]	Loss: 3.1872	LR: 0.100000
# Training Epoch: 2 [6656/50000]	Loss: 3.3790	LR: 0.100000
# Training Epoch: 2 [6784/50000]	Loss: 3.2547	LR: 0.100000
# Training Epoch: 2 [6912/50000]	Loss: 3.3219	LR: 0.100000
# Training Epoch: 2 [7040/50000]	Loss: 3.2747	LR: 0.100000
# Training Epoch: 2 [7168/50000]	Loss: 3.6084	LR: 0.100000
# Training Epoch: 2 [7296/50000]	Loss: 3.3250	LR: 0.100000
# Training Epoch: 2 [7424/50000]	Loss: 3.4416	LR: 0.100000
# Training Epoch: 2 [7552/50000]	Loss: 3.1118	LR: 0.100000
# Training Epoch: 2 [7680/50000]	Loss: 3.4816	LR: 0.100000
# Training Epoch: 2 [7808/50000]	Loss: 3.4773	LR: 0.100000
# Training Epoch: 2 [7936/50000]	Loss: 3.2496	LR: 0.100000
# Training Epoch: 2 [8064/50000]	Loss: 3.4269	LR: 0.100000
# Training Epoch: 2 [8192/50000]	Loss: 3.2839	LR: 0.100000
# Training Epoch: 2 [8320/50000]	Loss: 3.2499	LR: 0.100000
# Training Epoch: 2 [8448/50000]	Loss: 3.3261	LR: 0.100000
# Training Epoch: 2 [8576/50000]	Loss: 3.3131	LR: 0.100000
# Training Epoch: 2 [8704/50000]	Loss: 3.7673	LR: 0.100000
# Training Epoch: 2 [8832/50000]	Loss: 3.3229	LR: 0.100000
# Training Epoch: 2 [8960/50000]	Loss: 3.3342	LR: 0.100000
# Training Epoch: 2 [9088/50000]	Loss: 3.2218	LR: 0.100000
# Training Epoch: 2 [9216/50000]	Loss: 3.4008	LR: 0.100000
# Training Epoch: 2 [9344/50000]	Loss: 3.2535	LR: 0.100000
# Training Epoch: 2 [9472/50000]	Loss: 3.0988	LR: 0.100000
# Training Epoch: 2 [9600/50000]	Loss: 3.0334	LR: 0.100000
# Training Epoch: 2 [9728/50000]	Loss: 3.1361	LR: 0.100000
# Training Epoch: 2 [9856/50000]	Loss: 3.2502	LR: 0.100000
# Training Epoch: 2 [9984/50000]	Loss: 3.2972	LR: 0.100000
# Training Epoch: 2 [10112/50000]	Loss: 3.3541	LR: 0.100000
# Training Epoch: 2 [10240/50000]	Loss: 3.4812	LR: 0.100000
# Training Epoch: 2 [10368/50000]	Loss: 3.3487	LR: 0.100000
# Training Epoch: 2 [10496/50000]	Loss: 3.3529	LR: 0.100000
# Training Epoch: 2 [10624/50000]	Loss: 3.1886	LR: 0.100000
# Training Epoch: 2 [10752/50000]	Loss: 3.5030	LR: 0.100000
# Training Epoch: 2 [10880/50000]	Loss: 3.4168	LR: 0.100000
# Training Epoch: 2 [11008/50000]	Loss: 3.1902	LR: 0.100000
# Training Epoch: 2 [11136/50000]	Loss: 3.1657	LR: 0.100000
# Training Epoch: 2 [11264/50000]	Loss: 3.3752	LR: 0.100000
# Training Epoch: 2 [11392/50000]	Loss: 3.0544	LR: 0.100000
# Training Epoch: 2 [11520/50000]	Loss: 3.1152	LR: 0.100000
# Training Epoch: 2 [11648/50000]	Loss: 3.2516	LR: 0.100000
# Training Epoch: 2 [11776/50000]	Loss: 3.4259	LR: 0.100000
# Training Epoch: 2 [11904/50000]	Loss: 3.2297	LR: 0.100000
# Training Epoch: 2 [12032/50000]	Loss: 3.1588	LR: 0.100000
# Training Epoch: 2 [12160/50000]	Loss: 3.3925	LR: 0.100000
# Training Epoch: 2 [12288/50000]	Loss: 3.2620	LR: 0.100000
# Training Epoch: 2 [12416/50000]	Loss: 3.1192	LR: 0.100000
# Training Epoch: 2 [12544/50000]	Loss: 3.1424	LR: 0.100000
# Training Epoch: 2 [12672/50000]	Loss: 3.2394	LR: 0.100000
# Training Epoch: 2 [12800/50000]	Loss: 3.2507	LR: 0.100000
# Training Epoch: 2 [12928/50000]	Loss: 3.3724	LR: 0.100000
# Training Epoch: 2 [13056/50000]	Loss: 3.6103	LR: 0.100000
# Training Epoch: 2 [13184/50000]	Loss: 3.5478	LR: 0.100000
# Training Epoch: 2 [13312/50000]	Loss: 3.2046	LR: 0.100000
# Training Epoch: 2 [13440/50000]	Loss: 3.0879	LR: 0.100000
# Training Epoch: 2 [13568/50000]	Loss: 3.3192	LR: 0.100000
# Training Epoch: 2 [13696/50000]	Loss: 3.1603	LR: 0.100000
# Training Epoch: 2 [13824/50000]	Loss: 3.3326	LR: 0.100000
# Training Epoch: 2 [13952/50000]	Loss: 3.2492	LR: 0.100000
# Training Epoch: 2 [14080/50000]	Loss: 3.2861	LR: 0.100000
# Training Epoch: 2 [14208/50000]	Loss: 3.7038	LR: 0.100000
# Training Epoch: 2 [14336/50000]	Loss: 3.3060	LR: 0.100000
# Training Epoch: 2 [14464/50000]	Loss: 3.1049	LR: 0.100000
# Training Epoch: 2 [14592/50000]	Loss: 3.4034	LR: 0.100000
# Training Epoch: 2 [14720/50000]	Loss: 3.3331	LR: 0.100000
# Training Epoch: 2 [14848/50000]	Loss: 3.2772	LR: 0.100000
# Training Epoch: 2 [14976/50000]	Loss: 3.2408	LR: 0.100000
# Training Epoch: 2 [15104/50000]	Loss: 3.2212	LR: 0.100000
# Training Epoch: 2 [15232/50000]	Loss: 3.2801	LR: 0.100000
# Training Epoch: 2 [15360/50000]	Loss: 3.1930	LR: 0.100000
# Training Epoch: 2 [15488/50000]	Loss: 3.2246	LR: 0.100000
# Training Epoch: 2 [15616/50000]	Loss: 3.2033	LR: 0.100000
# Training Epoch: 2 [15744/50000]	Loss: 3.3427	LR: 0.100000
# Training Epoch: 2 [15872/50000]	Loss: 3.0486	LR: 0.100000
# Training Epoch: 2 [16000/50000]	Loss: 3.1516	LR: 0.100000
# Training Epoch: 2 [16128/50000]	Loss: 3.2338	LR: 0.100000
# Training Epoch: 2 [16256/50000]	Loss: 3.2992	LR: 0.100000
# Training Epoch: 2 [16384/50000]	Loss: 3.1327	LR: 0.100000
# Training Epoch: 2 [16512/50000]	Loss: 3.2029	LR: 0.100000
# Training Epoch: 2 [16640/50000]	Loss: 3.2428	LR: 0.100000
# Training Epoch: 2 [16768/50000]	Loss: 3.2754	LR: 0.100000
# Training Epoch: 2 [16896/50000]	Loss: 3.2994	LR: 0.100000
# Training Epoch: 2 [17024/50000]	Loss: 3.4333	LR: 0.100000
# Training Epoch: 2 [17152/50000]	Loss: 3.1793	LR: 0.100000
# Training Epoch: 2 [17280/50000]	Loss: 2.9000	LR: 0.100000
# Training Epoch: 2 [17408/50000]	Loss: 3.1870	LR: 0.100000
# Training Epoch: 2 [17536/50000]	Loss: 3.3949	LR: 0.100000
# Training Epoch: 2 [17664/50000]	Loss: 3.2717	LR: 0.100000
# Training Epoch: 2 [17792/50000]	Loss: 3.3686	LR: 0.100000
# Training Epoch: 2 [17920/50000]	Loss: 3.1152	LR: 0.100000
# Training Epoch: 2 [18048/50000]	Loss: 3.4011	LR: 0.100000
# Training Epoch: 2 [18176/50000]	Loss: 3.4232	LR: 0.100000
# Training Epoch: 2 [18304/50000]	Loss: 3.1989	LR: 0.100000
# Training Epoch: 2 [18432/50000]	Loss: 3.2169	LR: 0.100000
# Training Epoch: 2 [18560/50000]	Loss: 3.4247	LR: 0.100000
# Training Epoch: 2 [18688/50000]	Loss: 3.4657	LR: 0.100000
# Training Epoch: 2 [18816/50000]	Loss: 3.3693	LR: 0.100000
# Training Epoch: 2 [18944/50000]	Loss: 3.4360	LR: 0.100000
# Training Epoch: 2 [19072/50000]	Loss: 3.2343	LR: 0.100000
# Training Epoch: 2 [19200/50000]	Loss: 3.1412	LR: 0.100000
# Training Epoch: 2 [19328/50000]	Loss: 3.3634	LR: 0.100000
# Training Epoch: 2 [19456/50000]	Loss: 3.2096	LR: 0.100000
# Training Epoch: 2 [19584/50000]	Loss: 3.2553	LR: 0.100000
# Training Epoch: 2 [19712/50000]	Loss: 3.2957	LR: 0.100000
# Training Epoch: 2 [19840/50000]	Loss: 3.1521	LR: 0.100000
# Training Epoch: 2 [19968/50000]	Loss: 3.2445	LR: 0.100000
# Training Epoch: 2 [20096/50000]	Loss: 3.1447	LR: 0.100000
# Training Epoch: 2 [20224/50000]	Loss: 3.3856	LR: 0.100000
# Training Epoch: 2 [20352/50000]	Loss: 3.3611	LR: 0.100000
# Training Epoch: 2 [20480/50000]	Loss: 3.3009	LR: 0.100000
# Training Epoch: 2 [20608/50000]	Loss: 3.1872	LR: 0.100000
# Training Epoch: 2 [20736/50000]	Loss: 3.3781	LR: 0.100000
# Training Epoch: 2 [20864/50000]	Loss: 3.0697	LR: 0.100000
# Training Epoch: 2 [20992/50000]	Loss: 3.0200	LR: 0.100000
# Training Epoch: 2 [21120/50000]	Loss: 3.1500	LR: 0.100000
# Training Epoch: 2 [21248/50000]	Loss: 3.3521	LR: 0.100000
# Training Epoch: 2 [21376/50000]	Loss: 3.4268	LR: 0.100000
# Training Epoch: 2 [21504/50000]	Loss: 3.1066	LR: 0.100000
# Training Epoch: 2 [21632/50000]	Loss: 3.1871	LR: 0.100000
# Training Epoch: 2 [21760/50000]	Loss: 3.4206	LR: 0.100000
# Training Epoch: 2 [21888/50000]	Loss: 3.0694	LR: 0.100000
# Training Epoch: 2 [22016/50000]	Loss: 3.2597	LR: 0.100000
# Training Epoch: 2 [22144/50000]	Loss: 3.0428	LR: 0.100000
# Training Epoch: 2 [22272/50000]	Loss: 3.0698	LR: 0.100000
# Training Epoch: 2 [22400/50000]	Loss: 3.0543	LR: 0.100000
# Training Epoch: 2 [22528/50000]	Loss: 3.0640	LR: 0.100000
# Training Epoch: 2 [22656/50000]	Loss: 3.3914	LR: 0.100000
# Training Epoch: 2 [22784/50000]	Loss: 3.4640	LR: 0.100000
# Training Epoch: 2 [22912/50000]	Loss: 3.1657	LR: 0.100000
# Training Epoch: 2 [23040/50000]	Loss: 3.0708	LR: 0.100000
# Training Epoch: 2 [23168/50000]	Loss: 3.2699	LR: 0.100000
# Training Epoch: 2 [23296/50000]	Loss: 3.2897	LR: 0.100000
# Training Epoch: 2 [23424/50000]	Loss: 3.3543	LR: 0.100000
# Training Epoch: 2 [23552/50000]	Loss: 3.2260	LR: 0.100000
# Training Epoch: 2 [23680/50000]	Loss: 3.3826	LR: 0.100000
# Training Epoch: 2 [23808/50000]	Loss: 3.1392	LR: 0.100000
# Training Epoch: 2 [23936/50000]	Loss: 3.0658	LR: 0.100000
# Training Epoch: 2 [24064/50000]	Loss: 3.0220	LR: 0.100000
# Training Epoch: 2 [24192/50000]	Loss: 3.3463	LR: 0.100000
# Training Epoch: 2 [24320/50000]	Loss: 3.3263	LR: 0.100000
# Training Epoch: 2 [24448/50000]	Loss: 3.1836	LR: 0.100000
# Training Epoch: 2 [24576/50000]	Loss: 3.1620	LR: 0.100000
# Training Epoch: 2 [24704/50000]	Loss: 3.1430	LR: 0.100000
# Training Epoch: 2 [24832/50000]	Loss: 3.4641	LR: 0.100000
# Training Epoch: 2 [24960/50000]	Loss: 3.0147	LR: 0.100000
# Training Epoch: 2 [25088/50000]	Loss: 3.0541	LR: 0.100000
# Training Epoch: 2 [25216/50000]	Loss: 3.0784	LR: 0.100000
# Training Epoch: 2 [25344/50000]	Loss: 2.9511	LR: 0.100000
# Training Epoch: 2 [25472/50000]	Loss: 3.1270	LR: 0.100000
# Training Epoch: 2 [25600/50000]	Loss: 3.2308	LR: 0.100000
# Training Epoch: 2 [25728/50000]	Loss: 3.0732	LR: 0.100000
# Training Epoch: 2 [25856/50000]	Loss: 3.0385	LR: 0.100000
# Training Epoch: 2 [25984/50000]	Loss: 3.2621	LR: 0.100000
# Training Epoch: 2 [26112/50000]	Loss: 3.2028	LR: 0.100000
# Training Epoch: 2 [26240/50000]	Loss: 3.3373	LR: 0.100000
# Training Epoch: 2 [26368/50000]	Loss: 3.1484	LR: 0.100000
# Training Epoch: 2 [26496/50000]	Loss: 3.3031	LR: 0.100000
# Training Epoch: 2 [26624/50000]	Loss: 3.0874	LR: 0.100000
# Training Epoch: 2 [26752/50000]	Loss: 3.1891	LR: 0.100000
# Training Epoch: 2 [26880/50000]	Loss: 3.3247	LR: 0.100000
# Training Epoch: 2 [27008/50000]	Loss: 3.1921	LR: 0.100000
# Training Epoch: 2 [27136/50000]	Loss: 3.0828	LR: 0.100000
# Training Epoch: 2 [27264/50000]	Loss: 3.0753	LR: 0.100000
# Training Epoch: 2 [27392/50000]	Loss: 3.1794	LR: 0.100000
# Training Epoch: 2 [27520/50000]	Loss: 3.4109	LR: 0.100000
# Training Epoch: 2 [27648/50000]	Loss: 3.1461	LR: 0.100000
# Training Epoch: 2 [27776/50000]	Loss: 2.9616	LR: 0.100000
# Training Epoch: 2 [27904/50000]	Loss: 3.1077	LR: 0.100000
# Training Epoch: 2 [28032/50000]	Loss: 3.0548	LR: 0.100000
# Training Epoch: 2 [28160/50000]	Loss: 3.1627	LR: 0.100000
# Training Epoch: 2 [28288/50000]	Loss: 3.1179	LR: 0.100000
# Training Epoch: 2 [28416/50000]	Loss: 3.0863	LR: 0.100000
# Training Epoch: 2 [28544/50000]	Loss: 3.0906	LR: 0.100000
# Training Epoch: 2 [28672/50000]	Loss: 3.0531	LR: 0.100000
# Training Epoch: 2 [28800/50000]	Loss: 3.1032	LR: 0.100000
# Training Epoch: 2 [28928/50000]	Loss: 3.2358	LR: 0.100000
# Training Epoch: 2 [29056/50000]	Loss: 3.2919	LR: 0.100000
# Training Epoch: 2 [29184/50000]	Loss: 2.8538	LR: 0.100000
# Training Epoch: 2 [29312/50000]	Loss: 3.0997	LR: 0.100000
# Training Epoch: 2 [29440/50000]	Loss: 3.2927	LR: 0.100000
# Training Epoch: 2 [29568/50000]	Loss: 3.0846	LR: 0.100000
# Training Epoch: 2 [29696/50000]	Loss: 3.3065	LR: 0.100000
# Training Epoch: 2 [29824/50000]	Loss: 2.8992	LR: 0.100000
# Training Epoch: 2 [29952/50000]	Loss: 3.2851	LR: 0.100000
# Training Epoch: 2 [30080/50000]	Loss: 3.0747	LR: 0.100000
# Training Epoch: 2 [30208/50000]	Loss: 3.2553	LR: 0.100000
# Training Epoch: 2 [30336/50000]	Loss: 3.0278	LR: 0.100000
# Training Epoch: 2 [30464/50000]	Loss: 3.1985	LR: 0.100000
# Training Epoch: 2 [30592/50000]	Loss: 3.0426	LR: 0.100000
# Training Epoch: 2 [30720/50000]	Loss: 3.2498	LR: 0.100000
# Training Epoch: 2 [30848/50000]	Loss: 3.2943	LR: 0.100000
# Training Epoch: 2 [30976/50000]	Loss: 2.9994	LR: 0.100000
# Training Epoch: 2 [31104/50000]	Loss: 3.0192	LR: 0.100000
# Training Epoch: 2 [31232/50000]	Loss: 2.9362	LR: 0.100000
# Training Epoch: 2 [31360/50000]	Loss: 3.1381	LR: 0.100000
# Training Epoch: 2 [31488/50000]	Loss: 3.0498	LR: 0.100000
# Training Epoch: 2 [31616/50000]	Loss: 3.0961	LR: 0.100000
# Training Epoch: 2 [31744/50000]	Loss: 3.0231	LR: 0.100000
# Training Epoch: 2 [31872/50000]	Loss: 3.1925	LR: 0.100000
# Training Epoch: 2 [32000/50000]	Loss: 3.0556	LR: 0.100000
# Training Epoch: 2 [32128/50000]	Loss: 3.1250	LR: 0.100000
# Training Epoch: 2 [32256/50000]	Loss: 3.1748	LR: 0.100000
# Training Epoch: 2 [32384/50000]	Loss: 2.9148	LR: 0.100000
# Training Epoch: 2 [32512/50000]	Loss: 2.8701	LR: 0.100000
# Training Epoch: 2 [32640/50000]	Loss: 3.1249	LR: 0.100000
# Training Epoch: 2 [32768/50000]	Loss: 2.9650	LR: 0.100000
# Training Epoch: 2 [32896/50000]	Loss: 3.1229	LR: 0.100000
# Training Epoch: 2 [33024/50000]	Loss: 3.2512	LR: 0.100000
# Training Epoch: 2 [33152/50000]	Loss: 3.0678	LR: 0.100000
# Training Epoch: 2 [33280/50000]	Loss: 3.0983	LR: 0.100000
# Training Epoch: 2 [33408/50000]	Loss: 3.1314	LR: 0.100000
# Training Epoch: 2 [33536/50000]	Loss: 3.4390	LR: 0.100000
# Training Epoch: 2 [33664/50000]	Loss: 3.2510	LR: 0.100000
# Training Epoch: 2 [33792/50000]	Loss: 3.1314	LR: 0.100000
# Training Epoch: 2 [33920/50000]	Loss: 3.1899	LR: 0.100000
# Training Epoch: 2 [34048/50000]	Loss: 3.2050	LR: 0.100000
# Training Epoch: 2 [34176/50000]	Loss: 2.9636	LR: 0.100000
# Training Epoch: 2 [34304/50000]	Loss: 3.0757	LR: 0.100000
# Training Epoch: 2 [34432/50000]	Loss: 3.1814	LR: 0.100000
# Training Epoch: 2 [34560/50000]	Loss: 3.0341	LR: 0.100000
# Training Epoch: 2 [34688/50000]	Loss: 3.0365	LR: 0.100000
# Training Epoch: 2 [34816/50000]	Loss: 3.0863	LR: 0.100000
# Training Epoch: 2 [34944/50000]	Loss: 2.9121	LR: 0.100000
# Training Epoch: 2 [35072/50000]	Loss: 3.0936	LR: 0.100000
# Training Epoch: 2 [35200/50000]	Loss: 2.9144	LR: 0.100000
# Training Epoch: 2 [35328/50000]	Loss: 3.2441	LR: 0.100000
# Training Epoch: 2 [35456/50000]	Loss: 3.1151	LR: 0.100000
# Training Epoch: 2 [35584/50000]	Loss: 2.8949	LR: 0.100000
# Training Epoch: 2 [35712/50000]	Loss: 3.1208	LR: 0.100000
# Training Epoch: 2 [35840/50000]	Loss: 3.1504	LR: 0.100000
# Training Epoch: 2 [35968/50000]	Loss: 2.9617	LR: 0.100000
# Training Epoch: 2 [36096/50000]	Loss: 2.8740	LR: 0.100000
# Training Epoch: 2 [36224/50000]	Loss: 3.0508	LR: 0.100000
# Training Epoch: 2 [36352/50000]	Loss: 2.8439	LR: 0.100000
# Training Epoch: 2 [36480/50000]	Loss: 3.0144	LR: 0.100000
# Training Epoch: 2 [36608/50000]	Loss: 3.0027	LR: 0.100000
# Training Epoch: 2 [36736/50000]	Loss: 2.9519	LR: 0.100000
# Training Epoch: 2 [36864/50000]	Loss: 3.1738	LR: 0.100000
# Training Epoch: 2 [36992/50000]	Loss: 3.2184	LR: 0.100000
# Training Epoch: 2 [37120/50000]	Loss: 2.9830	LR: 0.100000
# Training Epoch: 2 [37248/50000]	Loss: 2.9813	LR: 0.100000
# Training Epoch: 2 [37376/50000]	Loss: 3.0746	LR: 0.100000
# Training Epoch: 2 [37504/50000]	Loss: 2.9162	LR: 0.100000
# Training Epoch: 2 [37632/50000]	Loss: 2.9968	LR: 0.100000
# Training Epoch: 2 [37760/50000]	Loss: 3.2581	LR: 0.100000
# Training Epoch: 2 [37888/50000]	Loss: 2.7999	LR: 0.100000
# Training Epoch: 2 [38016/50000]	Loss: 3.3110	LR: 0.100000
# Training Epoch: 2 [38144/50000]	Loss: 3.0600	LR: 0.100000
# Training Epoch: 2 [38272/50000]	Loss: 2.9322	LR: 0.100000
# Training Epoch: 2 [38400/50000]	Loss: 3.4172	LR: 0.100000
# Training Epoch: 2 [38528/50000]	Loss: 2.9200	LR: 0.100000
# Training Epoch: 2 [38656/50000]	Loss: 3.0177	LR: 0.100000
# Training Epoch: 2 [38784/50000]	Loss: 3.0844	LR: 0.100000
# Training Epoch: 2 [38912/50000]	Loss: 3.0444	LR: 0.100000
# Training Epoch: 2 [39040/50000]	Loss: 3.0394	LR: 0.100000
# Training Epoch: 2 [39168/50000]	Loss: 3.0424	LR: 0.100000
# Training Epoch: 2 [39296/50000]	Loss: 3.1119	LR: 0.100000
# Training Epoch: 2 [39424/50000]	Loss: 3.0753	LR: 0.100000
# Training Epoch: 2 [39552/50000]	Loss: 3.3332	LR: 0.100000
# Training Epoch: 2 [39680/50000]	Loss: 3.0543	LR: 0.100000
# Training Epoch: 2 [39808/50000]	Loss: 2.7097	LR: 0.100000
# Training Epoch: 2 [39936/50000]	Loss: 3.2816	LR: 0.100000
# Training Epoch: 2 [40064/50000]	Loss: 2.8019	LR: 0.100000
# Training Epoch: 2 [40192/50000]	Loss: 3.0430	LR: 0.100000
# Training Epoch: 2 [40320/50000]	Loss: 2.9651	LR: 0.100000
# Training Epoch: 2 [40448/50000]	Loss: 2.9979	LR: 0.100000
# Training Epoch: 2 [40576/50000]	Loss: 2.7831	LR: 0.100000
# Training Epoch: 2 [40704/50000]	Loss: 3.0180	LR: 0.100000
# Training Epoch: 2 [40832/50000]	Loss: 3.2668	LR: 0.100000
# Training Epoch: 2 [40960/50000]	Loss: 3.2109	LR: 0.100000
# Training Epoch: 2 [41088/50000]	Loss: 3.0483	LR: 0.100000
# Training Epoch: 2 [41216/50000]	Loss: 3.0030	LR: 0.100000
# Training Epoch: 2 [41344/50000]	Loss: 3.1568	LR: 0.100000
# Training Epoch: 2 [41472/50000]	Loss: 2.7379	LR: 0.100000
# Training Epoch: 2 [41600/50000]	Loss: 3.0947	LR: 0.100000
# Training Epoch: 2 [41728/50000]	Loss: 3.0983	LR: 0.100000
# Training Epoch: 2 [41856/50000]	Loss: 2.9454	LR: 0.100000
# Training Epoch: 2 [41984/50000]	Loss: 3.2414	LR: 0.100000
# Training Epoch: 2 [42112/50000]	Loss: 2.8018	LR: 0.100000
# Training Epoch: 2 [42240/50000]	Loss: 2.9296	LR: 0.100000
# Training Epoch: 2 [42368/50000]	Loss: 3.1271	LR: 0.100000
# Training Epoch: 2 [42496/50000]	Loss: 3.0282	LR: 0.100000
# Training Epoch: 2 [42624/50000]	Loss: 2.9247	LR: 0.100000
# Training Epoch: 2 [42752/50000]	Loss: 2.9410	LR: 0.100000
# Training Epoch: 2 [42880/50000]	Loss: 3.0280	LR: 0.100000
# Training Epoch: 2 [43008/50000]	Loss: 2.9835	LR: 0.100000
# Training Epoch: 2 [43136/50000]	Loss: 2.9992	LR: 0.100000
# Training Epoch: 2 [43264/50000]	Loss: 3.2030	LR: 0.100000
# Training Epoch: 2 [43392/50000]	Loss: 3.0782	LR: 0.100000
# Training Epoch: 2 [43520/50000]	Loss: 2.8836	LR: 0.100000
# Training Epoch: 2 [43648/50000]	Loss: 2.8191	LR: 0.100000
# Training Epoch: 2 [43776/50000]	Loss: 3.0501	LR: 0.100000
# Training Epoch: 2 [43904/50000]	Loss: 3.0092	LR: 0.100000
# Training Epoch: 2 [44032/50000]	Loss: 3.1126	LR: 0.100000
# Training Epoch: 2 [44160/50000]	Loss: 2.8934	LR: 0.100000
# Training Epoch: 2 [44288/50000]	Loss: 2.9694	LR: 0.100000
# Training Epoch: 2 [44416/50000]	Loss: 2.9872	LR: 0.100000
# Training Epoch: 2 [44544/50000]	Loss: 3.0067	LR: 0.100000
# Training Epoch: 2 [44672/50000]	Loss: 2.9201	LR: 0.100000
# Training Epoch: 2 [44800/50000]	Loss: 2.8969	LR: 0.100000
# Training Epoch: 2 [44928/50000]	Loss: 3.2193	LR: 0.100000
# Training Epoch: 2 [45056/50000]	Loss: 2.8120	LR: 0.100000
# Training Epoch: 2 [45184/50000]	Loss: 2.8114	LR: 0.100000
# Training Epoch: 2 [45312/50000]	Loss: 2.9067	LR: 0.100000
# Training Epoch: 2 [45440/50000]	Loss: 2.8155	LR: 0.100000
# Training Epoch: 2 [45568/50000]	Loss: 2.9004	LR: 0.100000
# Training Epoch: 2 [45696/50000]	Loss: 3.0598	LR: 0.100000
# Training Epoch: 2 [45824/50000]	Loss: 2.8530	LR: 0.100000
# Training Epoch: 2 [45952/50000]	Loss: 2.6060	LR: 0.100000
# Training Epoch: 2 [46080/50000]	Loss: 3.0196	LR: 0.100000
# Training Epoch: 2 [46208/50000]	Loss: 2.7922	LR: 0.100000
# Training Epoch: 2 [46336/50000]	Loss: 2.8993	LR: 0.100000
# Training Epoch: 2 [46464/50000]	Loss: 2.7907	LR: 0.100000
# Training Epoch: 2 [46592/50000]	Loss: 2.7949	LR: 0.100000
# Training Epoch: 2 [46720/50000]	Loss: 2.6571	LR: 0.100000
# Training Epoch: 2 [46848/50000]	Loss: 3.0890	LR: 0.100000
# Training Epoch: 2 [46976/50000]	Loss: 3.0023	LR: 0.100000
# Training Epoch: 2 [47104/50000]	Loss: 2.9418	LR: 0.100000
# Training Epoch: 2 [47232/50000]	Loss: 2.9314	LR: 0.100000
# Training Epoch: 2 [47360/50000]	Loss: 2.8961	LR: 0.100000
# Training Epoch: 2 [47488/50000]	Loss: 3.0072	LR: 0.100000
# Training Epoch: 2 [47616/50000]	Loss: 2.9563	LR: 0.100000
# Training Epoch: 2 [47744/50000]	Loss: 2.8749	LR: 0.100000
# Training Epoch: 2 [47872/50000]	Loss: 3.0536	LR: 0.100000
# Training Epoch: 2 [48000/50000]	Loss: 2.9172	LR: 0.100000
# Training Epoch: 2 [48128/50000]	Loss: 2.9074	LR: 0.100000
# Training Epoch: 2 [48256/50000]	Loss: 3.0933	LR: 0.100000
# Training Epoch: 2 [48384/50000]	Loss: 2.8929	LR: 0.100000
# Training Epoch: 2 [48512/50000]	Loss: 3.0187	LR: 0.100000
# Training Epoch: 2 [48640/50000]	Loss: 3.0148	LR: 0.100000
# Training Epoch: 2 [48768/50000]	Loss: 3.2092	LR: 0.100000
# Training Epoch: 2 [48896/50000]	Loss: 3.0011	LR: 0.100000
# Training Epoch: 2 [49024/50000]	Loss: 2.6976	LR: 0.100000
# Training Epoch: 2 [49152/50000]	Loss: 3.1709	LR: 0.100000
# Training Epoch: 2 [49280/50000]	Loss: 3.1925	LR: 0.100000
# Training Epoch: 2 [49408/50000]	Loss: 2.8741	LR: 0.100000
# Training Epoch: 2 [49536/50000]	Loss: 2.8928	LR: 0.100000
# Training Epoch: 2 [49664/50000]	Loss: 2.7912	LR: 0.100000
# Training Epoch: 2 [49792/50000]	Loss: 2.8637	LR: 0.100000
# Training Epoch: 2 [49920/50000]	Loss: 3.0007	LR: 0.100000
# Training Epoch: 2 [50000/50000]	Loss: 2.6582	LR: 0.100000
# Test set: Average loss: 0.0234, Accuracy: 0.2611
#
# Training Epoch: 3 [128/50000]	Loss: 3.0363	LR: 0.100000
# Training Epoch: 3 [256/50000]	Loss: 2.9090	LR: 0.100000
# Training Epoch: 3 [384/50000]	Loss: 3.0341	LR: 0.100000
# Training Epoch: 3 [512/50000]	Loss: 2.8426	LR: 0.100000
# Training Epoch: 3 [640/50000]	Loss: 2.9461	LR: 0.100000
# Training Epoch: 3 [768/50000]	Loss: 2.7675	LR: 0.100000
# Training Epoch: 3 [896/50000]	Loss: 2.7945	LR: 0.100000
# Training Epoch: 3 [1024/50000]	Loss: 2.9225	LR: 0.100000
# Training Epoch: 3 [1152/50000]	Loss: 2.9293	LR: 0.100000
# Training Epoch: 3 [1280/50000]	Loss: 2.8183	LR: 0.100000
# Training Epoch: 3 [1408/50000]	Loss: 2.6928	LR: 0.100000
# Training Epoch: 3 [1536/50000]	Loss: 2.7064	LR: 0.100000
# Training Epoch: 3 [1664/50000]	Loss: 2.7289	LR: 0.100000
# Training Epoch: 3 [1792/50000]	Loss: 2.8158	LR: 0.100000
# Training Epoch: 3 [1920/50000]	Loss: 2.9094	LR: 0.100000
# Training Epoch: 3 [2048/50000]	Loss: 3.1197	LR: 0.100000
# Training Epoch: 3 [2176/50000]	Loss: 2.7210	LR: 0.100000
# Training Epoch: 3 [2304/50000]	Loss: 3.1138	LR: 0.100000
# Training Epoch: 3 [2432/50000]	Loss: 2.7316	LR: 0.100000
# Training Epoch: 3 [2560/50000]	Loss: 2.4398	LR: 0.100000
# Training Epoch: 3 [2688/50000]	Loss: 3.0599	LR: 0.100000
# Training Epoch: 3 [2816/50000]	Loss: 3.0292	LR: 0.100000
# Training Epoch: 3 [2944/50000]	Loss: 2.6805	LR: 0.100000
# ...
# Training Epoch: 24 [15744/50000]	Loss: 0.8269	LR: 0.000337
# Training Epoch: 24 [15872/50000]	Loss: 0.8848	LR: 0.000337
# Training Epoch: 24 [16000/50000]	Loss: 0.9008	LR: 0.000337
# Training Epoch: 24 [16128/50000]	Loss: 0.7390	LR: 0.000337
# Training Epoch: 24 [16256/50000]	Loss: 0.8373	LR: 0.000337
# Training Epoch: 24 [16384/50000]	Loss: 0.8517	LR: 0.000337
# Training Epoch: 24 [16512/50000]	Loss: 0.7639	LR: 0.000337
# Training Epoch: 24 [16640/50000]	Loss: 0.7463	LR: 0.000337
# Training Epoch: 24 [16768/50000]	Loss: 0.8417	LR: 0.000337
# Training Epoch: 24 [16896/50000]	Loss: 0.8761	LR: 0.000337
# Training Epoch: 24 [17024/50000]	Loss: 0.6659	LR: 0.000337
# Training Epoch: 24 [17152/50000]	Loss: 1.0310	LR: 0.000337
# Training Epoch: 24 [17280/50000]	Loss: 0.7795	LR: 0.000337
# Training Epoch: 24 [17408/50000]	Loss: 0.7897	LR: 0.000337
# Training Epoch: 24 [17536/50000]	Loss: 0.9313	LR: 0.000337
# Training Epoch: 24 [17664/50000]	Loss: 0.8406	LR: 0.000337
# Training Epoch: 24 [17792/50000]	Loss: 0.8065	LR: 0.000337
# Training Epoch: 24 [17920/50000]	Loss: 0.8878	LR: 0.000337
# Training Epoch: 24 [18048/50000]	Loss: 0.8153	LR: 0.000337
# Training Epoch: 24 [18176/50000]	Loss: 0.8325	LR: 0.000337
# Training Epoch: 24 [18304/50000]	Loss: 0.9320	LR: 0.000337
# Training Epoch: 24 [18432/50000]	Loss: 0.7476	LR: 0.000337
# Training Epoch: 24 [18560/50000]	Loss: 0.7770	LR: 0.000337
# Training Epoch: 24 [18688/50000]	Loss: 0.9186	LR: 0.000337
# Training Epoch: 24 [18816/50000]	Loss: 0.6346	LR: 0.000337
# Training Epoch: 24 [18944/50000]	Loss: 0.7914	LR: 0.000337
# Training Epoch: 24 [19072/50000]	Loss: 0.9553	LR: 0.000337
# Training Epoch: 24 [19200/50000]	Loss: 0.8576	LR: 0.000337
# Training Epoch: 24 [19328/50000]	Loss: 0.8771	LR: 0.000337
# Training Epoch: 24 [19456/50000]	Loss: 0.7347	LR: 0.000337
# Training Epoch: 24 [19584/50000]	Loss: 0.7105	LR: 0.000337
# Training Epoch: 24 [19712/50000]	Loss: 0.9621	LR: 0.000337
# Training Epoch: 24 [19840/50000]	Loss: 0.7424	LR: 0.000337
# Training Epoch: 24 [19968/50000]	Loss: 0.8023	LR: 0.000337
# Training Epoch: 24 [20096/50000]	Loss: 0.7838	LR: 0.000337
# Training Epoch: 24 [20224/50000]	Loss: 0.7789	LR: 0.000337
# Training Epoch: 24 [20352/50000]	Loss: 0.8036	LR: 0.000337
# Training Epoch: 24 [20480/50000]	Loss: 0.5307	LR: 0.000337
# Training Epoch: 24 [20608/50000]	Loss: 0.8292	LR: 0.000337
# Training Epoch: 24 [20736/50000]	Loss: 0.7482	LR: 0.000337
# Training Epoch: 24 [20864/50000]	Loss: 0.7999	LR: 0.000337
# Training Epoch: 24 [20992/50000]	Loss: 0.7545	LR: 0.000337
# Training Epoch: 24 [21120/50000]	Loss: 0.8232	LR: 0.000337
# Training Epoch: 24 [21248/50000]	Loss: 0.7397	LR: 0.000337
# Training Epoch: 24 [21376/50000]	Loss: 0.9651	LR: 0.000337
# Training Epoch: 24 [21504/50000]	Loss: 0.7813	LR: 0.000337
# Training Epoch: 24 [21632/50000]	Loss: 0.8504	LR: 0.000337
# Training Epoch: 24 [21760/50000]	Loss: 0.8722	LR: 0.000337
# Training Epoch: 24 [21888/50000]	Loss: 0.9234	LR: 0.000337
# Training Epoch: 24 [22016/50000]	Loss: 0.7483	LR: 0.000337
# Training Epoch: 24 [22144/50000]	Loss: 0.8124	LR: 0.000337
# Training Epoch: 24 [22272/50000]	Loss: 0.7882	LR: 0.000337
# Training Epoch: 24 [22400/50000]	Loss: 0.7239	LR: 0.000337
# Training Epoch: 24 [22528/50000]	Loss: 0.8983	LR: 0.000337
# Training Epoch: 24 [22656/50000]	Loss: 0.7994	LR: 0.000337
# Training Epoch: 24 [22784/50000]	Loss: 0.9305	LR: 0.000337
# Training Epoch: 24 [22912/50000]	Loss: 0.7301	LR: 0.000337
# Training Epoch: 24 [23040/50000]	Loss: 0.9501	LR: 0.000337
# Training Epoch: 24 [23168/50000]	Loss: 0.9051	LR: 0.000337
# Training Epoch: 24 [23296/50000]	Loss: 1.1907	LR: 0.000337
# Training Epoch: 24 [23424/50000]	Loss: 0.8214	LR: 0.000337
# Training Epoch: 24 [23552/50000]	Loss: 0.8435	LR: 0.000337
# Training Epoch: 24 [23680/50000]	Loss: 0.8606	LR: 0.000337
# Training Epoch: 24 [23808/50000]	Loss: 0.7472	LR: 0.000337
# Training Epoch: 24 [23936/50000]	Loss: 0.7353	LR: 0.000337
# Training Epoch: 24 [24064/50000]	Loss: 0.8960	LR: 0.000337
# Training Epoch: 24 [24192/50000]	Loss: 0.6646	LR: 0.000337
# Training Epoch: 24 [24320/50000]	Loss: 0.7709	LR: 0.000337
# Training Epoch: 24 [24448/50000]	Loss: 0.8998	LR: 0.000337
# Training Epoch: 24 [24576/50000]	Loss: 0.6451	LR: 0.000337
# Training Epoch: 24 [24704/50000]	Loss: 0.6542	LR: 0.000337
# Training Epoch: 24 [24832/50000]	Loss: 0.6859	LR: 0.000337
# Training Epoch: 24 [24960/50000]	Loss: 0.8405	LR: 0.000337
# Training Epoch: 24 [25088/50000]	Loss: 0.7519	LR: 0.000337
# Training Epoch: 24 [25216/50000]	Loss: 0.9699	LR: 0.000337
# Training Epoch: 24 [25344/50000]	Loss: 0.7664	LR: 0.000337
# Training Epoch: 24 [25472/50000]	Loss: 0.8416	LR: 0.000337
# Training Epoch: 24 [25600/50000]	Loss: 0.8654	LR: 0.000337
# Training Epoch: 24 [25728/50000]	Loss: 0.7215	LR: 0.000337
# Training Epoch: 24 [25856/50000]	Loss: 0.7889	LR: 0.000337
# Training Epoch: 24 [25984/50000]	Loss: 0.7196	LR: 0.000337
# Training Epoch: 24 [26112/50000]	Loss: 0.7326	LR: 0.000337
# Training Epoch: 24 [26240/50000]	Loss: 0.6984	LR: 0.000337
# Training Epoch: 24 [26368/50000]	Loss: 0.8320	LR: 0.000337
# Training Epoch: 24 [26496/50000]	Loss: 0.7177	LR: 0.000337
# Training Epoch: 24 [26624/50000]	Loss: 0.7767	LR: 0.000337
# Training Epoch: 24 [26752/50000]	Loss: 0.9368	LR: 0.000337
# Training Epoch: 24 [26880/50000]	Loss: 0.8734	LR: 0.000337
# Training Epoch: 24 [27008/50000]	Loss: 0.8472	LR: 0.000337
# Training Epoch: 24 [27136/50000]	Loss: 0.8862	LR: 0.000337
# Training Epoch: 24 [27264/50000]	Loss: 0.7642	LR: 0.000337
# Training Epoch: 24 [27392/50000]	Loss: 0.9374	LR: 0.000337
# Training Epoch: 24 [27520/50000]	Loss: 0.7471	LR: 0.000337
# Training Epoch: 24 [27648/50000]	Loss: 0.7589	LR: 0.000337
# Training Epoch: 24 [27776/50000]	Loss: 0.7464	LR: 0.000337
# Training Epoch: 24 [27904/50000]	Loss: 0.8608	LR: 0.000337
# Training Epoch: 24 [28032/50000]	Loss: 0.7460	LR: 0.000337
# Training Epoch: 24 [28160/50000]	Loss: 0.7858	LR: 0.000337
# Training Epoch: 24 [28288/50000]	Loss: 0.7388	LR: 0.000337
# Training Epoch: 24 [28416/50000]	Loss: 1.0165	LR: 0.000337
# Training Epoch: 24 [28544/50000]	Loss: 0.8030	LR: 0.000337
# Training Epoch: 24 [28672/50000]	Loss: 0.8111	LR: 0.000337
# Training Epoch: 24 [28800/50000]	Loss: 0.9155	LR: 0.000337
# Training Epoch: 24 [28928/50000]	Loss: 0.9187	LR: 0.000337
# Training Epoch: 24 [29056/50000]	Loss: 0.7932	LR: 0.000337
# Training Epoch: 24 [29184/50000]	Loss: 0.7110	LR: 0.000337
# Training Epoch: 24 [29312/50000]	Loss: 0.8635	LR: 0.000337
# Training Epoch: 24 [29440/50000]	Loss: 0.9362	LR: 0.000337
# Training Epoch: 24 [29568/50000]	Loss: 0.6632	LR: 0.000337
# Training Epoch: 24 [29696/50000]	Loss: 0.8906	LR: 0.000337
# Training Epoch: 24 [29824/50000]	Loss: 0.9161	LR: 0.000337
# Training Epoch: 24 [29952/50000]	Loss: 0.9177	LR: 0.000337
# Training Epoch: 24 [30080/50000]	Loss: 0.7550	LR: 0.000337
# Training Epoch: 24 [30208/50000]	Loss: 0.7340	LR: 0.000337
# Training Epoch: 24 [30336/50000]	Loss: 0.7591	LR: 0.000337
# Training Epoch: 24 [30464/50000]	Loss: 0.6984	LR: 0.000337
# Training Epoch: 24 [30592/50000]	Loss: 0.7624	LR: 0.000337
# Training Epoch: 24 [30720/50000]	Loss: 0.8327	LR: 0.000337
# Training Epoch: 24 [30848/50000]	Loss: 0.6877	LR: 0.000337
# Training Epoch: 24 [30976/50000]	Loss: 0.7379	LR: 0.000337
# Training Epoch: 24 [31104/50000]	Loss: 0.7539	LR: 0.000337
# Training Epoch: 24 [31232/50000]	Loss: 0.9213	LR: 0.000337
# Training Epoch: 24 [31360/50000]	Loss: 0.7232	LR: 0.000337
# Training Epoch: 24 [31488/50000]	Loss: 0.9263	LR: 0.000337
# Training Epoch: 24 [31616/50000]	Loss: 0.8338	LR: 0.000337
# Training Epoch: 24 [31744/50000]	Loss: 0.6452	LR: 0.000337
# Training Epoch: 24 [31872/50000]	Loss: 0.8260	LR: 0.000337
# Training Epoch: 24 [32000/50000]	Loss: 0.8043	LR: 0.000337
# Training Epoch: 24 [32128/50000]	Loss: 0.8036	LR: 0.000337
# Training Epoch: 24 [32256/50000]	Loss: 0.8649	LR: 0.000337
# Training Epoch: 24 [32384/50000]	Loss: 0.9513	LR: 0.000337
# Training Epoch: 24 [32512/50000]	Loss: 0.7599	LR: 0.000337
# Training Epoch: 24 [32640/50000]	Loss: 0.6485	LR: 0.000337
# Training Epoch: 24 [32768/50000]	Loss: 0.7189	LR: 0.000337
# Training Epoch: 24 [32896/50000]	Loss: 0.8713	LR: 0.000337
# Training Epoch: 24 [33024/50000]	Loss: 0.6461	LR: 0.000337
# Training Epoch: 24 [33152/50000]	Loss: 0.8344	LR: 0.000337
# Training Epoch: 24 [33280/50000]	Loss: 0.6497	LR: 0.000337
# Training Epoch: 24 [33408/50000]	Loss: 0.7947	LR: 0.000337
# Training Epoch: 24 [33536/50000]	Loss: 0.7565	LR: 0.000337
# Training Epoch: 24 [33664/50000]	Loss: 0.9363	LR: 0.000337
# Training Epoch: 24 [33792/50000]	Loss: 0.7304	LR: 0.000337
# Training Epoch: 24 [33920/50000]	Loss: 0.6697	LR: 0.000337
# Training Epoch: 24 [34048/50000]	Loss: 0.8372	LR: 0.000337
# Training Epoch: 24 [34176/50000]	Loss: 0.8903	LR: 0.000337
# Training Epoch: 24 [34304/50000]	Loss: 0.8578	LR: 0.000337
# Training Epoch: 24 [34432/50000]	Loss: 0.7980	LR: 0.000337
# Training Epoch: 24 [34560/50000]	Loss: 0.7235	LR: 0.000337
# Training Epoch: 24 [34688/50000]	Loss: 0.7907	LR: 0.000337
# Training Epoch: 24 [34816/50000]	Loss: 0.8806	LR: 0.000337
# Training Epoch: 24 [34944/50000]	Loss: 0.7680	LR: 0.000337
# Training Epoch: 24 [35072/50000]	Loss: 0.8948	LR: 0.000337
# Training Epoch: 24 [35200/50000]	Loss: 0.9636	LR: 0.000337
# Training Epoch: 24 [35328/50000]	Loss: 0.8452	LR: 0.000337
# Training Epoch: 24 [35456/50000]	Loss: 0.7576	LR: 0.000337
# Training Epoch: 24 [35584/50000]	Loss: 0.7369	LR: 0.000337
# Training Epoch: 24 [35712/50000]	Loss: 0.8266	LR: 0.000337
# Training Epoch: 24 [35840/50000]	Loss: 0.7815	LR: 0.000337
# Training Epoch: 24 [35968/50000]	Loss: 0.8917	LR: 0.000337
# Training Epoch: 24 [36096/50000]	Loss: 0.8288	LR: 0.000337
# Training Epoch: 24 [36224/50000]	Loss: 0.8650	LR: 0.000337
# Training Epoch: 24 [36352/50000]	Loss: 0.8169	LR: 0.000337
# Training Epoch: 24 [36480/50000]	Loss: 0.7374	LR: 0.000337
# Training Epoch: 24 [36608/50000]	Loss: 0.8413	LR: 0.000337
# Training Epoch: 24 [36736/50000]	Loss: 0.8192	LR: 0.000337
# Training Epoch: 24 [36864/50000]	Loss: 0.7994	LR: 0.000337
# Training Epoch: 24 [36992/50000]	Loss: 0.7827	LR: 0.000337
# Training Epoch: 24 [37120/50000]	Loss: 0.7865	LR: 0.000337
# Training Epoch: 24 [37248/50000]	Loss: 0.8473	LR: 0.000337
# Training Epoch: 24 [37376/50000]	Loss: 0.7720	LR: 0.000337
# Training Epoch: 24 [37504/50000]	Loss: 0.7281	LR: 0.000337
# Training Epoch: 24 [37632/50000]	Loss: 0.8962	LR: 0.000337
# Training Epoch: 24 [37760/50000]	Loss: 0.6655	LR: 0.000337
# Training Epoch: 24 [37888/50000]	Loss: 0.8911	LR: 0.000337
# Training Epoch: 24 [38016/50000]	Loss: 0.6917	LR: 0.000337
# Training Epoch: 24 [38144/50000]	Loss: 0.8454	LR: 0.000337
# Training Epoch: 24 [38272/50000]	Loss: 1.0070	LR: 0.000337
# Training Epoch: 24 [38400/50000]	Loss: 0.7348	LR: 0.000337
# Training Epoch: 24 [38528/50000]	Loss: 0.7399	LR: 0.000337
# Training Epoch: 24 [38656/50000]	Loss: 0.8394	LR: 0.000337
# Training Epoch: 24 [38784/50000]	Loss: 0.8106	LR: 0.000337
# Training Epoch: 24 [38912/50000]	Loss: 0.7594	LR: 0.000337
# Training Epoch: 24 [39040/50000]	Loss: 0.8790	LR: 0.000337
# Training Epoch: 24 [39168/50000]	Loss: 0.6187	LR: 0.000337
# Training Epoch: 24 [39296/50000]	Loss: 0.8349	LR: 0.000337
# Training Epoch: 24 [39424/50000]	Loss: 0.7853	LR: 0.000337
# Training Epoch: 24 [39552/50000]	Loss: 0.7730	LR: 0.000337
# Training Epoch: 24 [39680/50000]	Loss: 0.6402	LR: 0.000337
# Training Epoch: 24 [39808/50000]	Loss: 0.8147	LR: 0.000337
# Training Epoch: 24 [39936/50000]	Loss: 0.8921	LR: 0.000337
# Training Epoch: 24 [40064/50000]	Loss: 0.7715	LR: 0.000337
# Training Epoch: 24 [40192/50000]	Loss: 0.8366	LR: 0.000337
# Training Epoch: 24 [40320/50000]	Loss: 0.6221	LR: 0.000337
# Training Epoch: 24 [40448/50000]	Loss: 0.8871	LR: 0.000337
# Training Epoch: 24 [40576/50000]	Loss: 0.8513	LR: 0.000337
# Training Epoch: 24 [40704/50000]	Loss: 0.7074	LR: 0.000337
# Training Epoch: 24 [40832/50000]	Loss: 0.9068	LR: 0.000337
# Training Epoch: 24 [40960/50000]	Loss: 0.8787	LR: 0.000337
# Training Epoch: 24 [41088/50000]	Loss: 0.7153	LR: 0.000337
# Training Epoch: 24 [41216/50000]	Loss: 0.7796	LR: 0.000337
# Training Epoch: 24 [41344/50000]	Loss: 0.8395	LR: 0.000337
# Training Epoch: 24 [41472/50000]	Loss: 0.8395	LR: 0.000337
# Training Epoch: 24 [41600/50000]	Loss: 0.7769	LR: 0.000337
# Training Epoch: 24 [41728/50000]	Loss: 1.0358	LR: 0.000337
# Training Epoch: 24 [41856/50000]	Loss: 0.7707	LR: 0.000337
# Training Epoch: 24 [41984/50000]	Loss: 0.7659	LR: 0.000337
# Training Epoch: 24 [42112/50000]	Loss: 0.8168	LR: 0.000337
# Training Epoch: 24 [42240/50000]	Loss: 0.7542	LR: 0.000337
# Training Epoch: 24 [42368/50000]	Loss: 0.7938	LR: 0.000337
# Training Epoch: 24 [42496/50000]	Loss: 0.9062	LR: 0.000337
# Training Epoch: 24 [42624/50000]	Loss: 0.6764	LR: 0.000337
# Training Epoch: 24 [42752/50000]	Loss: 0.7623	LR: 0.000337
# Training Epoch: 24 [42880/50000]	Loss: 0.8261	LR: 0.000337
# Training Epoch: 24 [43008/50000]	Loss: 0.7449	LR: 0.000337
# Training Epoch: 24 [43136/50000]	Loss: 0.7521	LR: 0.000337
# Training Epoch: 24 [43264/50000]	Loss: 0.8758	LR: 0.000337
# Training Epoch: 24 [43392/50000]	Loss: 0.7013	LR: 0.000337
# Training Epoch: 24 [43520/50000]	Loss: 0.8531	LR: 0.000337
# Training Epoch: 24 [43648/50000]	Loss: 0.6692	LR: 0.000337
# Training Epoch: 24 [43776/50000]	Loss: 0.8110	LR: 0.000337
# Training Epoch: 24 [43904/50000]	Loss: 0.8671	LR: 0.000337
# Training Epoch: 24 [44032/50000]	Loss: 0.9383	LR: 0.000337
# Training Epoch: 24 [44160/50000]	Loss: 0.7090	LR: 0.000337
# Training Epoch: 24 [44288/50000]	Loss: 0.8252	LR: 0.000337
# Training Epoch: 24 [44416/50000]	Loss: 0.8081	LR: 0.000337
# Training Epoch: 24 [44544/50000]	Loss: 0.9094	LR: 0.000337
# Training Epoch: 24 [44672/50000]	Loss: 0.7358	LR: 0.000337
# Training Epoch: 24 [44800/50000]	Loss: 0.8142	LR: 0.000337
# Training Epoch: 24 [44928/50000]	Loss: 0.9411	LR: 0.000337
# Training Epoch: 24 [45056/50000]	Loss: 0.7915	LR: 0.000337
# Training Epoch: 24 [45184/50000]	Loss: 0.7245	LR: 0.000337
# Training Epoch: 24 [45312/50000]	Loss: 0.7889	LR: 0.000337
# Training Epoch: 24 [45440/50000]	Loss: 0.6721	LR: 0.000337
# Training Epoch: 24 [45568/50000]	Loss: 0.9097	LR: 0.000337
# Training Epoch: 24 [45696/50000]	Loss: 0.8771	LR: 0.000337
# Training Epoch: 24 [45824/50000]	Loss: 0.9914	LR: 0.000337
# Training Epoch: 24 [45952/50000]	Loss: 0.6804	LR: 0.000337
# Training Epoch: 24 [46080/50000]	Loss: 0.7702	LR: 0.000337
# Training Epoch: 24 [46208/50000]	Loss: 0.8730	LR: 0.000337
# Training Epoch: 24 [46336/50000]	Loss: 0.8196	LR: 0.000337
# Training Epoch: 24 [46464/50000]	Loss: 1.0075	LR: 0.000337
# Training Epoch: 24 [46592/50000]	Loss: 0.9223	LR: 0.000337
# Training Epoch: 24 [46720/50000]	Loss: 0.8282	LR: 0.000337
# Training Epoch: 24 [46848/50000]	Loss: 0.8429	LR: 0.000337
# Training Epoch: 24 [46976/50000]	Loss: 1.0153	LR: 0.000337
# Training Epoch: 24 [47104/50000]	Loss: 0.9857	LR: 0.000337
# Training Epoch: 24 [47232/50000]	Loss: 0.7249	LR: 0.000337
# Training Epoch: 24 [47360/50000]	Loss: 0.5970	LR: 0.000337
# Training Epoch: 24 [47488/50000]	Loss: 0.9456	LR: 0.000337
# Training Epoch: 24 [47616/50000]	Loss: 0.7601	LR: 0.000337
# Training Epoch: 24 [47744/50000]	Loss: 0.6322	LR: 0.000337
# Training Epoch: 24 [47872/50000]	Loss: 0.8853	LR: 0.000337
# Training Epoch: 24 [48000/50000]	Loss: 0.8511	LR: 0.000337
# Training Epoch: 24 [48128/50000]	Loss: 0.7819	LR: 0.000337
# Training Epoch: 24 [48256/50000]	Loss: 0.8285	LR: 0.000337
# Training Epoch: 24 [48384/50000]	Loss: 0.7490	LR: 0.000337
# Training Epoch: 24 [48512/50000]	Loss: 0.8427	LR: 0.000337
# Training Epoch: 24 [48640/50000]	Loss: 0.8094	LR: 0.000337
# Training Epoch: 24 [48768/50000]	Loss: 0.8016	LR: 0.000337
# Training Epoch: 24 [48896/50000]	Loss: 0.6575	LR: 0.000337
# Training Epoch: 24 [49024/50000]	Loss: 0.6928	LR: 0.000337
# Training Epoch: 24 [49152/50000]	Loss: 0.7813	LR: 0.000337
# Training Epoch: 24 [49280/50000]	Loss: 0.8864	LR: 0.000337
# Training Epoch: 24 [49408/50000]	Loss: 0.7330	LR: 0.000337
# Training Epoch: 24 [49536/50000]	Loss: 0.8766	LR: 0.000337
# Training Epoch: 24 [49664/50000]	Loss: 0.7783	LR: 0.000337
# Training Epoch: 24 [49792/50000]	Loss: 0.7996	LR: 0.000337
# Training Epoch: 24 [49920/50000]	Loss: 0.9203	LR: 0.000337
# Training Epoch: 24 [50000/50000]	Loss: 1.0029	LR: 0.000337
# Test set: Average loss: 0.0093, Accuracy: 0.6727
#
#
# best_acc:  tensor(0.6727, device='cuda:0')

# %% [markdown]
# ## Testing the Model

# %%
weights_file="./resnetcbam18.pth"
torch.save(net.state_dict(), weights_file)

# %%
if __name__ == '__main__':
    net = get_network()
    CIFAR100_test_loader = get_test_dataloader(
        CIFAR100_TRAIN_MEAN,
        CIFAR100_TRAIN_STD,
        #CIFAR100_PATH,
        num_workers=2,
        batch_size=128,
        shuffle=True
    )

    net.load_state_dict(torch.load(weights_file), True)
    print(net)
    net.eval()

    correct_1 = 0.0
    correct_5 = 0.0
    total = 0

    for n_iter, (image, label) in enumerate(CIFAR100_test_loader):
        print("iteration: {}\ttotal {} iterations".format(n_iter + 1, len(CIFAR100_test_loader)))
        image = Variable(image).cuda()
        label = Variable(label).cuda()
        output = net(image)
        _, pred = output.topk(5, 1, largest=True, sorted=True)

        label = label.view(label.size(0), -1).expand_as(pred)
        correct = pred.eq(label).float()

        #compute top 5
        correct_5 += correct[:, :5].sum()

        #compute top1 
        correct_1 += correct[:, :1].sum()


    print()
    print("Top 1 err: ", 1 - correct_1 / len(CIFAR100_test_loader.dataset))
    print("Top 5 err: ", 1 - correct_5 / len(CIFAR100_test_loader.dataset))
    print("Parameter numbers: {}".format(sum(p.numel() for p in net.parameters())))
# Out:
# Files already downloaded and verified
# ResNetCBAM(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (linear): Linear(in_features=512, out_features=100, bias=True)
# )
# iteration: 1	total 79 iterations
# iteration: 2	total 79 iterations
# iteration: 3	total 79 iterations
# iteration: 4	total 79 iterations
# iteration: 5	total 79 iterations
# iteration: 6	total 79 iterations
# iteration: 7	total 79 iterations
# iteration: 8	total 79 iterations
# iteration: 9	total 79 iterations
# iteration: 10	total 79 iterations
# iteration: 11	total 79 iterations
# iteration: 12	total 79 iterations
# iteration: 13	total 79 iterations
# iteration: 14	total 79 iterations
# iteration: 15	total 79 iterations
# iteration: 16	total 79 iterations
# iteration: 17	total 79 iterations
# iteration: 18	total 79 iterations
# iteration: 19	total 79 iterations
# iteration: 20	total 79 iterations
# iteration: 21	total 79 iterations
# iteration: 22	total 79 iterations
# iteration: 23	total 79 iterations
# iteration: 24	total 79 iterations
# iteration: 25	total 79 iterations
# iteration: 26	total 79 iterations
# iteration: 27	total 79 iterations
# iteration: 28	total 79 iterations
# iteration: 29	total 79 iterations
# iteration: 30	total 79 iterations
# iteration: 31	total 79 iterations
# iteration: 32	total 79 iterations
# iteration: 33	total 79 iterations
# iteration: 34	total 79 iterations
# iteration: 35	total 79 iterations
# iteration: 36	total 79 iterations
# iteration: 37	total 79 iterations
# iteration: 38	total 79 iterations
# iteration: 39	total 79 iterations
# iteration: 40	total 79 iterations
# iteration: 41	total 79 iterations
# iteration: 42	total 79 iterations
# iteration: 43	total 79 iterations
# iteration: 44	total 79 iterations
# iteration: 45	total 79 iterations
# iteration: 46	total 79 iterations
# iteration: 47	total 79 iterations
# iteration: 48	total 79 iterations
# iteration: 49	total 79 iterations
# iteration: 50	total 79 iterations
# iteration: 51	total 79 iterations
# iteration: 52	total 79 iterations
# iteration: 53	total 79 iterations
# iteration: 54	total 79 iterations
# iteration: 55	total 79 iterations
# iteration: 56	total 79 iterations
# iteration: 57	total 79 iterations
# iteration: 58	total 79 iterations
# iteration: 59	total 79 iterations
# iteration: 60	total 79 iterations
# iteration: 61	total 79 iterations
# iteration: 62	total 79 iterations
# iteration: 63	total 79 iterations
# iteration: 64	total 79 iterations
# iteration: 65	total 79 iterations
# iteration: 66	total 79 iterations
# iteration: 67	total 79 iterations
# iteration: 68	total 79 iterations
# iteration: 69	total 79 iterations
# iteration: 70	total 79 iterations
# iteration: 71	total 79 iterations
# iteration: 72	total 79 iterations
# iteration: 73	total 79 iterations
# iteration: 74	total 79 iterations
# iteration: 75	total 79 iterations
# iteration: 76	total 79 iterations
# iteration: 77	total 79 iterations
# iteration: 78	total 79 iterations
# iteration: 79	total 79 iterations
#
# Top 1 err:  tensor(0.3273, device='cuda:0')
# Top 5 err:  tensor(0.0923, device='cuda:0')
# Parameter numbers: 11307316
