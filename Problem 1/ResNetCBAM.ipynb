# %%
import os
import sys
import pickle
from skimage import io
import matplotlib.pyplot as plt
import numpy 
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import _LRScheduler
from torch.autograd import Variable
import torchvision
import torchvision.transforms as transforms
import argparse
import glob
import cv2
import torch.optim as optim
import matplotlib
matplotlib.use('Agg')

# %% [markdown]
# ## Loading Data (CIFAR10)

# %%
class CIFAR10Train(Dataset):
    """CIFAR10 test dataset, derived from
    torch.utils.data.DataSet
    """

    def __init__(self, path, transform=None):
        #if transform is given, we transoform data using
        with open(os.path.join(path, 'train'), 'rb') as CIFAR10:
            self.data = pickle.load(CIFAR10, encoding='bytes')
        self.transform = transform
        
    def __len__(self):
        return len(self.data['fine_labels'.encode()])

    def __getitem__(self, index):
        label = self.data['fine_labels'.encode()][index]
        r = self.data['data'.encode()][index, :1024].reshape(32, 32)
        g = self.data['data'.encode()][index, 1024:2048].reshape(32, 32)
        b = self.data['data'.encode()][index, 2048:].reshape(32, 32)
        image = numpy.dstack((r, g, b))

        if self.transform:
            image = self.transform(image)
        return label, image

class CIFAR10Test(Dataset):
    """CIFAR10 test dataset, derived from
    torch.utils.data.DataSet
    """

    def __init__(self, path, transform=None):
        with open(os.path.join(path, 'test'), 'rb') as CIFAR10:
            self.data = pickle.load(CIFAR10, encoding='bytes')
        self.transform = transform 

    def __len__(self):
        return len(self.data['data'.encode()])
    
    def __getitem__(self, index):
        label = self.data['fine_labels'.encode()][index]
        r = self.data['data'.encode()][index, :1024].reshape(32, 32)
        g = self.data['data'.encode()][index, 1024:2048].reshape(32, 32)
        b = self.data['data'.encode()][index, 2048:].reshape(32, 32)
        image = numpy.dstack((r, g, b))

        if self.transform:
            image = self.transform(image)
        return label, image

# %% [markdown]
# ## Attention Modules (CAM,SAM,CBAM,ZAM)

# %%
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        return self.sigmoid(out)

class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=3):
        super(SpatialAttention, self).__init__()

        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return self.sigmoid(x)

class CBAM(nn.Module):
    def __init__(self, in_planes):
        super(CBAM, self).__init__()

        self.ca = ChannelAttention(in_planes)
        self.sa = SpatialAttention()
        
    def forward(self, x):
        
        out = x * (self.ca(x))
        out = out * (self.sa(out))
        
        return out

## ZAM ##    
class ZeroChannelAttention(nn.Module):
    def __init__(self):
        super(ZeroChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
    
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        return self.sigmoid(self.avg_pool(x) + self.max_pool(x))

class ZeroSpatialAttention(nn.Module):
    def __init__(self):
        super(ZeroSpatialAttention, self).__init__()

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        return self.sigmoid(avg_out + max_out)
    
class ZAM(nn.Module):
    def __init__(self, use_skip_connection = False):
        super(ZAM, self).__init__()

        self.ca = ZeroChannelAttention()
        self.sa = ZeroSpatialAttention()
        self.use_skip_connection = use_skip_connection
        
    def forward(self, x):
        
        out = x + x * self.ca(x) if self.use_skip_connection else x * self.ca(x)
        out = out + out * self.sa(out) if self.use_skip_connection else out * self.sa(out)
        
        return out

# %% [markdown]
# ## Models (ResNet,MobileNet)

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )
        
        self.cbam = CBAM(planes)

    def forward(self, x):
        residual = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = self.cbam(out)
        out += self.shortcut(residual)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )
        
        self.cbam = CBAM(self.expansion*planes)
        
    def forward(self, x):
        residual = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out = self.cbam(out)
        out += self.shortcut(residual)
        out = F.relu(out)
        return out


class ResNetCBAM(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNetCBAM, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNetCBAM18():
    return ResNetCBAM(BasicBlock, [2,2,2,2])

class MobileNetCBAM(nn.Module):
    def __init__(self, classes = 100):
        super(MobileNetCBAM, self).__init__()

        def conv_bn(inp, oup, stride):
            return nn.Sequential(
                nn.Conv2d(inp, oup, 3, stride, 1, bias=False),
                nn.BatchNorm2d(oup),
                nn.ReLU(inplace=True)
            )

        def conv_dw(inp, oup, stride):
            return nn.Sequential(
                nn.Conv2d(inp, inp, 3, stride, 1, groups=inp, bias=False),
                nn.BatchNorm2d(inp),
                nn.ReLU(inplace=True),
                nn.Conv2d(inp, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
                CBAM(oup),
                nn.ReLU(inplace=True),
            )

        self.model = nn.Sequential(
            conv_bn(  3,  32, 1), 
            conv_dw( 32,  64, 1),
            conv_dw( 64, 128, 1),
            conv_dw(128, 128, 1),
            conv_dw(128, 256, 2),
            conv_dw(256, 256, 1),
            conv_dw(256, 512, 2),
            conv_dw(512, 512, 1),
            conv_dw(512, 512, 1),
            conv_dw(512, 512, 1),
            conv_dw(512, 512, 1),
            conv_dw(512, 512, 1),
            conv_dw(512, 1024, 2),
            conv_dw(1024, 1024, 1),
            nn.AvgPool2d(4),
        )
        self.fc = nn.Linear(1024, classes)

    def forward(self, x):
        x = self.model(x)
        x = x.view(-1, 1024)
        x = self.fc(x)
        return x

# %% [markdown]
# ## Utils

# %%
def get_network():
    net=ResNetCBAM18().cuda()
    #net=MobileNetCBAM().cuda()
    """ return given network
    """
    return net


def get_training_dataloader(mean, std, batch_size=16, num_workers=2, shuffle=True):
    """ return training dataloader
    Args:
        mean: mean of CIFAR10 training dataset
        std: std of CIFAR10 training dataset
        path: path to CIFAR10 training python dataset
        batch_size: dataloader batchsize
        num_workers: dataloader num_works
        shuffle: whether to shuffle 
    Returns: train_data_loader:torch dataloader object
    """

    transform_train = transforms.Compose([
        #transforms.ToPILImage(),
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
    #CIFAR10_training = CIFAR10Train(path, transform=transform_train)
    CIFAR10_training = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
    CIFAR10_training_loader = DataLoader(
        CIFAR10_training, shuffle=shuffle, num_workers=num_workers, batch_size=batch_size)

    return CIFAR10_training_loader

def get_test_dataloader(mean, std, batch_size=16, num_workers=2, shuffle=True):
    """ return training dataloader
    Args:
        mean: mean of CIFAR10 test dataset
        std: std of CIFAR10 test dataset
        path: path to CIFAR10 test python dataset
        batch_size: dataloader batchsize
        num_workers: dataloader num_works
        shuffle: whether to shuffle 
    Returns: CIFAR10_test_loader:torch dataloader object
    """

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
    #CIFAR10_test = CIFAR10Test(path, transform=transform_test)
    CIFAR10_test = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
    CIFAR10_test_loader = DataLoader(
        CIFAR10_test, shuffle=shuffle, num_workers=num_workers, batch_size=batch_size)

    return CIFAR10_test_loader

def compute_mean_std(CIFAR10_dataset):
    """compute the mean and std of CIFAR10 dataset
    Args:
        CIFAR10_training_dataset or CIFAR10_test_dataset
        witch derived from class torch.utils.data
    
    Returns:
        a tuple contains mean, std value of entire dataset
    """

    data_r = numpy.dstack([CIFAR10_dataset[i][1][:, :, 0] for i in range(len(CIFAR10_dataset))])
    data_g = numpy.dstack([CIFAR10_dataset[i][1][:, :, 1] for i in range(len(CIFAR10_dataset))])
    data_b = numpy.dstack([CIFAR10_dataset[i][1][:, :, 2] for i in range(len(CIFAR10_dataset))])
    mean = numpy.mean(data_r), numpy.mean(data_g), numpy.mean(data_b)
    std = numpy.std(data_r), numpy.std(data_g), numpy.std(data_b)

    return mean, std

class WarmUpLR(_LRScheduler):
    """warmup_training learning rate scheduler
    Args:
        optimizer: optimzier(e.g. SGD)
        total_iters: totoal_iters of warmup phase
    """
    def __init__(self, optimizer, total_iters, last_epoch=-1):
        
        self.total_iters = total_iters
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        """we will use the first m batches, and set the learning
        rate to base_lr * m / total_iters
        """
        return [base_lr * self.last_epoch / (self.total_iters + 1e-8) for base_lr in self.base_lrs]

# %%
from datetime import datetime
CIFAR10_TRAIN_MEAN = (0.49139968, 0.48215827 ,0.44653124)
CIFAR10_TRAIN_STD = (0.24703233, 0.24348505, 0.26158768)

#CIFAR100_TEST_MEAN = (0.5088964127604166, 0.48739301317401956, 0.44194221124387256)
#CIFAR100_TEST_STD = (0.2682515741720801, 0.2573637364478126, 0.2770957707973042)

#directory to save weights file
CHECKPOINT_PATH = 'checkpoint'

#total training epoches
EPOCH = 25
MILESTONES = [6, 12, 16]

#initial learning rate
#INIT_LR = 0.1

#time of we run the script
TIME_NOW = datetime.now().isoformat()

#tensorboard log dir
LOG_DIR = 'runs'

#save weights file per SAVE_EPOCH epoch
SAVE_EPOCH = 10

# %% [markdown]
# ## Training the model

# %%
def train(epoch):

    net.train()
    for batch_index, (images, labels) in enumerate(CIFAR10_training_loader):
        if epoch <= 1:
            warmup_scheduler.step()

        images = Variable(images)
        labels = Variable(labels)

        labels = labels.cuda()
        images = images.cuda()

        optimizer.zero_grad()
        outputs = net(images)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()

        print('Training Epoch: {epoch} [{trained_samples}/{total_samples}]\tLoss: {:0.4f}\tLR: {:0.6f}'.format(
            loss.item(),
            optimizer.param_groups[0]['lr'],
            epoch=epoch,
            trained_samples=batch_index * 128 + len(images),
            total_samples=len(CIFAR10_training_loader.dataset)
        ))


    for name, param in net.named_parameters():
        layer, attr = os.path.splitext(name)
        attr = attr[1:]

def eval_training(epoch):
    net.eval()

    test_loss = 0.0 # cost function error
    correct = 0.0

    for (images, labels) in CIFAR10_test_loader:
        images = Variable(images)
        labels = Variable(labels)

        images = images.cuda()
        labels = labels.cuda()

        outputs = net(images)
        loss = loss_function(outputs, labels)
        test_loss += loss.item()
        _, preds = outputs.max(1)
        correct += preds.eq(labels).sum()

    print('Test set: Average loss: {:.4f}, Accuracy: {:.4f}'.format(
        test_loss / len(CIFAR10_test_loader.dataset),
        correct.float() / len(CIFAR10_test_loader.dataset)
    ))
    print()


    return correct.float() / len(CIFAR10_test_loader.dataset)

if __name__ == '__main__':
    
#     parser = argparse.ArgumentParser()
#     parser.add_argument('-net', type=str, required=True, help='net type')
#     parser.add_argument('-gpu', type=bool, default=True, help='use gpu or not')
#     parser.add_argument('-w', type=int, default=2, help='number of workers for dataloader')
#     parser.add_argument('-b', type=int, default=128, help='batch size for dataloader')
#     parser.add_argument('-s', type=bool, default=True, help='whether shuffle the dataset')
#     parser.add_argument('-warm', type=int, default=1, help='warm up training phase')
#     parser.add_argument('-lr', type=float, default=0.1, help='initial learning rate')
#     args = parser.parse_args()

    net= get_network()
    
        
    #data preprocessing:
    CIFAR10_training_loader = get_training_dataloader(
        CIFAR10_TRAIN_MEAN,
        CIFAR10_TRAIN_STD,
        num_workers=2,
        batch_size=128,
        shuffle=True
    )
    
    CIFAR10_test_loader = get_test_dataloader(
        CIFAR10_TRAIN_MEAN,
        CIFAR10_TRAIN_STD,
        num_workers=2,
        batch_size=128,
        shuffle=True
    )
    
    loss_function = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
    train_scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=MILESTONES, gamma=0.15) #learning rate decay
    iter_per_epoch = len(CIFAR10_training_loader)
    warmup_scheduler = WarmUpLR(optimizer, iter_per_epoch * 1)
    checkpoint_path = os.path.join(CHECKPOINT_PATH, "resnetcbam18")

    #create checkpoint folder to save model
    if not os.path.exists(checkpoint_path):
        os.makedirs(checkpoint_path)
    checkpoint_path = os.path.join(checkpoint_path, '{net}-{epoch}-{type}.pth')

    best_acc = 0.0
    for epoch in range(1, EPOCH):
        if epoch > 1:
            train_scheduler.step(epoch)

        train(epoch)
        acc = eval_training(epoch)

        #start to save best performance model after learning rate decay to 0.01 
        if epoch > MILESTONES[1] and best_acc < acc:
            torch.save(net.state_dict(), checkpoint_path.format(net="resnetcbam18", epoch=epoch, type='best'))
            best_acc = acc
            continue

        if not epoch % SAVE_EPOCH:
            torch.save(net.state_dict(), checkpoint_path.format(net="resnetcbam18", epoch=epoch, type='regular'))
    print()
    print("best_acc: ", best_acc)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 53830324.99it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Training Epoch: 1 [128/50000]	Loss: 2.3185	LR: 0.000256
# Training Epoch: 1 [256/50000]	Loss: 2.3504	LR: 0.000512
# Training Epoch: 1 [384/50000]	Loss: 2.3393	LR: 0.000767
# Training Epoch: 1 [512/50000]	Loss: 2.3447	LR: 0.001023
# Training Epoch: 1 [640/50000]	Loss: 2.3044	LR: 0.001279
# Training Epoch: 1 [768/50000]	Loss: 2.3667	LR: 0.001535
# Training Epoch: 1 [896/50000]	Loss: 2.2981	LR: 0.001790
# Training Epoch: 1 [1024/50000]	Loss: 2.3132	LR: 0.002046
# Training Epoch: 1 [1152/50000]	Loss: 2.2709	LR: 0.002302
# Training Epoch: 1 [1280/50000]	Loss: 2.2890	LR: 0.002558
# Training Epoch: 1 [1408/50000]	Loss: 2.2902	LR: 0.002813
# Training Epoch: 1 [1536/50000]	Loss: 2.2579	LR: 0.003069
# Training Epoch: 1 [1664/50000]	Loss: 2.2594	LR: 0.003325
# Training Epoch: 1 [1792/50000]	Loss: 2.2142	LR: 0.003581
# Training Epoch: 1 [1920/50000]	Loss: 2.2171	LR: 0.003836
# Training Epoch: 1 [2048/50000]	Loss: 2.1762	LR: 0.004092
# Training Epoch: 1 [2176/50000]	Loss: 2.1918	LR: 0.004348
# Training Epoch: 1 [2304/50000]	Loss: 2.1889	LR: 0.004604
# Training Epoch: 1 [2432/50000]	Loss: 2.1856	LR: 0.004859
# Training Epoch: 1 [2560/50000]	Loss: 2.1926	LR: 0.005115
# Training Epoch: 1 [2688/50000]	Loss: 2.1137	LR: 0.005371
# Training Epoch: 1 [2816/50000]	Loss: 2.2098	LR: 0.005627
# Training Epoch: 1 [2944/50000]	Loss: 2.1285	LR: 0.005882
# Training Epoch: 1 [3072/50000]	Loss: 2.0991	LR: 0.006138
# Training Epoch: 1 [3200/50000]	Loss: 2.1074	LR: 0.006394
# Training Epoch: 1 [3328/50000]	Loss: 2.0745	LR: 0.006650
# Training Epoch: 1 [3456/50000]	Loss: 2.1906	LR: 0.006905
# Training Epoch: 1 [3584/50000]	Loss: 2.1117	LR: 0.007161
# Training Epoch: 1 [3712/50000]	Loss: 2.1803	LR: 0.007417
# Training Epoch: 1 [3840/50000]	Loss: 2.0618	LR: 0.007673
# Training Epoch: 1 [3968/50000]	Loss: 2.1575	LR: 0.007928
# Training Epoch: 1 [4096/50000]	Loss: 2.0457	LR: 0.008184
# Training Epoch: 1 [4224/50000]	Loss: 1.8656	LR: 0.008440
# Training Epoch: 1 [4352/50000]	Loss: 2.0162	LR: 0.008696
# Training Epoch: 1 [4480/50000]	Loss: 2.0616	LR: 0.008951
# Training Epoch: 1 [4608/50000]	Loss: 2.1000	LR: 0.009207
# Training Epoch: 1 [4736/50000]	Loss: 2.0159	LR: 0.009463
# Training Epoch: 1 [4864/50000]	Loss: 1.9167	LR: 0.009719
# Training Epoch: 1 [4992/50000]	Loss: 1.9762	LR: 0.009974
# Training Epoch: 1 [5120/50000]	Loss: 1.9368	LR: 0.010230
# Training Epoch: 1 [5248/50000]	Loss: 2.0072	LR: 0.010486
# Training Epoch: 1 [5376/50000]	Loss: 2.0100	LR: 0.010742
# Training Epoch: 1 [5504/50000]	Loss: 1.9110	LR: 0.010997
# Training Epoch: 1 [5632/50000]	Loss: 1.8371	LR: 0.011253
# Training Epoch: 1 [5760/50000]	Loss: 1.9305	LR: 0.011509
# Training Epoch: 1 [5888/50000]	Loss: 1.8868	LR: 0.011765
# Training Epoch: 1 [6016/50000]	Loss: 1.8419	LR: 0.012020
# Training Epoch: 1 [6144/50000]	Loss: 1.9662	LR: 0.012276
# Training Epoch: 1 [6272/50000]	Loss: 1.8571	LR: 0.012532
# Training Epoch: 1 [6400/50000]	Loss: 1.7007	LR: 0.012788
# Training Epoch: 1 [6528/50000]	Loss: 1.8553	LR: 0.013043
# Training Epoch: 1 [6656/50000]	Loss: 1.8079	LR: 0.013299
# Training Epoch: 1 [6784/50000]	Loss: 1.8203	LR: 0.013555
# Training Epoch: 1 [6912/50000]	Loss: 1.8063	LR: 0.013811
# Training Epoch: 1 [7040/50000]	Loss: 1.7992	LR: 0.014066
# Training Epoch: 1 [7168/50000]	Loss: 1.7394	LR: 0.014322
# Training Epoch: 1 [7296/50000]	Loss: 1.8780	LR: 0.014578
# Training Epoch: 1 [7424/50000]	Loss: 1.8008	LR: 0.014834
# Training Epoch: 1 [7552/50000]	Loss: 2.0015	LR: 0.015090
# Training Epoch: 1 [7680/50000]	Loss: 1.7983	LR: 0.015345
# Training Epoch: 1 [7808/50000]	Loss: 1.6945	LR: 0.015601
# Training Epoch: 1 [7936/50000]	Loss: 1.8310	LR: 0.015857
# Training Epoch: 1 [8064/50000]	Loss: 1.7290	LR: 0.016113
# Training Epoch: 1 [8192/50000]	Loss: 1.9138	LR: 0.016368
# Training Epoch: 1 [8320/50000]	Loss: 1.8136	LR: 0.016624
# Training Epoch: 1 [8448/50000]	Loss: 1.7538	LR: 0.016880
# Training Epoch: 1 [8576/50000]	Loss: 1.8049	LR: 0.017136
# Training Epoch: 1 [8704/50000]	Loss: 1.7035	LR: 0.017391
# Training Epoch: 1 [8832/50000]	Loss: 2.1018	LR: 0.017647
# Training Epoch: 1 [8960/50000]	Loss: 1.8827	LR: 0.017903
# Training Epoch: 1 [9088/50000]	Loss: 1.7976	LR: 0.018159
# Training Epoch: 1 [9216/50000]	Loss: 1.6812	LR: 0.018414
# Training Epoch: 1 [9344/50000]	Loss: 1.8311	LR: 0.018670
# Training Epoch: 1 [9472/50000]	Loss: 2.0419	LR: 0.018926
# Training Epoch: 1 [9600/50000]	Loss: 1.9808	LR: 0.019182
# Training Epoch: 1 [9728/50000]	Loss: 1.9414	LR: 0.019437
# Training Epoch: 1 [9856/50000]	Loss: 1.7805	LR: 0.019693
# Training Epoch: 1 [9984/50000]	Loss: 1.7817	LR: 0.019949
# Training Epoch: 1 [10112/50000]	Loss: 1.7841	LR: 0.020205
# Training Epoch: 1 [10240/50000]	Loss: 1.9758	LR: 0.020460
# Training Epoch: 1 [10368/50000]	Loss: 1.8123	LR: 0.020716
# Training Epoch: 1 [10496/50000]	Loss: 1.7822	LR: 0.020972
# Training Epoch: 1 [10624/50000]	Loss: 1.8214	LR: 0.021228
# Training Epoch: 1 [10752/50000]	Loss: 1.8704	LR: 0.021483
# Training Epoch: 1 [10880/50000]	Loss: 1.7230	LR: 0.021739
# Training Epoch: 1 [11008/50000]	Loss: 1.7965	LR: 0.021995
# Training Epoch: 1 [11136/50000]	Loss: 1.7790	LR: 0.022251
# Training Epoch: 1 [11264/50000]	Loss: 1.7875	LR: 0.022506
# Training Epoch: 1 [11392/50000]	Loss: 1.7268	LR: 0.022762
# Training Epoch: 1 [11520/50000]	Loss: 1.8092	LR: 0.023018
# Training Epoch: 1 [11648/50000]	Loss: 1.7239	LR: 0.023274
# Training Epoch: 1 [11776/50000]	Loss: 1.7677	LR: 0.023529
# Training Epoch: 1 [11904/50000]	Loss: 1.7536	LR: 0.023785
# Training Epoch: 1 [12032/50000]	Loss: 1.6386	LR: 0.024041
# Training Epoch: 1 [12160/50000]	Loss: 1.7529	LR: 0.024297
# Training Epoch: 1 [12288/50000]	Loss: 1.6766	LR: 0.024552
# Training Epoch: 1 [12416/50000]	Loss: 1.6759	LR: 0.024808
# Training Epoch: 1 [12544/50000]	Loss: 1.8502	LR: 0.025064
# Training Epoch: 1 [12672/50000]	Loss: 1.6310	LR: 0.025320
# Training Epoch: 1 [12800/50000]	Loss: 1.5766	LR: 0.025575
# Training Epoch: 1 [12928/50000]	Loss: 1.6564	LR: 0.025831
# Training Epoch: 1 [13056/50000]	Loss: 1.7351	LR: 0.026087
# Training Epoch: 1 [13184/50000]	Loss: 1.7821	LR: 0.026343
# Training Epoch: 1 [13312/50000]	Loss: 1.8613	LR: 0.026598
# Training Epoch: 1 [13440/50000]	Loss: 1.7091	LR: 0.026854
# Training Epoch: 1 [13568/50000]	Loss: 1.8172	LR: 0.027110
# Training Epoch: 1 [13696/50000]	Loss: 1.7446	LR: 0.027366
# Training Epoch: 1 [13824/50000]	Loss: 1.7886	LR: 0.027621
# Training Epoch: 1 [13952/50000]	Loss: 1.7570	LR: 0.027877
# Training Epoch: 1 [14080/50000]	Loss: 1.6649	LR: 0.028133
# Training Epoch: 1 [14208/50000]	Loss: 1.6113	LR: 0.028389
# Training Epoch: 1 [14336/50000]	Loss: 1.7142	LR: 0.028645
# Training Epoch: 1 [14464/50000]	Loss: 1.5519	LR: 0.028900
# Training Epoch: 1 [14592/50000]	Loss: 1.5981	LR: 0.029156
# Training Epoch: 1 [14720/50000]	Loss: 1.6837	LR: 0.029412
# Training Epoch: 1 [14848/50000]	Loss: 1.6031	LR: 0.029668
# Training Epoch: 1 [14976/50000]	Loss: 1.6718	LR: 0.029923
# Training Epoch: 1 [15104/50000]	Loss: 1.7937	LR: 0.030179
# Training Epoch: 1 [15232/50000]	Loss: 1.5919	LR: 0.030435
# Training Epoch: 1 [15360/50000]	Loss: 1.8419	LR: 0.030691
# Training Epoch: 1 [15488/50000]	Loss: 1.7399	LR: 0.030946
# Training Epoch: 1 [15616/50000]	Loss: 1.6896	LR: 0.031202
# Training Epoch: 1 [15744/50000]	Loss: 1.5245	LR: 0.031458
# Training Epoch: 1 [15872/50000]	Loss: 1.6678	LR: 0.031714
# Training Epoch: 1 [16000/50000]	Loss: 1.7197	LR: 0.031969
# Training Epoch: 1 [16128/50000]	Loss: 1.5491	LR: 0.032225
# Training Epoch: 1 [16256/50000]	Loss: 1.5870	LR: 0.032481
# Training Epoch: 1 [16384/50000]	Loss: 1.5485	LR: 0.032737
# Training Epoch: 1 [16512/50000]	Loss: 1.6692	LR: 0.032992
# Training Epoch: 1 [16640/50000]	Loss: 1.5340	LR: 0.033248
# Training Epoch: 1 [16768/50000]	Loss: 1.5398	LR: 0.033504
# Training Epoch: 1 [16896/50000]	Loss: 1.5920	LR: 0.033760
# Training Epoch: 1 [17024/50000]	Loss: 1.5840	LR: 0.034015
# Training Epoch: 1 [17152/50000]	Loss: 1.6163	LR: 0.034271
# Training Epoch: 1 [17280/50000]	Loss: 1.5423	LR: 0.034527
# Training Epoch: 1 [17408/50000]	Loss: 1.5593	LR: 0.034783
# Training Epoch: 1 [17536/50000]	Loss: 1.6265	LR: 0.035038
# Training Epoch: 1 [17664/50000]	Loss: 1.6313	LR: 0.035294
# Training Epoch: 1 [17792/50000]	Loss: 1.5008	LR: 0.035550
# Training Epoch: 1 [17920/50000]	Loss: 1.6070	LR: 0.035806
# Training Epoch: 1 [18048/50000]	Loss: 1.7031	LR: 0.036061
# Training Epoch: 1 [18176/50000]	Loss: 1.5962	LR: 0.036317
# Training Epoch: 1 [18304/50000]	Loss: 1.6451	LR: 0.036573
# Training Epoch: 1 [18432/50000]	Loss: 1.5108	LR: 0.036829
# Training Epoch: 1 [18560/50000]	Loss: 1.6461	LR: 0.037084
# Training Epoch: 1 [18688/50000]	Loss: 1.5402	LR: 0.037340
# Training Epoch: 1 [18816/50000]	Loss: 1.5840	LR: 0.037596
# Training Epoch: 1 [18944/50000]	Loss: 1.5554	LR: 0.037852
# Training Epoch: 1 [19072/50000]	Loss: 1.6751	LR: 0.038107
# Training Epoch: 1 [19200/50000]	Loss: 1.5018	LR: 0.038363
# Training Epoch: 1 [19328/50000]	Loss: 1.5201	LR: 0.038619
# Training Epoch: 1 [19456/50000]	Loss: 1.6450	LR: 0.038875
# Training Epoch: 1 [19584/50000]	Loss: 1.8452	LR: 0.039130
# Training Epoch: 1 [19712/50000]	Loss: 1.6983	LR: 0.039386
# Training Epoch: 1 [19840/50000]	Loss: 1.8243	LR: 0.039642
# Training Epoch: 1 [19968/50000]	Loss: 1.5096	LR: 0.039898
# Training Epoch: 1 [20096/50000]	Loss: 1.6111	LR: 0.040153
# Training Epoch: 1 [20224/50000]	Loss: 1.5799	LR: 0.040409
# Training Epoch: 1 [20352/50000]	Loss: 1.5721	LR: 0.040665
# Training Epoch: 1 [20480/50000]	Loss: 1.5444	LR: 0.040921
# Training Epoch: 1 [20608/50000]	Loss: 1.8886	LR: 0.041176
# Training Epoch: 1 [20736/50000]	Loss: 1.5544	LR: 0.041432
# Training Epoch: 1 [20864/50000]	Loss: 1.7725	LR: 0.041688
# Training Epoch: 1 [20992/50000]	Loss: 1.5757	LR: 0.041944
# Training Epoch: 1 [21120/50000]	Loss: 1.4805	LR: 0.042199
# Training Epoch: 1 [21248/50000]	Loss: 1.6055	LR: 0.042455
# Training Epoch: 1 [21376/50000]	Loss: 1.6072	LR: 0.042711
# Training Epoch: 1 [21504/50000]	Loss: 1.6000	LR: 0.042967
# Training Epoch: 1 [21632/50000]	Loss: 1.5619	LR: 0.043223
# Training Epoch: 1 [21760/50000]	Loss: 1.5121	LR: 0.043478
# Training Epoch: 1 [21888/50000]	Loss: 1.6533	LR: 0.043734
# Training Epoch: 1 [22016/50000]	Loss: 1.5491	LR: 0.043990
# Training Epoch: 1 [22144/50000]	Loss: 1.6200	LR: 0.044246
# Training Epoch: 1 [22272/50000]	Loss: 1.7775	LR: 0.044501
# Training Epoch: 1 [22400/50000]	Loss: 1.6936	LR: 0.044757
# Training Epoch: 1 [22528/50000]	Loss: 1.6705	LR: 0.045013
# Training Epoch: 1 [22656/50000]	Loss: 1.6162	LR: 0.045269
# Training Epoch: 1 [22784/50000]	Loss: 1.7482	LR: 0.045524
# Training Epoch: 1 [22912/50000]	Loss: 1.6726	LR: 0.045780
# Training Epoch: 1 [23040/50000]	Loss: 1.5267	LR: 0.046036
# Training Epoch: 1 [23168/50000]	Loss: 1.4542	LR: 0.046292
# Training Epoch: 1 [23296/50000]	Loss: 1.6271	LR: 0.046547
# Training Epoch: 1 [23424/50000]	Loss: 1.5876	LR: 0.046803
# Training Epoch: 1 [23552/50000]	Loss: 1.6978	LR: 0.047059
# Training Epoch: 1 [23680/50000]	Loss: 1.5798	LR: 0.047315
# Training Epoch: 1 [23808/50000]	Loss: 1.4994	LR: 0.047570
# Training Epoch: 1 [23936/50000]	Loss: 1.7611	LR: 0.047826
# Training Epoch: 1 [24064/50000]	Loss: 1.7327	LR: 0.048082
# Training Epoch: 1 [24192/50000]	Loss: 1.5862	LR: 0.048338
# Training Epoch: 1 [24320/50000]	Loss: 1.6822	LR: 0.048593
# Training Epoch: 1 [24448/50000]	Loss: 1.5806	LR: 0.048849
# Training Epoch: 1 [24576/50000]	Loss: 1.6509	LR: 0.049105
# Training Epoch: 1 [24704/50000]	Loss: 1.5835	LR: 0.049361
# Training Epoch: 1 [24832/50000]	Loss: 1.5550	LR: 0.049616
# Training Epoch: 1 [24960/50000]	Loss: 1.6962	LR: 0.049872
# Training Epoch: 1 [25088/50000]	Loss: 1.4348	LR: 0.050128
# Training Epoch: 1 [25216/50000]	Loss: 1.5658	LR: 0.050384
# Training Epoch: 1 [25344/50000]	Loss: 1.7424	LR: 0.050639
# Training Epoch: 1 [25472/50000]	Loss: 1.5529	LR: 0.050895
# Training Epoch: 1 [25600/50000]	Loss: 1.5949	LR: 0.051151
# Training Epoch: 1 [25728/50000]	Loss: 1.4799	LR: 0.051407
# Training Epoch: 1 [25856/50000]	Loss: 1.4843	LR: 0.051662
# Training Epoch: 1 [25984/50000]	Loss: 1.3692	LR: 0.051918
# Training Epoch: 1 [26112/50000]	Loss: 1.3953	LR: 0.052174
# Training Epoch: 1 [26240/50000]	Loss: 1.5364	LR: 0.052430
# Training Epoch: 1 [26368/50000]	Loss: 1.5404	LR: 0.052685
# Training Epoch: 1 [26496/50000]	Loss: 1.5554	LR: 0.052941
# Training Epoch: 1 [26624/50000]	Loss: 1.6068	LR: 0.053197
# Training Epoch: 1 [26752/50000]	Loss: 1.3637	LR: 0.053453
# Training Epoch: 1 [26880/50000]	Loss: 1.5657	LR: 0.053708
# Training Epoch: 1 [27008/50000]	Loss: 1.5676	LR: 0.053964
# Training Epoch: 1 [27136/50000]	Loss: 1.7566	LR: 0.054220
# Training Epoch: 1 [27264/50000]	Loss: 1.5220	LR: 0.054476
# Training Epoch: 1 [27392/50000]	Loss: 1.6557	LR: 0.054731
# Training Epoch: 1 [27520/50000]	Loss: 1.5446	LR: 0.054987
# Training Epoch: 1 [27648/50000]	Loss: 1.4772	LR: 0.055243
# Training Epoch: 1 [27776/50000]	Loss: 1.4668	LR: 0.055499
# Training Epoch: 1 [27904/50000]	Loss: 1.6594	LR: 0.055754
# Training Epoch: 1 [28032/50000]	Loss: 1.4979	LR: 0.056010
# Training Epoch: 1 [28160/50000]	Loss: 1.5953	LR: 0.056266
# Training Epoch: 1 [28288/50000]	Loss: 1.5862	LR: 0.056522
# Training Epoch: 1 [28416/50000]	Loss: 1.5646	LR: 0.056777
# Training Epoch: 1 [28544/50000]	Loss: 1.4271	LR: 0.057033
# Training Epoch: 1 [28672/50000]	Loss: 1.6150	LR: 0.057289
# Training Epoch: 1 [28800/50000]	Loss: 1.3554	LR: 0.057545
# Training Epoch: 1 [28928/50000]	Loss: 1.5170	LR: 0.057801
# Training Epoch: 1 [29056/50000]	Loss: 1.6108	LR: 0.058056
# Training Epoch: 1 [29184/50000]	Loss: 1.6210	LR: 0.058312
# Training Epoch: 1 [29312/50000]	Loss: 1.5080	LR: 0.058568
# Training Epoch: 1 [29440/50000]	Loss: 1.5125	LR: 0.058824
# Training Epoch: 1 [29568/50000]	Loss: 1.6079	LR: 0.059079
# Training Epoch: 1 [29696/50000]	Loss: 1.2850	LR: 0.059335
# Training Epoch: 1 [29824/50000]	Loss: 1.5444	LR: 0.059591
# Training Epoch: 1 [29952/50000]	Loss: 1.7316	LR: 0.059847
# Training Epoch: 1 [30080/50000]	Loss: 1.6452	LR: 0.060102
# Training Epoch: 1 [30208/50000]	Loss: 1.4177	LR: 0.060358
# Training Epoch: 1 [30336/50000]	Loss: 1.4460	LR: 0.060614
# Training Epoch: 1 [30464/50000]	Loss: 1.3852	LR: 0.060870
# Training Epoch: 1 [30592/50000]	Loss: 1.5261	LR: 0.061125
# Training Epoch: 1 [30720/50000]	Loss: 1.3825	LR: 0.061381
# Training Epoch: 1 [30848/50000]	Loss: 1.5855	LR: 0.061637
# Training Epoch: 1 [30976/50000]	Loss: 1.5677	LR: 0.061893
# Training Epoch: 1 [31104/50000]	Loss: 1.4514	LR: 0.062148
# Training Epoch: 1 [31232/50000]	Loss: 1.4552	LR: 0.062404
# Training Epoch: 1 [31360/50000]	Loss: 1.4095	LR: 0.062660
# Training Epoch: 1 [31488/50000]	Loss: 1.4853	LR: 0.062916
# Training Epoch: 1 [31616/50000]	Loss: 1.7024	LR: 0.063171
# Training Epoch: 1 [31744/50000]	Loss: 1.6733	LR: 0.063427
# Training Epoch: 1 [31872/50000]	Loss: 1.6075	LR: 0.063683
# Training Epoch: 1 [32000/50000]	Loss: 1.4226	LR: 0.063939
# Training Epoch: 1 [32128/50000]	Loss: 1.4400	LR: 0.064194
# Training Epoch: 1 [32256/50000]	Loss: 1.5154	LR: 0.064450
# Training Epoch: 1 [32384/50000]	Loss: 1.3185	LR: 0.064706
# Training Epoch: 1 [32512/50000]	Loss: 1.3845	LR: 0.064962
# Training Epoch: 1 [32640/50000]	Loss: 1.3997	LR: 0.065217
# Training Epoch: 1 [32768/50000]	Loss: 1.4467	LR: 0.065473
# Training Epoch: 1 [32896/50000]	Loss: 1.5878	LR: 0.065729
# Training Epoch: 1 [33024/50000]	Loss: 1.4761	LR: 0.065985
# Training Epoch: 1 [33152/50000]	Loss: 1.5168	LR: 0.066240
# Training Epoch: 1 [33280/50000]	Loss: 1.5597	LR: 0.066496
# Training Epoch: 1 [33408/50000]	Loss: 1.3898	LR: 0.066752
# Training Epoch: 1 [33536/50000]	Loss: 1.3869	LR: 0.067008
# Training Epoch: 1 [33664/50000]	Loss: 1.5301	LR: 0.067263
# Training Epoch: 1 [33792/50000]	Loss: 1.5900	LR: 0.067519
# Training Epoch: 1 [33920/50000]	Loss: 1.5361	LR: 0.067775
# Training Epoch: 1 [34048/50000]	Loss: 1.4829	LR: 0.068031
# Training Epoch: 1 [34176/50000]	Loss: 1.3309	LR: 0.068286
# Training Epoch: 1 [34304/50000]	Loss: 1.4049	LR: 0.068542
# Training Epoch: 1 [34432/50000]	Loss: 1.6726	LR: 0.068798
# Training Epoch: 1 [34560/50000]	Loss: 1.4792	LR: 0.069054
# Training Epoch: 1 [34688/50000]	Loss: 1.5473	LR: 0.069309
# Training Epoch: 1 [34816/50000]	Loss: 1.8357	LR: 0.069565
# Training Epoch: 1 [34944/50000]	Loss: 1.3629	LR: 0.069821
# Training Epoch: 1 [35072/50000]	Loss: 1.5708	LR: 0.070077
# Training Epoch: 1 [35200/50000]	Loss: 1.4153	LR: 0.070332
# Training Epoch: 1 [35328/50000]	Loss: 1.7075	LR: 0.070588
# Training Epoch: 1 [35456/50000]	Loss: 1.4108	LR: 0.070844
# Training Epoch: 1 [35584/50000]	Loss: 1.6768	LR: 0.071100
# Training Epoch: 1 [35712/50000]	Loss: 1.3220	LR: 0.071355
# Training Epoch: 1 [35840/50000]	Loss: 1.4047	LR: 0.071611
# Training Epoch: 1 [35968/50000]	Loss: 1.3836	LR: 0.071867
# Training Epoch: 1 [36096/50000]	Loss: 1.5291	LR: 0.072123
# Training Epoch: 1 [36224/50000]	Loss: 1.3933	LR: 0.072379
# Training Epoch: 1 [36352/50000]	Loss: 1.5028	LR: 0.072634
# Training Epoch: 1 [36480/50000]	Loss: 1.5526	LR: 0.072890
# Training Epoch: 1 [36608/50000]	Loss: 1.7219	LR: 0.073146
# Training Epoch: 1 [36736/50000]	Loss: 1.4986	LR: 0.073402
# Training Epoch: 1 [36864/50000]	Loss: 1.4751	LR: 0.073657
# Training Epoch: 1 [36992/50000]	Loss: 1.5336	LR: 0.073913
# Training Epoch: 1 [37120/50000]	Loss: 1.5117	LR: 0.074169
# Training Epoch: 1 [37248/50000]	Loss: 1.5863	LR: 0.074425
# Training Epoch: 1 [37376/50000]	Loss: 1.3627	LR: 0.074680
# Training Epoch: 1 [37504/50000]	Loss: 1.3036	LR: 0.074936
# Training Epoch: 1 [37632/50000]	Loss: 1.4830	LR: 0.075192
# Training Epoch: 1 [37760/50000]	Loss: 1.2281	LR: 0.075448
# Training Epoch: 1 [37888/50000]	Loss: 1.4009	LR: 0.075703
# Training Epoch: 1 [38016/50000]	Loss: 1.3680	LR: 0.075959
# Training Epoch: 1 [38144/50000]	Loss: 1.4087	LR: 0.076215
# Training Epoch: 1 [38272/50000]	Loss: 1.2186	LR: 0.076471
# Training Epoch: 1 [38400/50000]	Loss: 1.3479	LR: 0.076726
# Training Epoch: 1 [38528/50000]	Loss: 1.2697	LR: 0.076982
# Training Epoch: 1 [38656/50000]	Loss: 1.2856	LR: 0.077238
# Training Epoch: 1 [38784/50000]	Loss: 1.4350	LR: 0.077494
# Training Epoch: 1 [38912/50000]	Loss: 1.4277	LR: 0.077749
# Training Epoch: 1 [39040/50000]	Loss: 1.3033	LR: 0.078005
# Training Epoch: 1 [39168/50000]	Loss: 1.6478	LR: 0.078261
# Training Epoch: 1 [39296/50000]	Loss: 1.5213	LR: 0.078517
# Training Epoch: 1 [39424/50000]	Loss: 1.2555	LR: 0.078772
# Training Epoch: 1 [39552/50000]	Loss: 1.2863	LR: 0.079028
# Training Epoch: 1 [39680/50000]	Loss: 1.4653	LR: 0.079284
# Training Epoch: 1 [39808/50000]	Loss: 1.4554	LR: 0.079540
# Training Epoch: 1 [39936/50000]	Loss: 1.4546	LR: 0.079795
# Training Epoch: 1 [40064/50000]	Loss: 1.2107	LR: 0.080051
# Training Epoch: 1 [40192/50000]	Loss: 1.7043	LR: 0.080307
# Training Epoch: 1 [40320/50000]	Loss: 1.2946	LR: 0.080563
# Training Epoch: 1 [40448/50000]	Loss: 1.3744	LR: 0.080818
# Training Epoch: 1 [40576/50000]	Loss: 1.6740	LR: 0.081074
# Training Epoch: 1 [40704/50000]	Loss: 1.5135	LR: 0.081330
# Training Epoch: 1 [40832/50000]	Loss: 1.3654	LR: 0.081586
# Training Epoch: 1 [40960/50000]	Loss: 1.5219	LR: 0.081841
# Training Epoch: 1 [41088/50000]	Loss: 1.6025	LR: 0.082097
# Training Epoch: 1 [41216/50000]	Loss: 1.4704	LR: 0.082353
# Training Epoch: 1 [41344/50000]	Loss: 1.4649	LR: 0.082609
# Training Epoch: 1 [41472/50000]	Loss: 1.5454	LR: 0.082864
# Training Epoch: 1 [41600/50000]	Loss: 1.5784	LR: 0.083120
# Training Epoch: 1 [41728/50000]	Loss: 1.5240	LR: 0.083376
# Training Epoch: 1 [41856/50000]	Loss: 1.4210	LR: 0.083632
# Training Epoch: 1 [41984/50000]	Loss: 1.5716	LR: 0.083887
# Training Epoch: 1 [42112/50000]	Loss: 1.4809	LR: 0.084143
# Training Epoch: 1 [42240/50000]	Loss: 1.3252	LR: 0.084399
# Training Epoch: 1 [42368/50000]	Loss: 1.3209	LR: 0.084655
# Training Epoch: 1 [42496/50000]	Loss: 1.4005	LR: 0.084910
# Training Epoch: 1 [42624/50000]	Loss: 1.4601	LR: 0.085166
# Training Epoch: 1 [42752/50000]	Loss: 1.4968	LR: 0.085422
# Training Epoch: 1 [42880/50000]	Loss: 1.3409	LR: 0.085678
# Training Epoch: 1 [43008/50000]	Loss: 1.5093	LR: 0.085934
# Training Epoch: 1 [43136/50000]	Loss: 1.5745	LR: 0.086189
# Training Epoch: 1 [43264/50000]	Loss: 1.6550	LR: 0.086445
# Training Epoch: 1 [43392/50000]	Loss: 1.7181	LR: 0.086701
# Training Epoch: 1 [43520/50000]	Loss: 1.5826	LR: 0.086957
# Training Epoch: 1 [43648/50000]	Loss: 1.3570	LR: 0.087212
# Training Epoch: 1 [43776/50000]	Loss: 1.4549	LR: 0.087468
# Training Epoch: 1 [43904/50000]	Loss: 1.5953	LR: 0.087724
# Training Epoch: 1 [44032/50000]	Loss: 1.4576	LR: 0.087980
# Training Epoch: 1 [44160/50000]	Loss: 1.4233	LR: 0.088235
# Training Epoch: 1 [44288/50000]	Loss: 1.5637	LR: 0.088491
# Training Epoch: 1 [44416/50000]	Loss: 1.5570	LR: 0.088747
# Training Epoch: 1 [44544/50000]	Loss: 1.4842	LR: 0.089003
# Training Epoch: 1 [44672/50000]	Loss: 1.2784	LR: 0.089258
# Training Epoch: 1 [44800/50000]	Loss: 1.3582	LR: 0.089514
# Training Epoch: 1 [44928/50000]	Loss: 1.4832	LR: 0.089770
# Training Epoch: 1 [45056/50000]	Loss: 1.4080	LR: 0.090026
# Training Epoch: 1 [45184/50000]	Loss: 1.3446	LR: 0.090281
# Training Epoch: 1 [45312/50000]	Loss: 1.1482	LR: 0.090537
# Training Epoch: 1 [45440/50000]	Loss: 1.3242	LR: 0.090793
# Training Epoch: 1 [45568/50000]	Loss: 1.3720	LR: 0.091049
# Training Epoch: 1 [45696/50000]	Loss: 1.2502	LR: 0.091304
# Training Epoch: 1 [45824/50000]	Loss: 1.1292	LR: 0.091560
# Training Epoch: 1 [45952/50000]	Loss: 1.4421	LR: 0.091816
# Training Epoch: 1 [46080/50000]	Loss: 1.4183	LR: 0.092072
# Training Epoch: 1 [46208/50000]	Loss: 1.4548	LR: 0.092327
# Training Epoch: 1 [46336/50000]	Loss: 1.2047	LR: 0.092583
# Training Epoch: 1 [46464/50000]	Loss: 1.2525	LR: 0.092839
# Training Epoch: 1 [46592/50000]	Loss: 1.3975	LR: 0.093095
# Training Epoch: 1 [46720/50000]	Loss: 1.2745	LR: 0.093350
# Training Epoch: 1 [46848/50000]	Loss: 1.2713	LR: 0.093606
# Training Epoch: 1 [46976/50000]	Loss: 1.3195	LR: 0.093862
# Training Epoch: 1 [47104/50000]	Loss: 1.2603	LR: 0.094118
# Training Epoch: 1 [47232/50000]	Loss: 1.3186	LR: 0.094373
# Training Epoch: 1 [47360/50000]	Loss: 1.3927	LR: 0.094629
# Training Epoch: 1 [47488/50000]	Loss: 1.4243	LR: 0.094885
# Training Epoch: 1 [47616/50000]	Loss: 1.3025	LR: 0.095141
# Training Epoch: 1 [47744/50000]	Loss: 1.4128	LR: 0.095396
# Training Epoch: 1 [47872/50000]	Loss: 1.2350	LR: 0.095652
# Training Epoch: 1 [48000/50000]	Loss: 1.3434	LR: 0.095908
# Training Epoch: 1 [48128/50000]	Loss: 1.2969	LR: 0.096164
# Training Epoch: 1 [48256/50000]	Loss: 1.3331	LR: 0.096419
# Training Epoch: 1 [48384/50000]	Loss: 1.4793	LR: 0.096675
# Training Epoch: 1 [48512/50000]	Loss: 1.2295	LR: 0.096931
# Training Epoch: 1 [48640/50000]	Loss: 1.2151	LR: 0.097187
# Training Epoch: 1 [48768/50000]	Loss: 1.3265	LR: 0.097442
# Training Epoch: 1 [48896/50000]	Loss: 1.4686	LR: 0.097698
# Training Epoch: 1 [49024/50000]	Loss: 1.3106	LR: 0.097954
# Training Epoch: 1 [49152/50000]	Loss: 1.2927	LR: 0.098210
# Training Epoch: 1 [49280/50000]	Loss: 1.2375	LR: 0.098465
# Training Epoch: 1 [49408/50000]	Loss: 1.4936	LR: 0.098721
# Training Epoch: 1 [49536/50000]	Loss: 1.2857	LR: 0.098977
# Training Epoch: 1 [49664/50000]	Loss: 1.3136	LR: 0.099233
# Training Epoch: 1 [49792/50000]	Loss: 1.3541	LR: 0.099488
# Training Epoch: 1 [49920/50000]	Loss: 1.3499	LR: 0.099744
# Training Epoch: 1 [50000/50000]	Loss: 1.2646	LR: 0.100000
# Test set: Average loss: 0.0124, Accuracy: 0.5053
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Training Epoch: 2 [128/50000]	Loss: 1.2191	LR: 0.100000
# Training Epoch: 2 [256/50000]	Loss: 1.2328	LR: 0.100000
# Training Epoch: 2 [384/50000]	Loss: 1.4113	LR: 0.100000
# Training Epoch: 2 [512/50000]	Loss: 1.4235	LR: 0.100000
# Training Epoch: 2 [640/50000]	Loss: 1.4252	LR: 0.100000
# Training Epoch: 2 [768/50000]	Loss: 1.2249	LR: 0.100000
# Training Epoch: 2 [896/50000]	Loss: 1.2134	LR: 0.100000
# Training Epoch: 2 [1024/50000]	Loss: 1.3223	LR: 0.100000
# Training Epoch: 2 [1152/50000]	Loss: 1.4181	LR: 0.100000
# Training Epoch: 2 [1280/50000]	Loss: 1.3734	LR: 0.100000
# Training Epoch: 2 [1408/50000]	Loss: 1.4232	LR: 0.100000
# Training Epoch: 2 [1536/50000]	Loss: 1.2248	LR: 0.100000
# Training Epoch: 2 [1664/50000]	Loss: 1.1528	LR: 0.100000
# Training Epoch: 2 [1792/50000]	Loss: 1.2469	LR: 0.100000
# Training Epoch: 2 [1920/50000]	Loss: 1.4591	LR: 0.100000
# Training Epoch: 2 [2048/50000]	Loss: 1.3539	LR: 0.100000
# Training Epoch: 2 [2176/50000]	Loss: 1.2164	LR: 0.100000
# Training Epoch: 2 [2304/50000]	Loss: 1.3643	LR: 0.100000
# Training Epoch: 2 [2432/50000]	Loss: 1.3133	LR: 0.100000
# Training Epoch: 2 [2560/50000]	Loss: 1.2479	LR: 0.100000
# Training Epoch: 2 [2688/50000]	Loss: 1.1908	LR: 0.100000
# Training Epoch: 2 [2816/50000]	Loss: 1.2525	LR: 0.100000
# Training Epoch: 2 [2944/50000]	Loss: 1.2790	LR: 0.100000
# Training Epoch: 2 [3072/50000]	Loss: 1.4857	LR: 0.100000
# Training Epoch: 2 [3200/50000]	Loss: 1.3589	LR: 0.100000
# Training Epoch: 2 [3328/50000]	Loss: 1.1618	LR: 0.100000
# Training Epoch: 2 [3456/50000]	Loss: 1.3055	LR: 0.100000
# Training Epoch: 2 [3584/50000]	Loss: 1.1355	LR: 0.100000
# Training Epoch: 2 [3712/50000]	Loss: 1.0695	LR: 0.100000
# Training Epoch: 2 [3840/50000]	Loss: 1.1917	LR: 0.100000
# Training Epoch: 2 [3968/50000]	Loss: 1.3283	LR: 0.100000
# Training Epoch: 2 [4096/50000]	Loss: 1.1436	LR: 0.100000
# Training Epoch: 2 [4224/50000]	Loss: 1.2673	LR: 0.100000
# Training Epoch: 2 [4352/50000]	Loss: 1.3538	LR: 0.100000
# Training Epoch: 2 [4480/50000]	Loss: 1.1997	LR: 0.100000
# Training Epoch: 2 [4608/50000]	Loss: 1.1775	LR: 0.100000
# Training Epoch: 2 [4736/50000]	Loss: 1.3097	LR: 0.100000
# Training Epoch: 2 [4864/50000]	Loss: 1.2349	LR: 0.100000
# Training Epoch: 2 [4992/50000]	Loss: 1.3421	LR: 0.100000
# Training Epoch: 2 [5120/50000]	Loss: 1.3031	LR: 0.100000
# Training Epoch: 2 [5248/50000]	Loss: 1.4959	LR: 0.100000
# Training Epoch: 2 [5376/50000]	Loss: 1.5619	LR: 0.100000
# Training Epoch: 2 [5504/50000]	Loss: 1.1747	LR: 0.100000
# Training Epoch: 2 [5632/50000]	Loss: 1.3469	LR: 0.100000
# Training Epoch: 2 [5760/50000]	Loss: 1.3169	LR: 0.100000
# Training Epoch: 2 [5888/50000]	Loss: 1.1684	LR: 0.100000
# Training Epoch: 2 [6016/50000]	Loss: 1.1712	LR: 0.100000
# Training Epoch: 2 [6144/50000]	Loss: 1.2051	LR: 0.100000
# Training Epoch: 2 [6272/50000]	Loss: 1.2677	LR: 0.100000
# Training Epoch: 2 [6400/50000]	Loss: 1.2411	LR: 0.100000
# Training Epoch: 2 [6528/50000]	Loss: 1.2284	LR: 0.100000
# Training Epoch: 2 [6656/50000]	Loss: 1.1377	LR: 0.100000
# Training Epoch: 2 [6784/50000]	Loss: 1.2190	LR: 0.100000
# Training Epoch: 2 [6912/50000]	Loss: 1.2048	LR: 0.100000
# Training Epoch: 2 [7040/50000]	Loss: 1.1145	LR: 0.100000
# Training Epoch: 2 [7168/50000]	Loss: 1.1632	LR: 0.100000
# Training Epoch: 2 [7296/50000]	Loss: 1.0819	LR: 0.100000
# Training Epoch: 2 [7424/50000]	Loss: 1.2510	LR: 0.100000
# Training Epoch: 2 [7552/50000]	Loss: 1.2673	LR: 0.100000
# Training Epoch: 2 [7680/50000]	Loss: 1.4100	LR: 0.100000
# Training Epoch: 2 [7808/50000]	Loss: 1.1483	LR: 0.100000
# Training Epoch: 2 [7936/50000]	Loss: 1.1271	LR: 0.100000
# Training Epoch: 2 [8064/50000]	Loss: 1.1216	LR: 0.100000
# Training Epoch: 2 [8192/50000]	Loss: 1.3238	LR: 0.100000
# Training Epoch: 2 [8320/50000]	Loss: 1.2384	LR: 0.100000
# Training Epoch: 2 [8448/50000]	Loss: 1.2756	LR: 0.100000
# Training Epoch: 2 [8576/50000]	Loss: 1.3197	LR: 0.100000
# Training Epoch: 2 [8704/50000]	Loss: 1.2800	LR: 0.100000
# Training Epoch: 2 [8832/50000]	Loss: 1.1928	LR: 0.100000
# Training Epoch: 2 [8960/50000]	Loss: 1.5574	LR: 0.100000
# Training Epoch: 2 [9088/50000]	Loss: 1.2382	LR: 0.100000
# Training Epoch: 2 [9216/50000]	Loss: 1.1901	LR: 0.100000
# Training Epoch: 2 [9344/50000]	Loss: 1.2289	LR: 0.100000
# Training Epoch: 2 [9472/50000]	Loss: 1.2157	LR: 0.100000
# Training Epoch: 2 [9600/50000]	Loss: 1.1891	LR: 0.100000
# Training Epoch: 2 [9728/50000]	Loss: 1.3603	LR: 0.100000
# Training Epoch: 2 [9856/50000]	Loss: 1.1235	LR: 0.100000
# Training Epoch: 2 [9984/50000]	Loss: 1.6162	LR: 0.100000
# Training Epoch: 2 [10112/50000]	Loss: 1.1091	LR: 0.100000
# Training Epoch: 2 [10240/50000]	Loss: 1.1467	LR: 0.100000
# Training Epoch: 2 [10368/50000]	Loss: 1.3303	LR: 0.100000
# Training Epoch: 2 [10496/50000]	Loss: 1.1462	LR: 0.100000
# Training Epoch: 2 [10624/50000]	Loss: 1.0197	LR: 0.100000
# Training Epoch: 2 [10752/50000]	Loss: 1.2251	LR: 0.100000
# Training Epoch: 2 [10880/50000]	Loss: 1.1477	LR: 0.100000
# Training Epoch: 2 [11008/50000]	Loss: 1.1436	LR: 0.100000
# Training Epoch: 2 [11136/50000]	Loss: 1.1518	LR: 0.100000
# Training Epoch: 2 [11264/50000]	Loss: 1.1149	LR: 0.100000
# Training Epoch: 2 [11392/50000]	Loss: 1.1624	LR: 0.100000
# Training Epoch: 2 [11520/50000]	Loss: 1.2674	LR: 0.100000
# Training Epoch: 2 [11648/50000]	Loss: 1.1434	LR: 0.100000
# Training Epoch: 2 [11776/50000]	Loss: 1.2269	LR: 0.100000
# Training Epoch: 2 [11904/50000]	Loss: 1.2341	LR: 0.100000
# Training Epoch: 2 [12032/50000]	Loss: 1.2306	LR: 0.100000
# Training Epoch: 2 [12160/50000]	Loss: 1.0964	LR: 0.100000
# Training Epoch: 2 [12288/50000]	Loss: 1.0144	LR: 0.100000
# Training Epoch: 2 [12416/50000]	Loss: 1.1646	LR: 0.100000
# Training Epoch: 2 [12544/50000]	Loss: 1.1475	LR: 0.100000
# Training Epoch: 2 [12672/50000]	Loss: 1.3377	LR: 0.100000
# Training Epoch: 2 [12800/50000]	Loss: 1.2074	LR: 0.100000
# Training Epoch: 2 [12928/50000]	Loss: 1.2513	LR: 0.100000
# Training Epoch: 2 [13056/50000]	Loss: 1.1375	LR: 0.100000
# Training Epoch: 2 [13184/50000]	Loss: 0.9039	LR: 0.100000
# Training Epoch: 2 [13312/50000]	Loss: 1.0921	LR: 0.100000
# Training Epoch: 2 [13440/50000]	Loss: 1.1828	LR: 0.100000
# Training Epoch: 2 [13568/50000]	Loss: 1.1269	LR: 0.100000
# Training Epoch: 2 [13696/50000]	Loss: 1.0819	LR: 0.100000
# Training Epoch: 2 [13824/50000]	Loss: 1.0645	LR: 0.100000
# Training Epoch: 2 [13952/50000]	Loss: 1.1922	LR: 0.100000
# Training Epoch: 2 [14080/50000]	Loss: 1.2625	LR: 0.100000
# Training Epoch: 2 [14208/50000]	Loss: 1.3001	LR: 0.100000
# Training Epoch: 2 [14336/50000]	Loss: 1.2117	LR: 0.100000
# Training Epoch: 2 [14464/50000]	Loss: 1.1801	LR: 0.100000
# Training Epoch: 2 [14592/50000]	Loss: 1.1996	LR: 0.100000
# Training Epoch: 2 [14720/50000]	Loss: 1.0806	LR: 0.100000
# Training Epoch: 2 [14848/50000]	Loss: 1.1633	LR: 0.100000
# Training Epoch: 2 [14976/50000]	Loss: 1.1612	LR: 0.100000
# Training Epoch: 2 [15104/50000]	Loss: 1.1625	LR: 0.100000
# Training Epoch: 2 [15232/50000]	Loss: 0.8964	LR: 0.100000
# Training Epoch: 2 [15360/50000]	Loss: 1.2430	LR: 0.100000
# Training Epoch: 2 [15488/50000]	Loss: 1.1681	LR: 0.100000
# Training Epoch: 2 [15616/50000]	Loss: 1.1055	LR: 0.100000
# Training Epoch: 2 [15744/50000]	Loss: 1.1424	LR: 0.100000
# Training Epoch: 2 [15872/50000]	Loss: 1.2245	LR: 0.100000
# Training Epoch: 2 [16000/50000]	Loss: 1.2060	LR: 0.100000
# Training Epoch: 2 [16128/50000]	Loss: 1.0818	LR: 0.100000
# Training Epoch: 2 [16256/50000]	Loss: 1.1929	LR: 0.100000
# Training Epoch: 2 [16384/50000]	Loss: 1.0802	LR: 0.100000
# Training Epoch: 2 [16512/50000]	Loss: 1.1210	LR: 0.100000
# Training Epoch: 2 [16640/50000]	Loss: 1.3542	LR: 0.100000
# Training Epoch: 2 [16768/50000]	Loss: 1.1589	LR: 0.100000
# Training Epoch: 2 [16896/50000]	Loss: 1.2229	LR: 0.100000
# Training Epoch: 2 [17024/50000]	Loss: 1.1705	LR: 0.100000
# Training Epoch: 2 [17152/50000]	Loss: 1.3068	LR: 0.100000
# Training Epoch: 2 [17280/50000]	Loss: 1.1354	LR: 0.100000
# Training Epoch: 2 [17408/50000]	Loss: 1.2442	LR: 0.100000
# Training Epoch: 2 [17536/50000]	Loss: 1.1295	LR: 0.100000
# Training Epoch: 2 [17664/50000]	Loss: 1.1495	LR: 0.100000
# Training Epoch: 2 [17792/50000]	Loss: 0.9845	LR: 0.100000
# Training Epoch: 2 [17920/50000]	Loss: 0.9230	LR: 0.100000
# Training Epoch: 2 [18048/50000]	Loss: 1.2990	LR: 0.100000
# Training Epoch: 2 [18176/50000]	Loss: 1.2557	LR: 0.100000
# Training Epoch: 2 [18304/50000]	Loss: 1.0956	LR: 0.100000
# Training Epoch: 2 [18432/50000]	Loss: 1.1230	LR: 0.100000
# Training Epoch: 2 [18560/50000]	Loss: 1.3483	LR: 0.100000
# Training Epoch: 2 [18688/50000]	Loss: 1.1926	LR: 0.100000
# Training Epoch: 2 [18816/50000]	Loss: 1.0296	LR: 0.100000
# Training Epoch: 2 [18944/50000]	Loss: 1.1819	LR: 0.100000
# Training Epoch: 2 [19072/50000]	Loss: 1.0257	LR: 0.100000
# Training Epoch: 2 [19200/50000]	Loss: 1.1195	LR: 0.100000
# Training Epoch: 2 [19328/50000]	Loss: 1.1158	LR: 0.100000
# Training Epoch: 2 [19456/50000]	Loss: 1.0809	LR: 0.100000
# Training Epoch: 2 [19584/50000]	Loss: 1.0379	LR: 0.100000
# Training Epoch: 2 [19712/50000]	Loss: 1.2390	LR: 0.100000
# Training Epoch: 2 [19840/50000]	Loss: 1.1611	LR: 0.100000
# Training Epoch: 2 [19968/50000]	Loss: 1.0783	LR: 0.100000
# Training Epoch: 2 [20096/50000]	Loss: 0.8893	LR: 0.100000
# Training Epoch: 2 [20224/50000]	Loss: 1.1809	LR: 0.100000
# Training Epoch: 2 [20352/50000]	Loss: 1.2513	LR: 0.100000
# Training Epoch: 2 [20480/50000]	Loss: 1.1183	LR: 0.100000
# Training Epoch: 2 [20608/50000]	Loss: 1.2618	LR: 0.100000
# Training Epoch: 2 [20736/50000]	Loss: 1.2175	LR: 0.100000
# Training Epoch: 2 [20864/50000]	Loss: 1.1230	LR: 0.100000
# Training Epoch: 2 [20992/50000]	Loss: 1.0092	LR: 0.100000
# Training Epoch: 2 [21120/50000]	Loss: 1.1237	LR: 0.100000
# Training Epoch: 2 [21248/50000]	Loss: 1.2186	LR: 0.100000
# Training Epoch: 2 [21376/50000]	Loss: 1.2702	LR: 0.100000
# Training Epoch: 2 [21504/50000]	Loss: 1.0345	LR: 0.100000
# Training Epoch: 2 [21632/50000]	Loss: 1.0449	LR: 0.100000
# Training Epoch: 2 [21760/50000]	Loss: 1.1047	LR: 0.100000
# Training Epoch: 2 [21888/50000]	Loss: 1.0956	LR: 0.100000
# Training Epoch: 2 [22016/50000]	Loss: 1.1542	LR: 0.100000
# Training Epoch: 2 [22144/50000]	Loss: 1.0110	LR: 0.100000
# Training Epoch: 2 [22272/50000]	Loss: 1.1696	LR: 0.100000
# Training Epoch: 2 [22400/50000]	Loss: 1.1667	LR: 0.100000
# Training Epoch: 2 [22528/50000]	Loss: 1.0953	LR: 0.100000
# Training Epoch: 2 [22656/50000]	Loss: 1.2186	LR: 0.100000
# Training Epoch: 2 [22784/50000]	Loss: 1.0459	LR: 0.100000
# Training Epoch: 2 [22912/50000]	Loss: 0.9869	LR: 0.100000
# Training Epoch: 2 [23040/50000]	Loss: 1.0860	LR: 0.100000
# Training Epoch: 2 [23168/50000]	Loss: 1.2371	LR: 0.100000
# Training Epoch: 2 [23296/50000]	Loss: 1.0355	LR: 0.100000
# Training Epoch: 2 [23424/50000]	Loss: 1.0056	LR: 0.100000
# Training Epoch: 2 [23552/50000]	Loss: 0.9146	LR: 0.100000
# Training Epoch: 2 [23680/50000]	Loss: 1.0593	LR: 0.100000
# Training Epoch: 2 [23808/50000]	Loss: 1.1624	LR: 0.100000
# Training Epoch: 2 [23936/50000]	Loss: 1.2056	LR: 0.100000
# Training Epoch: 2 [24064/50000]	Loss: 1.1499	LR: 0.100000
# Training Epoch: 2 [24192/50000]	Loss: 1.0779	LR: 0.100000
# Training Epoch: 2 [24320/50000]	Loss: 1.0640	LR: 0.100000
# Training Epoch: 2 [24448/50000]	Loss: 0.9859	LR: 0.100000
# Training Epoch: 2 [24576/50000]	Loss: 1.0972	LR: 0.100000
# Training Epoch: 2 [24704/50000]	Loss: 0.9948	LR: 0.100000
# Training Epoch: 2 [24832/50000]	Loss: 1.0358	LR: 0.100000
# Training Epoch: 2 [24960/50000]	Loss: 1.0652	LR: 0.100000
# Training Epoch: 2 [25088/50000]	Loss: 0.9725	LR: 0.100000
# Training Epoch: 2 [25216/50000]	Loss: 1.0704	LR: 0.100000
# Training Epoch: 2 [25344/50000]	Loss: 1.2119	LR: 0.100000
# Training Epoch: 2 [25472/50000]	Loss: 1.1329	LR: 0.100000
# Training Epoch: 2 [25600/50000]	Loss: 1.2532	LR: 0.100000
# Training Epoch: 2 [25728/50000]	Loss: 0.9465	LR: 0.100000
# Training Epoch: 2 [25856/50000]	Loss: 1.0666	LR: 0.100000
# Training Epoch: 2 [25984/50000]	Loss: 0.9730	LR: 0.100000
# Training Epoch: 2 [26112/50000]	Loss: 1.0913	LR: 0.100000
# Training Epoch: 2 [26240/50000]	Loss: 1.0813	LR: 0.100000
# Training Epoch: 2 [26368/50000]	Loss: 1.0269	LR: 0.100000
# Training Epoch: 2 [26496/50000]	Loss: 1.0023	LR: 0.100000
# Training Epoch: 2 [26624/50000]	Loss: 1.1068	LR: 0.100000
# Training Epoch: 2 [26752/50000]	Loss: 1.1239	LR: 0.100000
# Training Epoch: 2 [26880/50000]	Loss: 1.1689	LR: 0.100000
# Training Epoch: 2 [27008/50000]	Loss: 1.0356	LR: 0.100000
# Training Epoch: 2 [27136/50000]	Loss: 1.2046	LR: 0.100000
# Training Epoch: 2 [27264/50000]	Loss: 1.2399	LR: 0.100000
# Training Epoch: 2 [27392/50000]	Loss: 1.0833	LR: 0.100000
# Training Epoch: 2 [27520/50000]	Loss: 1.2564	LR: 0.100000
# Training Epoch: 2 [27648/50000]	Loss: 0.9635	LR: 0.100000
# Training Epoch: 2 [27776/50000]	Loss: 1.0474	LR: 0.100000
# Training Epoch: 2 [27904/50000]	Loss: 1.2888	LR: 0.100000
# Training Epoch: 2 [28032/50000]	Loss: 1.2662	LR: 0.100000
# Training Epoch: 2 [28160/50000]	Loss: 1.2036	LR: 0.100000
# Training Epoch: 2 [28288/50000]	Loss: 1.0596	LR: 0.100000
# Training Epoch: 2 [28416/50000]	Loss: 1.0151	LR: 0.100000
# Training Epoch: 2 [28544/50000]	Loss: 1.1817	LR: 0.100000
# Training Epoch: 2 [28672/50000]	Loss: 1.0840	LR: 0.100000
# Training Epoch: 2 [28800/50000]	Loss: 1.1776	LR: 0.100000
# Training Epoch: 2 [28928/50000]	Loss: 1.1906	LR: 0.100000
# Training Epoch: 2 [29056/50000]	Loss: 1.0405	LR: 0.100000
# Training Epoch: 2 [29184/50000]	Loss: 1.0754	LR: 0.100000
# Training Epoch: 2 [29312/50000]	Loss: 1.1162	LR: 0.100000
# Training Epoch: 2 [29440/50000]	Loss: 1.0504	LR: 0.100000
# Training Epoch: 2 [29568/50000]	Loss: 1.0206	LR: 0.100000
# Training Epoch: 2 [29696/50000]	Loss: 1.0143	LR: 0.100000
# Training Epoch: 2 [29824/50000]	Loss: 1.0524	LR: 0.100000
# Training Epoch: 2 [29952/50000]	Loss: 1.1835	LR: 0.100000
# Training Epoch: 2 [30080/50000]	Loss: 0.9786	LR: 0.100000
# Training Epoch: 2 [30208/50000]	Loss: 0.9009	LR: 0.100000
# Training Epoch: 2 [30336/50000]	Loss: 1.1380	LR: 0.100000
# Training Epoch: 2 [30464/50000]	Loss: 1.1064	LR: 0.100000
# Training Epoch: 2 [30592/50000]	Loss: 1.0110	LR: 0.100000
# Training Epoch: 2 [30720/50000]	Loss: 1.1122	LR: 0.100000
# Training Epoch: 2 [30848/50000]	Loss: 1.2206	LR: 0.100000
# Training Epoch: 2 [30976/50000]	Loss: 0.9683	LR: 0.100000
# Training Epoch: 2 [31104/50000]	Loss: 1.1203	LR: 0.100000
# Training Epoch: 2 [31232/50000]	Loss: 1.2863	LR: 0.100000
# Training Epoch: 2 [31360/50000]	Loss: 1.1943	LR: 0.100000
# Training Epoch: 2 [31488/50000]	Loss: 0.9481	LR: 0.100000
# Training Epoch: 2 [31616/50000]	Loss: 1.1360	LR: 0.100000
# Training Epoch: 2 [31744/50000]	Loss: 1.1950	LR: 0.100000
# Training Epoch: 2 [31872/50000]	Loss: 1.0334	LR: 0.100000
# Training Epoch: 2 [32000/50000]	Loss: 1.1524	LR: 0.100000
# Training Epoch: 2 [32128/50000]	Loss: 0.9927	LR: 0.100000
# Training Epoch: 2 [32256/50000]	Loss: 1.1489	LR: 0.100000
# Training Epoch: 2 [32384/50000]	Loss: 1.0653	LR: 0.100000
# Training Epoch: 2 [32512/50000]	Loss: 1.0208	LR: 0.100000
# Training Epoch: 2 [32640/50000]	Loss: 1.1470	LR: 0.100000
# Training Epoch: 2 [32768/50000]	Loss: 0.9457	LR: 0.100000
# Training Epoch: 2 [32896/50000]	Loss: 1.0313	LR: 0.100000
# Training Epoch: 2 [33024/50000]	Loss: 1.0517	LR: 0.100000
# Training Epoch: 2 [33152/50000]	Loss: 1.0410	LR: 0.100000
# Training Epoch: 2 [33280/50000]	Loss: 1.1453	LR: 0.100000
# Training Epoch: 2 [33408/50000]	Loss: 0.9162	LR: 0.100000
# Training Epoch: 2 [33536/50000]	Loss: 1.1836	LR: 0.100000
# Training Epoch: 2 [33664/50000]	Loss: 1.0918	LR: 0.100000
# Training Epoch: 2 [33792/50000]	Loss: 1.0757	LR: 0.100000
# Training Epoch: 2 [33920/50000]	Loss: 1.0417	LR: 0.100000
# Training Epoch: 2 [34048/50000]	Loss: 1.0211	LR: 0.100000
# Training Epoch: 2 [34176/50000]	Loss: 0.9627	LR: 0.100000
# Training Epoch: 2 [34304/50000]	Loss: 1.1979	LR: 0.100000
# Training Epoch: 2 [34432/50000]	Loss: 1.0835	LR: 0.100000
# Training Epoch: 2 [34560/50000]	Loss: 1.0947	LR: 0.100000
# Training Epoch: 2 [34688/50000]	Loss: 1.1444	LR: 0.100000
# Training Epoch: 2 [34816/50000]	Loss: 0.9927	LR: 0.100000
# Training Epoch: 2 [34944/50000]	Loss: 1.2901	LR: 0.100000
# Training Epoch: 2 [35072/50000]	Loss: 1.2867	LR: 0.100000
# Training Epoch: 2 [35200/50000]	Loss: 1.0080	LR: 0.100000
# Training Epoch: 2 [35328/50000]	Loss: 1.0429	LR: 0.100000
# Training Epoch: 2 [35456/50000]	Loss: 1.2320	LR: 0.100000
# Training Epoch: 2 [35584/50000]	Loss: 0.8521	LR: 0.100000
# Training Epoch: 2 [35712/50000]	Loss: 1.0218	LR: 0.100000
# Training Epoch: 2 [35840/50000]	Loss: 0.9833	LR: 0.100000
# Training Epoch: 2 [35968/50000]	Loss: 1.1020	LR: 0.100000
# Training Epoch: 2 [36096/50000]	Loss: 1.1513	LR: 0.100000
# Training Epoch: 2 [36224/50000]	Loss: 1.0960	LR: 0.100000
# Training Epoch: 2 [36352/50000]	Loss: 1.0525	LR: 0.100000
# Training Epoch: 2 [36480/50000]	Loss: 0.9934	LR: 0.100000
# Training Epoch: 2 [36608/50000]	Loss: 1.0369	LR: 0.100000
# Training Epoch: 2 [36736/50000]	Loss: 1.0763	LR: 0.100000
# Training Epoch: 2 [36864/50000]	Loss: 1.0579	LR: 0.100000
# Training Epoch: 2 [36992/50000]	Loss: 1.0897	LR: 0.100000
# Training Epoch: 2 [37120/50000]	Loss: 1.0197	LR: 0.100000
# Training Epoch: 2 [37248/50000]	Loss: 1.0524	LR: 0.100000
# Training Epoch: 2 [37376/50000]	Loss: 0.8443	LR: 0.100000
# Training Epoch: 2 [37504/50000]	Loss: 0.9263	LR: 0.100000
# Training Epoch: 2 [37632/50000]	Loss: 0.9921	LR: 0.100000
# Training Epoch: 2 [37760/50000]	Loss: 0.9652	LR: 0.100000
# Training Epoch: 2 [37888/50000]	Loss: 1.1132	LR: 0.100000
# Training Epoch: 2 [38016/50000]	Loss: 1.0431	LR: 0.100000
# Training Epoch: 2 [38144/50000]	Loss: 1.0764	LR: 0.100000
# Training Epoch: 2 [38272/50000]	Loss: 0.8537	LR: 0.100000
# Training Epoch: 2 [38400/50000]	Loss: 0.8671	LR: 0.100000
# Training Epoch: 2 [38528/50000]	Loss: 1.2055	LR: 0.100000
# Training Epoch: 2 [38656/50000]	Loss: 1.0447	LR: 0.100000
# Training Epoch: 2 [38784/50000]	Loss: 0.9986	LR: 0.100000
# Training Epoch: 2 [38912/50000]	Loss: 1.0632	LR: 0.100000
# Training Epoch: 2 [39040/50000]	Loss: 0.9477	LR: 0.100000
# Training Epoch: 2 [39168/50000]	Loss: 1.0513	LR: 0.100000
# Training Epoch: 2 [39296/50000]	Loss: 1.0412	LR: 0.100000
# Training Epoch: 2 [39424/50000]	Loss: 1.0362	LR: 0.100000
# Training Epoch: 2 [39552/50000]	Loss: 0.9567	LR: 0.100000
# Training Epoch: 2 [39680/50000]	Loss: 0.9512	LR: 0.100000
# Training Epoch: 2 [39808/50000]	Loss: 0.9128	LR: 0.100000
# Training Epoch: 2 [39936/50000]	Loss: 1.1290	LR: 0.100000
# Training Epoch: 2 [40064/50000]	Loss: 1.1883	LR: 0.100000
# Training Epoch: 2 [40192/50000]	Loss: 1.0131	LR: 0.100000
# Training Epoch: 2 [40320/50000]	Loss: 0.9738	LR: 0.100000
# Training Epoch: 2 [40448/50000]	Loss: 0.9484	LR: 0.100000
# Training Epoch: 2 [40576/50000]	Loss: 1.0536	LR: 0.100000
# Training Epoch: 2 [40704/50000]	Loss: 0.9770	LR: 0.100000
# Training Epoch: 2 [40832/50000]	Loss: 1.0292	LR: 0.100000
# Training Epoch: 2 [40960/50000]	Loss: 1.1037	LR: 0.100000
# Training Epoch: 2 [41088/50000]	Loss: 1.1963	LR: 0.100000
# Training Epoch: 2 [41216/50000]	Loss: 0.9827	LR: 0.100000
# Training Epoch: 2 [41344/50000]	Loss: 1.1557	LR: 0.100000
# Training Epoch: 2 [41472/50000]	Loss: 1.0771	LR: 0.100000
# Training Epoch: 2 [41600/50000]	Loss: 0.9371	LR: 0.100000
# Training Epoch: 2 [41728/50000]	Loss: 0.9977	LR: 0.100000
# Training Epoch: 2 [41856/50000]	Loss: 1.0798	LR: 0.100000
# Training Epoch: 2 [41984/50000]	Loss: 0.9837	LR: 0.100000
# Training Epoch: 2 [42112/50000]	Loss: 0.8522	LR: 0.100000
# Training Epoch: 2 [42240/50000]	Loss: 1.0868	LR: 0.100000
# Training Epoch: 2 [42368/50000]	Loss: 1.0754	LR: 0.100000
# Training Epoch: 2 [42496/50000]	Loss: 0.9175	LR: 0.100000
# Training Epoch: 2 [42624/50000]	Loss: 0.8693	LR: 0.100000
# Training Epoch: 2 [42752/50000]	Loss: 1.0872	LR: 0.100000
# Training Epoch: 2 [42880/50000]	Loss: 1.0274	LR: 0.100000
# Training Epoch: 2 [43008/50000]	Loss: 0.9977	LR: 0.100000
# Training Epoch: 2 [43136/50000]	Loss: 1.2084	LR: 0.100000
# Training Epoch: 2 [43264/50000]	Loss: 0.9789	LR: 0.100000
# Training Epoch: 2 [43392/50000]	Loss: 1.0058	LR: 0.100000
# Training Epoch: 2 [43520/50000]	Loss: 1.0766	LR: 0.100000
# Training Epoch: 2 [43648/50000]	Loss: 1.0192	LR: 0.100000
# Training Epoch: 2 [43776/50000]	Loss: 1.1641	LR: 0.100000
# Training Epoch: 2 [43904/50000]	Loss: 0.9567	LR: 0.100000
# Training Epoch: 2 [44032/50000]	Loss: 1.0304	LR: 0.100000
# Training Epoch: 2 [44160/50000]	Loss: 0.8271	LR: 0.100000
# Training Epoch: 2 [44288/50000]	Loss: 1.1156	LR: 0.100000
# Training Epoch: 2 [44416/50000]	Loss: 1.0046	LR: 0.100000
# Training Epoch: 2 [44544/50000]	Loss: 1.0186	LR: 0.100000
# Training Epoch: 2 [44672/50000]	Loss: 1.1608	LR: 0.100000
# Training Epoch: 2 [44800/50000]	Loss: 1.0069	LR: 0.100000
# Training Epoch: 2 [44928/50000]	Loss: 1.0882	LR: 0.100000
# Training Epoch: 2 [45056/50000]	Loss: 0.9542	LR: 0.100000
# Training Epoch: 2 [45184/50000]	Loss: 1.1326	LR: 0.100000
# Training Epoch: 2 [45312/50000]	Loss: 1.0295	LR: 0.100000
# Training Epoch: 2 [45440/50000]	Loss: 1.0474	LR: 0.100000
# Training Epoch: 2 [45568/50000]	Loss: 0.9943	LR: 0.100000
# Training Epoch: 2 [45696/50000]	Loss: 0.9257	LR: 0.100000
# Training Epoch: 2 [45824/50000]	Loss: 1.0636	LR: 0.100000
# Training Epoch: 2 [45952/50000]	Loss: 0.8982	LR: 0.100000
# Training Epoch: 2 [46080/50000]	Loss: 1.0661	LR: 0.100000
# Training Epoch: 2 [46208/50000]	Loss: 0.8924	LR: 0.100000
# Training Epoch: 2 [46336/50000]	Loss: 1.0952	LR: 0.100000
# Training Epoch: 2 [46464/50000]	Loss: 0.9582	LR: 0.100000
# Training Epoch: 2 [46592/50000]	Loss: 0.9443	LR: 0.100000
# Training Epoch: 2 [46720/50000]	Loss: 1.0479	LR: 0.100000
# Training Epoch: 2 [46848/50000]	Loss: 1.0916	LR: 0.100000
# Training Epoch: 2 [46976/50000]	Loss: 0.9740	LR: 0.100000
# Training Epoch: 2 [47104/50000]	Loss: 1.0126	LR: 0.100000
# Training Epoch: 2 [47232/50000]	Loss: 0.9396	LR: 0.100000
# Training Epoch: 2 [47360/50000]	Loss: 1.0973	LR: 0.100000
# Training Epoch: 2 [47488/50000]	Loss: 1.0726	LR: 0.100000
# Training Epoch: 2 [47616/50000]	Loss: 0.9855	LR: 0.100000
# Training Epoch: 2 [47744/50000]	Loss: 1.2019	LR: 0.100000
# Training Epoch: 2 [47872/50000]	Loss: 1.1503	LR: 0.100000
# Training Epoch: 2 [48000/50000]	Loss: 1.0391	LR: 0.100000
# Training Epoch: 2 [48128/50000]	Loss: 1.0260	LR: 0.100000
# Training Epoch: 2 [48256/50000]	Loss: 0.8716	LR: 0.100000
# Training Epoch: 2 [48384/50000]	Loss: 0.8769	LR: 0.100000
# Training Epoch: 2 [48512/50000]	Loss: 0.9233	LR: 0.100000
# Training Epoch: 2 [48640/50000]	Loss: 0.9879	LR: 0.100000
# Training Epoch: 2 [48768/50000]	Loss: 0.8568	LR: 0.100000
# Training Epoch: 2 [48896/50000]	Loss: 0.8352	LR: 0.100000
# Training Epoch: 2 [49024/50000]	Loss: 1.0444	LR: 0.100000
# Training Epoch: 2 [49152/50000]	Loss: 0.8458	LR: 0.100000
# Training Epoch: 2 [49280/50000]	Loss: 0.9079	LR: 0.100000
# Training Epoch: 2 [49408/50000]	Loss: 0.7986	LR: 0.100000
# Training Epoch: 2 [49536/50000]	Loss: 0.9865	LR: 0.100000
# Training Epoch: 2 [49664/50000]	Loss: 0.9991	LR: 0.100000
# Training Epoch: 2 [49792/50000]	Loss: 1.0340	LR: 0.100000
# Training Epoch: 2 [49920/50000]	Loss: 0.9420	LR: 0.100000
# Training Epoch: 2 [50000/50000]	Loss: 0.8124	LR: 0.100000
# Test set: Average loss: 0.0080, Accuracy: 0.6444
#
# Training Epoch: 3 [128/50000]	Loss: 0.9103	LR: 0.100000
# Training Epoch: 3 [256/50000]	Loss: 1.0075	LR: 0.100000
# Training Epoch: 3 [384/50000]	Loss: 1.0008	LR: 0.100000
# Training Epoch: 3 [512/50000]	Loss: 1.0799	LR: 0.100000
# Training Epoch: 3 [640/50000]	Loss: 0.8556	LR: 0.100000
# Training Epoch: 3 [768/50000]	Loss: 1.0102	LR: 0.100000
# Training Epoch: 3 [896/50000]	Loss: 0.8600	LR: 0.100000
# Training Epoch: 3 [1024/50000]	Loss: 0.8835	LR: 0.100000
# Training Epoch: 3 [1152/50000]	Loss: 1.0040	LR: 0.100000
# Training Epoch: 3 [1280/50000]	Loss: 0.9284	LR: 0.100000
# Training Epoch: 3 [1408/50000]	Loss: 1.0503	LR: 0.100000
# Training Epoch: 3 [1536/50000]	Loss: 0.8520	LR: 0.100000
# Training Epoch: 3 [1664/50000]	Loss: 0.8423	LR: 0.100000
# Training Epoch: 3 [1792/50000]	Loss: 1.1540	LR: 0.100000
# Training Epoch: 3 [1920/50000]	Loss: 1.1026	LR: 0.100000
# Training Epoch: 3 [2048/50000]	Loss: 1.0914	LR: 0.100000
# Training Epoch: 3 [2176/50000]	Loss: 0.7625	LR: 0.100000
# Training Epoch: 3 [2304/50000]	Loss: 1.0343	LR: 0.100000
# Training Epoch: 3 [2432/50000]	Loss: 0.9363	LR: 0.100000
# Training Epoch: 3 [2560/50000]	Loss: 0.9877	LR: 0.100000
# Training Epoch: 3 [2688/50000]	Loss: 0.9760	LR: 0.100000
# Training Epoch: 3 [2816/50000]	Loss: 1.0988	LR: 0.100000
# Training Epoch: 3 [2944/50000]	Loss: 0.8466	LR: 0.100000
# ...
# Training Epoch: 24 [15744/50000]	Loss: 0.1440	LR: 0.000337
# Training Epoch: 24 [15872/50000]	Loss: 0.2818	LR: 0.000337
# Training Epoch: 24 [16000/50000]	Loss: 0.2048	LR: 0.000337
# Training Epoch: 24 [16128/50000]	Loss: 0.2191	LR: 0.000337
# Training Epoch: 24 [16256/50000]	Loss: 0.2869	LR: 0.000337
# Training Epoch: 24 [16384/50000]	Loss: 0.2588	LR: 0.000337
# Training Epoch: 24 [16512/50000]	Loss: 0.2918	LR: 0.000337
# Training Epoch: 24 [16640/50000]	Loss: 0.2444	LR: 0.000337
# Training Epoch: 24 [16768/50000]	Loss: 0.2247	LR: 0.000337
# Training Epoch: 24 [16896/50000]	Loss: 0.2474	LR: 0.000337
# Training Epoch: 24 [17024/50000]	Loss: 0.2018	LR: 0.000337
# Training Epoch: 24 [17152/50000]	Loss: 0.2314	LR: 0.000337
# Training Epoch: 24 [17280/50000]	Loss: 0.2587	LR: 0.000337
# Training Epoch: 24 [17408/50000]	Loss: 0.2495	LR: 0.000337
# Training Epoch: 24 [17536/50000]	Loss: 0.3087	LR: 0.000337
# Training Epoch: 24 [17664/50000]	Loss: 0.2631	LR: 0.000337
# Training Epoch: 24 [17792/50000]	Loss: 0.2928	LR: 0.000337
# Training Epoch: 24 [17920/50000]	Loss: 0.2734	LR: 0.000337
# Training Epoch: 24 [18048/50000]	Loss: 0.3490	LR: 0.000337
# Training Epoch: 24 [18176/50000]	Loss: 0.2418	LR: 0.000337
# Training Epoch: 24 [18304/50000]	Loss: 0.1973	LR: 0.000337
# Training Epoch: 24 [18432/50000]	Loss: 0.2216	LR: 0.000337
# Training Epoch: 24 [18560/50000]	Loss: 0.1714	LR: 0.000337
# Training Epoch: 24 [18688/50000]	Loss: 0.1807	LR: 0.000337
# Training Epoch: 24 [18816/50000]	Loss: 0.2221	LR: 0.000337
# Training Epoch: 24 [18944/50000]	Loss: 0.3160	LR: 0.000337
# Training Epoch: 24 [19072/50000]	Loss: 0.3268	LR: 0.000337
# Training Epoch: 24 [19200/50000]	Loss: 0.2523	LR: 0.000337
# Training Epoch: 24 [19328/50000]	Loss: 0.4009	LR: 0.000337
# Training Epoch: 24 [19456/50000]	Loss: 0.1966	LR: 0.000337
# Training Epoch: 24 [19584/50000]	Loss: 0.1984	LR: 0.000337
# Training Epoch: 24 [19712/50000]	Loss: 0.3123	LR: 0.000337
# Training Epoch: 24 [19840/50000]	Loss: 0.2442	LR: 0.000337
# Training Epoch: 24 [19968/50000]	Loss: 0.2676	LR: 0.000337
# Training Epoch: 24 [20096/50000]	Loss: 0.3257	LR: 0.000337
# Training Epoch: 24 [20224/50000]	Loss: 0.2215	LR: 0.000337
# Training Epoch: 24 [20352/50000]	Loss: 0.2751	LR: 0.000337
# Training Epoch: 24 [20480/50000]	Loss: 0.2826	LR: 0.000337
# Training Epoch: 24 [20608/50000]	Loss: 0.2457	LR: 0.000337
# Training Epoch: 24 [20736/50000]	Loss: 0.1521	LR: 0.000337
# Training Epoch: 24 [20864/50000]	Loss: 0.2279	LR: 0.000337
# Training Epoch: 24 [20992/50000]	Loss: 0.2179	LR: 0.000337
# Training Epoch: 24 [21120/50000]	Loss: 0.2319	LR: 0.000337
# Training Epoch: 24 [21248/50000]	Loss: 0.3706	LR: 0.000337
# Training Epoch: 24 [21376/50000]	Loss: 0.1556	LR: 0.000337
# Training Epoch: 24 [21504/50000]	Loss: 0.3176	LR: 0.000337
# Training Epoch: 24 [21632/50000]	Loss: 0.2303	LR: 0.000337
# Training Epoch: 24 [21760/50000]	Loss: 0.1980	LR: 0.000337
# Training Epoch: 24 [21888/50000]	Loss: 0.2810	LR: 0.000337
# Training Epoch: 24 [22016/50000]	Loss: 0.2741	LR: 0.000337
# Training Epoch: 24 [22144/50000]	Loss: 0.3278	LR: 0.000337
# Training Epoch: 24 [22272/50000]	Loss: 0.2833	LR: 0.000337
# Training Epoch: 24 [22400/50000]	Loss: 0.1645	LR: 0.000337
# Training Epoch: 24 [22528/50000]	Loss: 0.2867	LR: 0.000337
# Training Epoch: 24 [22656/50000]	Loss: 0.2190	LR: 0.000337
# Training Epoch: 24 [22784/50000]	Loss: 0.2940	LR: 0.000337
# Training Epoch: 24 [22912/50000]	Loss: 0.2396	LR: 0.000337
# Training Epoch: 24 [23040/50000]	Loss: 0.1888	LR: 0.000337
# Training Epoch: 24 [23168/50000]	Loss: 0.1805	LR: 0.000337
# Training Epoch: 24 [23296/50000]	Loss: 0.2181	LR: 0.000337
# Training Epoch: 24 [23424/50000]	Loss: 0.1663	LR: 0.000337
# Training Epoch: 24 [23552/50000]	Loss: 0.3529	LR: 0.000337
# Training Epoch: 24 [23680/50000]	Loss: 0.2072	LR: 0.000337
# Training Epoch: 24 [23808/50000]	Loss: 0.3173	LR: 0.000337
# Training Epoch: 24 [23936/50000]	Loss: 0.1895	LR: 0.000337
# Training Epoch: 24 [24064/50000]	Loss: 0.3410	LR: 0.000337
# Training Epoch: 24 [24192/50000]	Loss: 0.2779	LR: 0.000337
# Training Epoch: 24 [24320/50000]	Loss: 0.1870	LR: 0.000337
# Training Epoch: 24 [24448/50000]	Loss: 0.2442	LR: 0.000337
# Training Epoch: 24 [24576/50000]	Loss: 0.2378	LR: 0.000337
# Training Epoch: 24 [24704/50000]	Loss: 0.2417	LR: 0.000337
# Training Epoch: 24 [24832/50000]	Loss: 0.2543	LR: 0.000337
# Training Epoch: 24 [24960/50000]	Loss: 0.2505	LR: 0.000337
# Training Epoch: 24 [25088/50000]	Loss: 0.1977	LR: 0.000337
# Training Epoch: 24 [25216/50000]	Loss: 0.3311	LR: 0.000337
# Training Epoch: 24 [25344/50000]	Loss: 0.4996	LR: 0.000337
# Training Epoch: 24 [25472/50000]	Loss: 0.3109	LR: 0.000337
# Training Epoch: 24 [25600/50000]	Loss: 0.3266	LR: 0.000337
# Training Epoch: 24 [25728/50000]	Loss: 0.2875	LR: 0.000337
# Training Epoch: 24 [25856/50000]	Loss: 0.1606	LR: 0.000337
# Training Epoch: 24 [25984/50000]	Loss: 0.1742	LR: 0.000337
# Training Epoch: 24 [26112/50000]	Loss: 0.1888	LR: 0.000337
# Training Epoch: 24 [26240/50000]	Loss: 0.2179	LR: 0.000337
# Training Epoch: 24 [26368/50000]	Loss: 0.2154	LR: 0.000337
# Training Epoch: 24 [26496/50000]	Loss: 0.2400	LR: 0.000337
# Training Epoch: 24 [26624/50000]	Loss: 0.2446	LR: 0.000337
# Training Epoch: 24 [26752/50000]	Loss: 0.2672	LR: 0.000337
# Training Epoch: 24 [26880/50000]	Loss: 0.2038	LR: 0.000337
# Training Epoch: 24 [27008/50000]	Loss: 0.3358	LR: 0.000337
# Training Epoch: 24 [27136/50000]	Loss: 0.2708	LR: 0.000337
# Training Epoch: 24 [27264/50000]	Loss: 0.4584	LR: 0.000337
# Training Epoch: 24 [27392/50000]	Loss: 0.1569	LR: 0.000337
# Training Epoch: 24 [27520/50000]	Loss: 0.1422	LR: 0.000337
# Training Epoch: 24 [27648/50000]	Loss: 0.3265	LR: 0.000337
# Training Epoch: 24 [27776/50000]	Loss: 0.2134	LR: 0.000337
# Training Epoch: 24 [27904/50000]	Loss: 0.2851	LR: 0.000337
# Training Epoch: 24 [28032/50000]	Loss: 0.2353	LR: 0.000337
# Training Epoch: 24 [28160/50000]	Loss: 0.2328	LR: 0.000337
# Training Epoch: 24 [28288/50000]	Loss: 0.2324	LR: 0.000337
# Training Epoch: 24 [28416/50000]	Loss: 0.1655	LR: 0.000337
# Training Epoch: 24 [28544/50000]	Loss: 0.2075	LR: 0.000337
# Training Epoch: 24 [28672/50000]	Loss: 0.2202	LR: 0.000337
# Training Epoch: 24 [28800/50000]	Loss: 0.1849	LR: 0.000337
# Training Epoch: 24 [28928/50000]	Loss: 0.1957	LR: 0.000337
# Training Epoch: 24 [29056/50000]	Loss: 0.3054	LR: 0.000337
# Training Epoch: 24 [29184/50000]	Loss: 0.1936	LR: 0.000337
# Training Epoch: 24 [29312/50000]	Loss: 0.1591	LR: 0.000337
# Training Epoch: 24 [29440/50000]	Loss: 0.2765	LR: 0.000337
# Training Epoch: 24 [29568/50000]	Loss: 0.2271	LR: 0.000337
# Training Epoch: 24 [29696/50000]	Loss: 0.2833	LR: 0.000337
# Training Epoch: 24 [29824/50000]	Loss: 0.3058	LR: 0.000337
# Training Epoch: 24 [29952/50000]	Loss: 0.2564	LR: 0.000337
# Training Epoch: 24 [30080/50000]	Loss: 0.2576	LR: 0.000337
# Training Epoch: 24 [30208/50000]	Loss: 0.2669	LR: 0.000337
# Training Epoch: 24 [30336/50000]	Loss: 0.2239	LR: 0.000337
# Training Epoch: 24 [30464/50000]	Loss: 0.3332	LR: 0.000337
# Training Epoch: 24 [30592/50000]	Loss: 0.2970	LR: 0.000337
# Training Epoch: 24 [30720/50000]	Loss: 0.2792	LR: 0.000337
# Training Epoch: 24 [30848/50000]	Loss: 0.3024	LR: 0.000337
# Training Epoch: 24 [30976/50000]	Loss: 0.2719	LR: 0.000337
# Training Epoch: 24 [31104/50000]	Loss: 0.4437	LR: 0.000337
# Training Epoch: 24 [31232/50000]	Loss: 0.1989	LR: 0.000337
# Training Epoch: 24 [31360/50000]	Loss: 0.2525	LR: 0.000337
# Training Epoch: 24 [31488/50000]	Loss: 0.2815	LR: 0.000337
# Training Epoch: 24 [31616/50000]	Loss: 0.2840	LR: 0.000337
# Training Epoch: 24 [31744/50000]	Loss: 0.2104	LR: 0.000337
# Training Epoch: 24 [31872/50000]	Loss: 0.2201	LR: 0.000337
# Training Epoch: 24 [32000/50000]	Loss: 0.2171	LR: 0.000337
# Training Epoch: 24 [32128/50000]	Loss: 0.3006	LR: 0.000337
# Training Epoch: 24 [32256/50000]	Loss: 0.1764	LR: 0.000337
# Training Epoch: 24 [32384/50000]	Loss: 0.2701	LR: 0.000337
# Training Epoch: 24 [32512/50000]	Loss: 0.2534	LR: 0.000337
# Training Epoch: 24 [32640/50000]	Loss: 0.2477	LR: 0.000337
# Training Epoch: 24 [32768/50000]	Loss: 0.2629	LR: 0.000337
# Training Epoch: 24 [32896/50000]	Loss: 0.2862	LR: 0.000337
# Training Epoch: 24 [33024/50000]	Loss: 0.2647	LR: 0.000337
# Training Epoch: 24 [33152/50000]	Loss: 0.2253	LR: 0.000337
# Training Epoch: 24 [33280/50000]	Loss: 0.3612	LR: 0.000337
# Training Epoch: 24 [33408/50000]	Loss: 0.3052	LR: 0.000337
# Training Epoch: 24 [33536/50000]	Loss: 0.1799	LR: 0.000337
# Training Epoch: 24 [33664/50000]	Loss: 0.3340	LR: 0.000337
# Training Epoch: 24 [33792/50000]	Loss: 0.3163	LR: 0.000337
# Training Epoch: 24 [33920/50000]	Loss: 0.2203	LR: 0.000337
# Training Epoch: 24 [34048/50000]	Loss: 0.2984	LR: 0.000337
# Training Epoch: 24 [34176/50000]	Loss: 0.2155	LR: 0.000337
# Training Epoch: 24 [34304/50000]	Loss: 0.2896	LR: 0.000337
# Training Epoch: 24 [34432/50000]	Loss: 0.2254	LR: 0.000337
# Training Epoch: 24 [34560/50000]	Loss: 0.2512	LR: 0.000337
# Training Epoch: 24 [34688/50000]	Loss: 0.2580	LR: 0.000337
# Training Epoch: 24 [34816/50000]	Loss: 0.2668	LR: 0.000337
# Training Epoch: 24 [34944/50000]	Loss: 0.1423	LR: 0.000337
# Training Epoch: 24 [35072/50000]	Loss: 0.2934	LR: 0.000337
# Training Epoch: 24 [35200/50000]	Loss: 0.3352	LR: 0.000337
# Training Epoch: 24 [35328/50000]	Loss: 0.2388	LR: 0.000337
# Training Epoch: 24 [35456/50000]	Loss: 0.2234	LR: 0.000337
# Training Epoch: 24 [35584/50000]	Loss: 0.2962	LR: 0.000337
# Training Epoch: 24 [35712/50000]	Loss: 0.3594	LR: 0.000337
# Training Epoch: 24 [35840/50000]	Loss: 0.3037	LR: 0.000337
# Training Epoch: 24 [35968/50000]	Loss: 0.2257	LR: 0.000337
# Training Epoch: 24 [36096/50000]	Loss: 0.2698	LR: 0.000337
# Training Epoch: 24 [36224/50000]	Loss: 0.3770	LR: 0.000337
# Training Epoch: 24 [36352/50000]	Loss: 0.1856	LR: 0.000337
# Training Epoch: 24 [36480/50000]	Loss: 0.2200	LR: 0.000337
# Training Epoch: 24 [36608/50000]	Loss: 0.1490	LR: 0.000337
# Training Epoch: 24 [36736/50000]	Loss: 0.1527	LR: 0.000337
# Training Epoch: 24 [36864/50000]	Loss: 0.2897	LR: 0.000337
# Training Epoch: 24 [36992/50000]	Loss: 0.1728	LR: 0.000337
# Training Epoch: 24 [37120/50000]	Loss: 0.2816	LR: 0.000337
# Training Epoch: 24 [37248/50000]	Loss: 0.2964	LR: 0.000337
# Training Epoch: 24 [37376/50000]	Loss: 0.2809	LR: 0.000337
# Training Epoch: 24 [37504/50000]	Loss: 0.1592	LR: 0.000337
# Training Epoch: 24 [37632/50000]	Loss: 0.2497	LR: 0.000337
# Training Epoch: 24 [37760/50000]	Loss: 0.1665	LR: 0.000337
# Training Epoch: 24 [37888/50000]	Loss: 0.1470	LR: 0.000337
# Training Epoch: 24 [38016/50000]	Loss: 0.2573	LR: 0.000337
# Training Epoch: 24 [38144/50000]	Loss: 0.2591	LR: 0.000337
# Training Epoch: 24 [38272/50000]	Loss: 0.1838	LR: 0.000337
# Training Epoch: 24 [38400/50000]	Loss: 0.2514	LR: 0.000337
# Training Epoch: 24 [38528/50000]	Loss: 0.2645	LR: 0.000337
# Training Epoch: 24 [38656/50000]	Loss: 0.3101	LR: 0.000337
# Training Epoch: 24 [38784/50000]	Loss: 0.3064	LR: 0.000337
# Training Epoch: 24 [38912/50000]	Loss: 0.2497	LR: 0.000337
# Training Epoch: 24 [39040/50000]	Loss: 0.2300	LR: 0.000337
# Training Epoch: 24 [39168/50000]	Loss: 0.3489	LR: 0.000337
# Training Epoch: 24 [39296/50000]	Loss: 0.2145	LR: 0.000337
# Training Epoch: 24 [39424/50000]	Loss: 0.3098	LR: 0.000337
# Training Epoch: 24 [39552/50000]	Loss: 0.3986	LR: 0.000337
# Training Epoch: 24 [39680/50000]	Loss: 0.1685	LR: 0.000337
# Training Epoch: 24 [39808/50000]	Loss: 0.1985	LR: 0.000337
# Training Epoch: 24 [39936/50000]	Loss: 0.2546	LR: 0.000337
# Training Epoch: 24 [40064/50000]	Loss: 0.1986	LR: 0.000337
# Training Epoch: 24 [40192/50000]	Loss: 0.2489	LR: 0.000337
# Training Epoch: 24 [40320/50000]	Loss: 0.2200	LR: 0.000337
# Training Epoch: 24 [40448/50000]	Loss: 0.1647	LR: 0.000337
# Training Epoch: 24 [40576/50000]	Loss: 0.2542	LR: 0.000337
# Training Epoch: 24 [40704/50000]	Loss: 0.1923	LR: 0.000337
# Training Epoch: 24 [40832/50000]	Loss: 0.3894	LR: 0.000337
# Training Epoch: 24 [40960/50000]	Loss: 0.1831	LR: 0.000337
# Training Epoch: 24 [41088/50000]	Loss: 0.2660	LR: 0.000337
# Training Epoch: 24 [41216/50000]	Loss: 0.1529	LR: 0.000337
# Training Epoch: 24 [41344/50000]	Loss: 0.3250	LR: 0.000337
# Training Epoch: 24 [41472/50000]	Loss: 0.2466	LR: 0.000337
# Training Epoch: 24 [41600/50000]	Loss: 0.1357	LR: 0.000337
# Training Epoch: 24 [41728/50000]	Loss: 0.2700	LR: 0.000337
# Training Epoch: 24 [41856/50000]	Loss: 0.3319	LR: 0.000337
# Training Epoch: 24 [41984/50000]	Loss: 0.2427	LR: 0.000337
# Training Epoch: 24 [42112/50000]	Loss: 0.2367	LR: 0.000337
# Training Epoch: 24 [42240/50000]	Loss: 0.1428	LR: 0.000337
# Training Epoch: 24 [42368/50000]	Loss: 0.1717	LR: 0.000337
# Training Epoch: 24 [42496/50000]	Loss: 0.2333	LR: 0.000337
# Training Epoch: 24 [42624/50000]	Loss: 0.2505	LR: 0.000337
# Training Epoch: 24 [42752/50000]	Loss: 0.1829	LR: 0.000337
# Training Epoch: 24 [42880/50000]	Loss: 0.2788	LR: 0.000337
# Training Epoch: 24 [43008/50000]	Loss: 0.2686	LR: 0.000337
# Training Epoch: 24 [43136/50000]	Loss: 0.1844	LR: 0.000337
# Training Epoch: 24 [43264/50000]	Loss: 0.2339	LR: 0.000337
# Training Epoch: 24 [43392/50000]	Loss: 0.2501	LR: 0.000337
# Training Epoch: 24 [43520/50000]	Loss: 0.1925	LR: 0.000337
# Training Epoch: 24 [43648/50000]	Loss: 0.1907	LR: 0.000337
# Training Epoch: 24 [43776/50000]	Loss: 0.2508	LR: 0.000337
# Training Epoch: 24 [43904/50000]	Loss: 0.2200	LR: 0.000337
# Training Epoch: 24 [44032/50000]	Loss: 0.2950	LR: 0.000337
# Training Epoch: 24 [44160/50000]	Loss: 0.2736	LR: 0.000337
# Training Epoch: 24 [44288/50000]	Loss: 0.3588	LR: 0.000337
# Training Epoch: 24 [44416/50000]	Loss: 0.2052	LR: 0.000337
# Training Epoch: 24 [44544/50000]	Loss: 0.1428	LR: 0.000337
# Training Epoch: 24 [44672/50000]	Loss: 0.2722	LR: 0.000337
# Training Epoch: 24 [44800/50000]	Loss: 0.2318	LR: 0.000337
# Training Epoch: 24 [44928/50000]	Loss: 0.2108	LR: 0.000337
# Training Epoch: 24 [45056/50000]	Loss: 0.2245	LR: 0.000337
# Training Epoch: 24 [45184/50000]	Loss: 0.2269	LR: 0.000337
# Training Epoch: 24 [45312/50000]	Loss: 0.2771	LR: 0.000337
# Training Epoch: 24 [45440/50000]	Loss: 0.2078	LR: 0.000337
# Training Epoch: 24 [45568/50000]	Loss: 0.2660	LR: 0.000337
# Training Epoch: 24 [45696/50000]	Loss: 0.2319	LR: 0.000337
# Training Epoch: 24 [45824/50000]	Loss: 0.2266	LR: 0.000337
# Training Epoch: 24 [45952/50000]	Loss: 0.2167	LR: 0.000337
# Training Epoch: 24 [46080/50000]	Loss: 0.1439	LR: 0.000337
# Training Epoch: 24 [46208/50000]	Loss: 0.2220	LR: 0.000337
# Training Epoch: 24 [46336/50000]	Loss: 0.3008	LR: 0.000337
# Training Epoch: 24 [46464/50000]	Loss: 0.2872	LR: 0.000337
# Training Epoch: 24 [46592/50000]	Loss: 0.2217	LR: 0.000337
# Training Epoch: 24 [46720/50000]	Loss: 0.3064	LR: 0.000337
# Training Epoch: 24 [46848/50000]	Loss: 0.1121	LR: 0.000337
# Training Epoch: 24 [46976/50000]	Loss: 0.1957	LR: 0.000337
# Training Epoch: 24 [47104/50000]	Loss: 0.2911	LR: 0.000337
# Training Epoch: 24 [47232/50000]	Loss: 0.1942	LR: 0.000337
# Training Epoch: 24 [47360/50000]	Loss: 0.2294	LR: 0.000337
# Training Epoch: 24 [47488/50000]	Loss: 0.2373	LR: 0.000337
# Training Epoch: 24 [47616/50000]	Loss: 0.3176	LR: 0.000337
# Training Epoch: 24 [47744/50000]	Loss: 0.2028	LR: 0.000337
# Training Epoch: 24 [47872/50000]	Loss: 0.3010	LR: 0.000337
# Training Epoch: 24 [48000/50000]	Loss: 0.2859	LR: 0.000337
# Training Epoch: 24 [48128/50000]	Loss: 0.1551	LR: 0.000337
# Training Epoch: 24 [48256/50000]	Loss: 0.2191	LR: 0.000337
# Training Epoch: 24 [48384/50000]	Loss: 0.2504	LR: 0.000337
# Training Epoch: 24 [48512/50000]	Loss: 0.3329	LR: 0.000337
# Training Epoch: 24 [48640/50000]	Loss: 0.2784	LR: 0.000337
# Training Epoch: 24 [48768/50000]	Loss: 0.3100	LR: 0.000337
# Training Epoch: 24 [48896/50000]	Loss: 0.2576	LR: 0.000337
# Training Epoch: 24 [49024/50000]	Loss: 0.2248	LR: 0.000337
# Training Epoch: 24 [49152/50000]	Loss: 0.2679	LR: 0.000337
# Training Epoch: 24 [49280/50000]	Loss: 0.2612	LR: 0.000337
# Training Epoch: 24 [49408/50000]	Loss: 0.2627	LR: 0.000337
# Training Epoch: 24 [49536/50000]	Loss: 0.2815	LR: 0.000337
# Training Epoch: 24 [49664/50000]	Loss: 0.3710	LR: 0.000337
# Training Epoch: 24 [49792/50000]	Loss: 0.3208	LR: 0.000337
# Training Epoch: 24 [49920/50000]	Loss: 0.1941	LR: 0.000337
# Training Epoch: 24 [50000/50000]	Loss: 0.2620	LR: 0.000337
# Test set: Average loss: 0.0026, Accuracy: 0.8943
#
#
# best_acc:  tensor(0.8943, device='cuda:0')

# %% [markdown]
# ## Testing the Model

# %%
weights_file="./resnetcbam18.pth"
torch.save(net.state_dict(), weights_file)

# %%
if __name__ == '__main__':
    net = get_network()
    CIFAR10_test_loader = get_test_dataloader(
        CIFAR10_TRAIN_MEAN,
        CIFAR10_TRAIN_STD,
        #CIFAR10_PATH,
        num_workers=2,
        batch_size=128,
        shuffle=True
    )

    net.load_state_dict(torch.load(weights_file), True)
    print(net)
    net.eval()

    correct_1 = 0.0
    correct_5 = 0.0
    total = 0

    for n_iter, (image, label) in enumerate(CIFAR10_test_loader):
        print("iteration: {}\ttotal {} iterations".format(n_iter + 1, len(CIFAR10_test_loader)))
        image = Variable(image).cuda()
        label = Variable(label).cuda()
        output = net(image)
        _, pred = output.topk(5, 1, largest=True, sorted=True)

        label = label.view(label.size(0), -1).expand_as(pred)
        correct = pred.eq(label).float()

        #compute top 5
        correct_5 += correct[:, :5].sum()

        #compute top1 
        correct_1 += correct[:, :1].sum()


    print()
    print("Top 1 err: ", 1 - correct_1 / len(CIFAR10_test_loader.dataset))
    print("Top 5 err: ", 1 - correct_5 / len(CIFAR10_test_loader.dataset))
    print("Parameter numbers: {}".format(sum(p.numel() for p in net.parameters())))
# Out:
# Files already downloaded and verified
# ResNetCBAM(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (cbam): CBAM(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )
# iteration: 1	total 79 iterations
# iteration: 2	total 79 iterations
# iteration: 3	total 79 iterations
# iteration: 4	total 79 iterations
# iteration: 5	total 79 iterations
# iteration: 6	total 79 iterations
# iteration: 7	total 79 iterations
# iteration: 8	total 79 iterations
# iteration: 9	total 79 iterations
# iteration: 10	total 79 iterations
# iteration: 11	total 79 iterations
# iteration: 12	total 79 iterations
# iteration: 13	total 79 iterations
# iteration: 14	total 79 iterations
# iteration: 15	total 79 iterations
# iteration: 16	total 79 iterations
# iteration: 17	total 79 iterations
# iteration: 18	total 79 iterations
# iteration: 19	total 79 iterations
# iteration: 20	total 79 iterations
# iteration: 21	total 79 iterations
# iteration: 22	total 79 iterations
# iteration: 23	total 79 iterations
# iteration: 24	total 79 iterations
# iteration: 25	total 79 iterations
# iteration: 26	total 79 iterations
# iteration: 27	total 79 iterations
# iteration: 28	total 79 iterations
# iteration: 29	total 79 iterations
# iteration: 30	total 79 iterations
# iteration: 31	total 79 iterations
# iteration: 32	total 79 iterations
# iteration: 33	total 79 iterations
# iteration: 34	total 79 iterations
# iteration: 35	total 79 iterations
# iteration: 36	total 79 iterations
# iteration: 37	total 79 iterations
# iteration: 38	total 79 iterations
# iteration: 39	total 79 iterations
# iteration: 40	total 79 iterations
# iteration: 41	total 79 iterations
# iteration: 42	total 79 iterations
# iteration: 43	total 79 iterations
# iteration: 44	total 79 iterations
# iteration: 45	total 79 iterations
# iteration: 46	total 79 iterations
# iteration: 47	total 79 iterations
# iteration: 48	total 79 iterations
# iteration: 49	total 79 iterations
# iteration: 50	total 79 iterations
# iteration: 51	total 79 iterations
# iteration: 52	total 79 iterations
# iteration: 53	total 79 iterations
# iteration: 54	total 79 iterations
# iteration: 55	total 79 iterations
# iteration: 56	total 79 iterations
# iteration: 57	total 79 iterations
# iteration: 58	total 79 iterations
# iteration: 59	total 79 iterations
# iteration: 60	total 79 iterations
# iteration: 61	total 79 iterations
# iteration: 62	total 79 iterations
# iteration: 63	total 79 iterations
# iteration: 64	total 79 iterations
# iteration: 65	total 79 iterations
# iteration: 66	total 79 iterations
# iteration: 67	total 79 iterations
# iteration: 68	total 79 iterations
# iteration: 69	total 79 iterations
# iteration: 70	total 79 iterations
# iteration: 71	total 79 iterations
# iteration: 72	total 79 iterations
# iteration: 73	total 79 iterations
# iteration: 74	total 79 iterations
# iteration: 75	total 79 iterations
# iteration: 76	total 79 iterations
# iteration: 77	total 79 iterations
# iteration: 78	total 79 iterations
# iteration: 79	total 79 iterations
#
# Top 1 err:  tensor(0.1057, device='cuda:0')
# Top 5 err:  tensor(0.0031, device='cuda:0')
# Parameter numbers: 11261146
